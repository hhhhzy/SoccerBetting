# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
from diskcache import Cache

cache = Cache("match_details.shelve")

@cache.memoize()
def get_page(link):
    print(link)
    return requests.get(link).content

# %%
import sys
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
matches_df = pd.read_csv('dfs/matches/matches.csv', parse_dates=['datetime'])

matches_df
# Out:
#          id  isResult  h_id                  h_title h_short_title  a_id  \
# 0     14814     False   229  Wolverhampton Wanderers           WOL    89
# 1     14813     False    81                 West Ham           WHU    74
# 2     14812     False   238         Sheffield United           SHE    92
# 3     14811     False    88          Manchester City           MCI    72
# 4     14810     False    87                Liverpool           LIV    78
# ...     ...       ...   ...                      ...           ...   ...
# 2655   4751      True   202      Queens Park Rangers           QPR    91
# 2656   4750      True    75                Leicester           LEI    72
# 2657   4753      True    76     West Bromwich Albion           WBA    77
# 2658   4754      True    81                 West Ham           WHU    82
# 2659   4749      True    89        Manchester United           MUN    84
#
#                 a_title a_short_title  goals_h  goals_a     xG_h      xG_a  \
# 0     Manchester United           MUN      NaN      NaN      NaN       NaN
# 1           Southampton           SOU      NaN      NaN      NaN       NaN
# 2               Burnley           BUR      NaN      NaN      NaN       NaN
# 3               Everton           EVE      NaN      NaN      NaN       NaN
# 4        Crystal Palace           CRY      NaN      NaN      NaN       NaN
# ...                 ...           ...      ...      ...      ...       ...
# 2655               Hull           HUL      0.0      1.0  1.90067  1.117570
# 2656            Everton           EVE      2.0      2.0  1.27830  0.613273
# 2657         Sunderland           SUN      2.0      2.0  1.68343  0.991901
# 2658          Tottenham           TOT      0.0      1.0  1.85310  1.017060
# 2659            Swansea           SWA      1.0      2.0  1.16635  0.278076
#
#                 datetime  forecast_w  forecast_d  forecast_l     season league
# 0    2021-05-22 17:00:00         NaN         NaN         NaN  2020-2021    EPL
# 1    2021-05-22 17:00:00         NaN         NaN         NaN  2020-2021    EPL
# 2    2021-05-22 17:00:00         NaN         NaN         NaN  2020-2021    EPL
# 3    2021-05-22 17:00:00         NaN         NaN         NaN  2020-2021    EPL
# 4    2021-05-22 17:00:00         NaN         NaN         NaN  2020-2021    EPL
# ...                  ...         ...         ...         ...        ...    ...
# 2655 2014-08-16 15:00:00      0.5900      0.2449      0.1651  2014-2015    EPL
# 2656 2014-08-16 15:00:00      0.5513      0.2922      0.1565  2014-2015    EPL
# 2657 2014-08-16 15:00:00      0.5894      0.2676      0.1430  2014-2015    EPL
# 2658 2014-08-16 15:00:00      0.5856      0.2648      0.1496  2014-2015    EPL
# 2659 2014-08-16 12:45:00      0.6519      0.2802      0.0679  2014-2015    EPL
#
# [2660 rows x 18 columns]

# %%
from tqdm.auto import tqdm

base_url = 'https://understat.com/match/'

dfs = []

for _, row in tqdm(matches_df.iterrows()):
    if row['isResult'] == True:
        match_id = row['id']
        url = base_url + str(match_id)

        #Use requests to get the webpage and BeautifulSoup to parse the page
        res = get_page(url)
        soup = BeautifulSoup(res, 'lxml')
        scripts = soup.find_all('script')

        #get only the shotsData
        strings = scripts[1].string
        # strip unnecessary symbols and get only JSON data 
        ind_start = strings.index("('")+2 
        ind_end = strings.index("')") 
        json_data = strings[ind_start:ind_end] 
        json_data = json_data.encode('utf8').decode('unicode_escape')

        #convert string to json format
        data = json.loads(json_data)
        data_home = data['h']
        data_away = data['a']

        df_h = pd.DataFrame(data_home)
        df_h['season'] = row['season']
        df_h['league'] = row['league']
        df_h['HomeAway'] = 'Home'

        df_a = pd.DataFrame(data_away)
        df_a['season'] = row['season']
        df_a['league'] = row['league']
        df_a['HomeAway'] = 'Away'

        df = pd.concat([df_h, df_a])

        dfs.append(df)
# Out:
# 0it [00:00, ?it/s]
# https://understat.com/match/14685
# https://understat.com/match/14693
# https://understat.com/match/14687
# https://understat.com/match/14690
# https://understat.com/match/14688
# https://understat.com/match/14691
# https://understat.com/match/14692
# https://understat.com/match/14689
# https://understat.com/match/14608
# https://understat.com/match/14677
# https://understat.com/match/14681
# https://understat.com/match/14675
# https://understat.com/match/14676
# https://understat.com/match/14683
# https://understat.com/match/14679
# https://understat.com/match/14680
# https://understat.com/match/14678
# https://understat.com/match/14682
# https://understat.com/match/14684
# https://understat.com/match/14593
# https://understat.com/match/14602
# https://understat.com/match/14667
# https://understat.com/match/14674
# https://understat.com/match/14669
# https://understat.com/match/14665
# https://understat.com/match/14673
# https://understat.com/match/14672
# https://understat.com/match/14666
# https://understat.com/match/14671
# https://understat.com/match/14668
# https://understat.com/match/14670
# https://understat.com/match/14658
# https://understat.com/match/14662
# https://understat.com/match/14659
# https://understat.com/match/14664
# https://understat.com/match/14663
# https://understat.com/match/14660
# https://understat.com/match/14657
# https://understat.com/match/14656
# https://understat.com/match/14661
# https://understat.com/match/14655
# https://understat.com/match/14653
# https://understat.com/match/14654
# https://understat.com/match/14645
# https://understat.com/match/14648
# https://understat.com/match/14647
# https://understat.com/match/14646
# https://understat.com/match/14652
# https://understat.com/match/14651
# https://understat.com/match/14649
# https://understat.com/match/14650
# https://understat.com/match/14636
# https://understat.com/match/14639
# https://understat.com/match/14643
# https://understat.com/match/14637
# https://understat.com/match/14641
# https://understat.com/match/14635
# https://understat.com/match/14638
# https://understat.com/match/14642
# https://understat.com/match/14640
# https://understat.com/match/14644
# https://understat.com/match/14633
# https://understat.com/match/14627
# https://understat.com/match/14628
# https://understat.com/match/14625
# https://understat.com/match/14630
# https://understat.com/match/14626
# https://understat.com/match/14632
# https://understat.com/match/14629
# https://understat.com/match/14634
# https://understat.com/match/14631
# https://understat.com/match/14535
# https://understat.com/match/14613
# https://understat.com/match/14607
# https://understat.com/match/14089
# https://understat.com/match/14609
# https://understat.com/match/14611
# https://understat.com/match/14615
# https://understat.com/match/14621
# https://understat.com/match/14620
# https://understat.com/match/14622
# https://understat.com/match/14619
# https://understat.com/match/14617
# https://understat.com/match/14623
# https://understat.com/match/14618
# https://understat.com/match/14624
# https://understat.com/match/14605
# https://understat.com/match/14589
# https://understat.com/match/14614
# https://understat.com/match/14088
# https://understat.com/match/14612
# https://understat.com/match/14610
# https://understat.com/match/14598
# https://understat.com/match/14603
# https://understat.com/match/14597
# https://understat.com/match/14600
# https://understat.com/match/14601
# https://understat.com/match/14604
# https://understat.com/match/14599
# https://understat.com/match/14596
# https://understat.com/match/14595
# https://understat.com/match/14591
# https://understat.com/match/14592
# https://understat.com/match/14590
# https://understat.com/match/14588
# https://understat.com/match/14587
# https://understat.com/match/14585
# https://understat.com/match/14586
# https://understat.com/match/14594
# https://understat.com/match/14584
# https://understat.com/match/14580
# https://understat.com/match/14583
# https://understat.com/match/14578
# https://understat.com/match/14582
# https://understat.com/match/14581
# https://understat.com/match/14575
# https://understat.com/match/14577
# https://understat.com/match/14576
# https://understat.com/match/14579
# https://understat.com/match/14567
# https://understat.com/match/14566
# https://understat.com/match/14574
# https://understat.com/match/14570
# https://understat.com/match/14573
# https://understat.com/match/14565
# https://understat.com/match/14571
# https://understat.com/match/14569
# https://understat.com/match/14572
# https://understat.com/match/14568
# https://understat.com/match/14560
# https://understat.com/match/14556
# https://understat.com/match/14563
# https://understat.com/match/14561
# https://understat.com/match/14557
# https://understat.com/match/14558
# https://understat.com/match/14555
# https://understat.com/match/14559
# https://understat.com/match/14564
# https://understat.com/match/14562
# https://understat.com/match/14554
# https://understat.com/match/14553
# https://understat.com/match/14547
# https://understat.com/match/14545
# https://understat.com/match/14551
# https://understat.com/match/14546
# https://understat.com/match/14549
# https://understat.com/match/14550
# https://understat.com/match/14552
# https://understat.com/match/14548
# https://understat.com/match/14536
# https://understat.com/match/14539
# https://understat.com/match/14542
# https://understat.com/match/14541
# https://understat.com/match/14543
# https://understat.com/match/14538
# https://understat.com/match/14544
# https://understat.com/match/14540
# https://understat.com/match/14537
# https://understat.com/match/14526
# https://understat.com/match/14532
# https://understat.com/match/14525
# https://understat.com/match/14529
# https://understat.com/match/14534
# https://understat.com/match/14527
# https://understat.com/match/14531
# https://understat.com/match/14533
# https://understat.com/match/14528
# https://understat.com/match/14530
# https://understat.com/match/14524
# https://understat.com/match/14516
# https://understat.com/match/14519
# https://understat.com/match/14518
# https://understat.com/match/14522
# https://understat.com/match/14517
# https://understat.com/match/14520
# https://understat.com/match/14523
# https://understat.com/match/14515
# https://understat.com/match/14521
# https://understat.com/match/14505
# https://understat.com/match/14511
# https://understat.com/match/14510
# https://understat.com/match/14513
# https://understat.com/match/14514
# https://understat.com/match/14507
# https://understat.com/match/14508
# https://understat.com/match/14509
# https://understat.com/match/14512
# https://understat.com/match/14506
# https://understat.com/match/14498
# https://understat.com/match/14497
# https://understat.com/match/14503
# https://understat.com/match/14500
# https://understat.com/match/14501
# https://understat.com/match/14495
# https://understat.com/match/14499
# https://understat.com/match/14496
# https://understat.com/match/14502
# https://understat.com/match/14504
# https://understat.com/match/14488
# https://understat.com/match/14487
# https://understat.com/match/14485
# https://understat.com/match/14494
# https://understat.com/match/14492
# https://understat.com/match/14490
# https://understat.com/match/14491
# https://understat.com/match/14489
# https://understat.com/match/14493
# https://understat.com/match/14486
# https://understat.com/match/14478
# https://understat.com/match/14484
# https://understat.com/match/14479
# https://understat.com/match/14483
# https://understat.com/match/14476
# https://understat.com/match/14482
# https://understat.com/match/14481
# https://understat.com/match/14480
# https://understat.com/match/14475
# https://understat.com/match/14477
# https://understat.com/match/14466
# https://understat.com/match/14471
# https://understat.com/match/14474
# https://understat.com/match/14465
# https://understat.com/match/14473
# https://understat.com/match/14470
# https://understat.com/match/14472
# https://understat.com/match/14469
# https://understat.com/match/14468
# https://understat.com/match/14467
# https://understat.com/match/14115
# https://understat.com/match/14114
# https://understat.com/match/14113
# https://understat.com/match/14112
# https://understat.com/match/14111
# https://understat.com/match/14110
# https://understat.com/match/14109
# https://understat.com/match/14108
# https://understat.com/match/14107
# https://understat.com/match/14106
# https://understat.com/match/14105
# https://understat.com/match/14104
# https://understat.com/match/14103
# https://understat.com/match/14102
# https://understat.com/match/14101
# https://understat.com/match/14100
# https://understat.com/match/14099
# https://understat.com/match/14098
# https://understat.com/match/14097
# https://understat.com/match/14096
# https://understat.com/match/14095
# https://understat.com/match/14094
# https://understat.com/match/14093
# https://understat.com/match/14092
# https://understat.com/match/14091
# https://understat.com/match/14090
# https://understat.com/match/14087
# https://understat.com/match/14086
# https://understat.com/match/12022
# https://understat.com/match/12013
# https://understat.com/match/12021
# https://understat.com/match/12020
# https://understat.com/match/12019
# https://understat.com/match/12018
# https://understat.com/match/12017
# https://understat.com/match/12016
# https://understat.com/match/12015
# https://understat.com/match/12014
# https://understat.com/match/12006
# https://understat.com/match/12007
# https://understat.com/match/12003
# https://understat.com/match/12011
# https://understat.com/match/12012
# https://understat.com/match/12009
# https://understat.com/match/12005
# https://understat.com/match/12010
# https://understat.com/match/12004
# https://understat.com/match/12008
# https://understat.com/match/12001
# https://understat.com/match/11996
# https://understat.com/match/12002
# https://understat.com/match/11998
# https://understat.com/match/11997
# https://understat.com/match/11993
# https://understat.com/match/12000
# https://understat.com/match/11999
# https://understat.com/match/11994
# https://understat.com/match/11995
# https://understat.com/match/11987
# https://understat.com/match/11984
# https://understat.com/match/11990
# https://understat.com/match/11983
# https://understat.com/match/11992
# https://understat.com/match/11985
# https://understat.com/match/11989
# https://understat.com/match/11986
# https://understat.com/match/11991
# https://understat.com/match/11988
# https://understat.com/match/11974
# https://understat.com/match/11975
# https://understat.com/match/11978
# https://understat.com/match/11976
# https://understat.com/match/11979
# https://understat.com/match/11980
# https://understat.com/match/11982
# https://understat.com/match/11973
# https://understat.com/match/11981
# https://understat.com/match/11977
# https://understat.com/match/11971
# https://understat.com/match/11970
# https://understat.com/match/11966
# https://understat.com/match/11968
# https://understat.com/match/11963
# https://understat.com/match/11964
# https://understat.com/match/11972
# https://understat.com/match/11967
# https://understat.com/match/11965
# https://understat.com/match/11969
# https://understat.com/match/11959
# https://understat.com/match/11960
# https://understat.com/match/11962
# https://understat.com/match/11953
# https://understat.com/match/11958
# https://understat.com/match/11955
# https://understat.com/match/11956
# https://understat.com/match/11957
# https://understat.com/match/11961
# https://understat.com/match/11954
# https://understat.com/match/11946
# https://understat.com/match/11952
# https://understat.com/match/11943
# https://understat.com/match/11951
# https://understat.com/match/11950
# https://understat.com/match/11949
# https://understat.com/match/11948
# https://understat.com/match/11947
# https://understat.com/match/11944
# https://understat.com/match/11945
# https://understat.com/match/11939
# https://understat.com/match/11940
# https://understat.com/match/11933
# https://understat.com/match/11938
# https://understat.com/match/11942
# https://understat.com/match/11934
# https://understat.com/match/11941
# https://understat.com/match/11935
# https://understat.com/match/11936
# https://understat.com/match/11937
# https://understat.com/match/11917
# https://understat.com/match/11913
# https://understat.com/match/11927
# https://understat.com/match/11932
# https://understat.com/match/11925
# https://understat.com/match/11924
# https://understat.com/match/11931
# https://understat.com/match/11930
# https://understat.com/match/11929
# https://understat.com/match/11926
# https://understat.com/match/11923
# https://understat.com/match/11928
# https://understat.com/match/11916
# https://understat.com/match/11920
# https://understat.com/match/11921
# https://understat.com/match/11922
# https://understat.com/match/11918
# https://understat.com/match/11914
# https://understat.com/match/11915
# https://understat.com/match/11919
# https://understat.com/match/11911
# https://understat.com/match/11903
# https://understat.com/match/11910
# https://understat.com/match/11912
# https://understat.com/match/11904
# https://understat.com/match/11905
# https://understat.com/match/11907
# https://understat.com/match/11908
# https://understat.com/match/11909
# https://understat.com/match/11906
# https://understat.com/match/11898
# https://understat.com/match/11896
# https://understat.com/match/11893
# https://understat.com/match/11894
# https://understat.com/match/11899
# https://understat.com/match/11901
# https://understat.com/match/11902
# https://understat.com/match/11900
# https://understat.com/match/11895
# https://understat.com/match/11897
# https://understat.com/match/11890
# https://understat.com/match/11884
# https://understat.com/match/11888
# https://understat.com/match/11889
# https://understat.com/match/11885
# https://understat.com/match/11887
# https://understat.com/match/11883
# https://understat.com/match/11891
# https://understat.com/match/11892
# https://understat.com/match/11886
# https://understat.com/match/11822
# https://understat.com/match/11874
# https://understat.com/match/11879
# https://understat.com/match/11880
# https://understat.com/match/11876
# https://understat.com/match/11881
# https://understat.com/match/11873
# https://understat.com/match/11882
# https://understat.com/match/11878
# https://understat.com/match/11877
# https://understat.com/match/11875
# https://understat.com/match/11865
# https://understat.com/match/11866
# https://understat.com/match/11868
# https://understat.com/match/11872
# https://understat.com/match/11870
# https://understat.com/match/11869
# https://understat.com/match/11867
# https://understat.com/match/11864
# https://understat.com/match/11863
# https://understat.com/match/11871
# https://understat.com/match/11856
# https://understat.com/match/11857
# https://understat.com/match/11854
# https://understat.com/match/11861
# https://understat.com/match/11860
# https://understat.com/match/11858
# https://understat.com/match/11853
# https://understat.com/match/11862
# https://understat.com/match/11859
# https://understat.com/match/11855
# https://understat.com/match/11847
# https://understat.com/match/11844
# https://understat.com/match/11848
# https://understat.com/match/11843
# https://understat.com/match/11850
# https://understat.com/match/11852
# https://understat.com/match/11851
# https://understat.com/match/11849
# https://understat.com/match/11846
# https://understat.com/match/11845
# https://understat.com/match/11837
# https://understat.com/match/11836
# https://understat.com/match/11833
# https://understat.com/match/11835
# https://understat.com/match/11839
# https://understat.com/match/11842
# https://understat.com/match/11840
# https://understat.com/match/11841
# https://understat.com/match/11838
# https://understat.com/match/11834
# https://understat.com/match/11832
# https://understat.com/match/11828
# https://understat.com/match/11829
# https://understat.com/match/11823
# https://understat.com/match/11830
# https://understat.com/match/11827
# https://understat.com/match/11826
# https://understat.com/match/11825
# https://understat.com/match/11824
# https://understat.com/match/11831
# https://understat.com/match/11820
# https://understat.com/match/11821
# https://understat.com/match/11817
# https://understat.com/match/11819
# https://understat.com/match/11818
# https://understat.com/match/11815
# https://understat.com/match/11814
# https://understat.com/match/11813
# https://understat.com/match/11816
# https://understat.com/match/11806
# https://understat.com/match/11803
# https://understat.com/match/11809
# https://understat.com/match/11812
# https://understat.com/match/11811
# https://understat.com/match/11810
# https://understat.com/match/11807
# https://understat.com/match/11805
# https://understat.com/match/11804
# https://understat.com/match/11808
# https://understat.com/match/11802
# https://understat.com/match/11795
# https://understat.com/match/11793
# https://understat.com/match/11798
# https://understat.com/match/11799
# https://understat.com/match/11797
# https://understat.com/match/11801
# https://understat.com/match/11800
# https://understat.com/match/11794
# https://understat.com/match/11796
# https://understat.com/match/11783
# https://understat.com/match/11786
# https://understat.com/match/11792
# https://understat.com/match/11785
# https://understat.com/match/11788
# https://understat.com/match/11787
# https://understat.com/match/11789
# https://understat.com/match/11790
# https://understat.com/match/11784
# https://understat.com/match/11791
# https://understat.com/match/11782
# https://understat.com/match/11775
# https://understat.com/match/11781
# https://understat.com/match/11780
# https://understat.com/match/11778
# https://understat.com/match/11779
# https://understat.com/match/11776
# https://understat.com/match/11774
# https://understat.com/match/11773
# https://understat.com/match/11777
# https://understat.com/match/11764
# https://understat.com/match/11770
# https://understat.com/match/11769
# https://understat.com/match/11763
# https://understat.com/match/11767
# https://understat.com/match/11766
# https://understat.com/match/11765
# https://understat.com/match/11768
# https://understat.com/match/11771
# https://understat.com/match/11772
# https://understat.com/match/11755
# https://understat.com/match/11761
# https://understat.com/match/11760
# https://understat.com/match/11762
# https://understat.com/match/11758
# https://understat.com/match/11756
# https://understat.com/match/11753
# https://understat.com/match/11759
# https://understat.com/match/11754
# https://understat.com/match/11757
# https://understat.com/match/11748
# https://understat.com/match/11747
# https://understat.com/match/11751
# https://understat.com/match/11743
# https://understat.com/match/11752
# https://understat.com/match/11750
# https://understat.com/match/11749
# https://understat.com/match/11746
# https://understat.com/match/11744
# https://understat.com/match/11745
# https://understat.com/match/11736
# https://understat.com/match/11733
# https://understat.com/match/11739
# https://understat.com/match/11738
# https://understat.com/match/11735
# https://understat.com/match/11742
# https://understat.com/match/11741
# https://understat.com/match/11734
# https://understat.com/match/11737
# https://understat.com/match/11740
# https://understat.com/match/11730
# https://understat.com/match/11729
# https://understat.com/match/11726
# https://understat.com/match/11725
# https://understat.com/match/11723
# https://understat.com/match/11724
# https://understat.com/match/11728
# https://understat.com/match/11731
# https://understat.com/match/11732
# https://understat.com/match/11727
# https://understat.com/match/11721
# https://understat.com/match/11722
# https://understat.com/match/11718
# https://understat.com/match/11716
# https://understat.com/match/11720
# https://understat.com/match/11715
# https://understat.com/match/11714
# https://understat.com/match/11717
# https://understat.com/match/11719
# https://understat.com/match/11713
# https://understat.com/match/11712
# https://understat.com/match/11710
# https://understat.com/match/11711
# https://understat.com/match/11705
# https://understat.com/match/11707
# https://understat.com/match/11704
# https://understat.com/match/11706
# https://understat.com/match/11708
# https://understat.com/match/11709
# https://understat.com/match/11703
# https://understat.com/match/11702
# https://understat.com/match/11701
# https://understat.com/match/11700
# https://understat.com/match/11697
# https://understat.com/match/11699
# https://understat.com/match/11698
# https://understat.com/match/11695
# https://understat.com/match/11696
# https://understat.com/match/11694
# https://understat.com/match/11693
# https://understat.com/match/11692
# https://understat.com/match/11691
# https://understat.com/match/11690
# https://understat.com/match/11689
# https://understat.com/match/11688
# https://understat.com/match/11687
# https://understat.com/match/11686
# https://understat.com/match/11685
# https://understat.com/match/11684
# https://understat.com/match/11683
# https://understat.com/match/11682
# https://understat.com/match/11681
# https://understat.com/match/11680
# https://understat.com/match/11679
# https://understat.com/match/11678
# https://understat.com/match/11677
# https://understat.com/match/11676
# https://understat.com/match/11675
# https://understat.com/match/11674
# https://understat.com/match/11673
# https://understat.com/match/11668
# https://understat.com/match/11672
# https://understat.com/match/11671
# https://understat.com/match/11670
# https://understat.com/match/11669
# https://understat.com/match/11667
# https://understat.com/match/11666
# https://understat.com/match/11665
# https://understat.com/match/11664
# https://understat.com/match/11663
# https://understat.com/match/11662
# https://understat.com/match/11661
# https://understat.com/match/11660
# https://understat.com/match/11659
# https://understat.com/match/11658
# https://understat.com/match/11657
# https://understat.com/match/11656
# https://understat.com/match/11655
# https://understat.com/match/11654
# https://understat.com/match/11653
# https://understat.com/match/11652
# https://understat.com/match/11650
# https://understat.com/match/11651
# https://understat.com/match/11649
# https://understat.com/match/11647
# https://understat.com/match/11645
# https://understat.com/match/11648
# https://understat.com/match/11646
# https://understat.com/match/11644
# https://understat.com/match/11643
# https://understat.com/match/9576
# https://understat.com/match/9571
# https://understat.com/match/9568
# https://understat.com/match/9569
# https://understat.com/match/9570
# https://understat.com/match/9567
# https://understat.com/match/9572
# https://understat.com/match/9573
# https://understat.com/match/9574
# https://understat.com/match/9575
# https://understat.com/match/9560
# https://understat.com/match/9566
# https://understat.com/match/9563
# https://understat.com/match/9561
# https://understat.com/match/9559
# https://understat.com/match/9564
# https://understat.com/match/9558
# https://understat.com/match/9557
# https://understat.com/match/9565
# https://understat.com/match/9562
# https://understat.com/match/9550
# https://understat.com/match/9555
# https://understat.com/match/9552
# https://understat.com/match/9556
# https://understat.com/match/9554
# https://understat.com/match/9553
# https://understat.com/match/9549
# https://understat.com/match/9547
# https://understat.com/match/9548
# https://understat.com/match/9551
# https://understat.com/match/9501
# https://understat.com/match/9497
# https://understat.com/match/9499
# https://understat.com/match/9519
# https://understat.com/match/9543
# https://understat.com/match/9546
# https://understat.com/match/9544
# https://understat.com/match/9542
# https://understat.com/match/9539
# https://understat.com/match/9537
# https://understat.com/match/9545
# https://understat.com/match/9541
# https://understat.com/match/9538
# https://understat.com/match/9540
# https://understat.com/match/9505
# https://understat.com/match/9527
# https://understat.com/match/9531
# https://understat.com/match/9534
# https://understat.com/match/9530
# https://understat.com/match/9536
# https://understat.com/match/9535
# https://understat.com/match/9533
# https://understat.com/match/9529
# https://understat.com/match/9528
# https://understat.com/match/9532
# https://understat.com/match/9525
# https://understat.com/match/9524
# https://understat.com/match/9526
# https://understat.com/match/9523
# https://understat.com/match/9521
# https://understat.com/match/9520
# https://understat.com/match/9522
# https://understat.com/match/9500
# https://understat.com/match/9462
# https://understat.com/match/9517
# https://understat.com/match/9518
# https://understat.com/match/9507
# https://understat.com/match/9510
# https://understat.com/match/9514
# https://understat.com/match/9508
# https://understat.com/match/9516
# https://understat.com/match/9515
# https://understat.com/match/9513
# https://understat.com/match/9511
# https://understat.com/match/9509
# https://understat.com/match/9512
# https://understat.com/match/9503
# https://understat.com/match/9502
# https://understat.com/match/9498
# https://understat.com/match/9504
# https://understat.com/match/9506
# https://understat.com/match/9496
# https://understat.com/match/9494
# https://understat.com/match/9490
# https://understat.com/match/9489
# https://understat.com/match/9491
# https://understat.com/match/9488
# https://understat.com/match/9487
# https://understat.com/match/9492
# https://understat.com/match/9495
# https://understat.com/match/9493
# https://understat.com/match/9483
# https://understat.com/match/9482
# https://understat.com/match/9479
# https://understat.com/match/9478
# https://understat.com/match/9486
# https://understat.com/match/9485
# https://understat.com/match/9484
# https://understat.com/match/9481
# https://understat.com/match/9477
# https://understat.com/match/9480
# https://understat.com/match/9471
# https://understat.com/match/9475
# https://understat.com/match/9474
# https://understat.com/match/9476
# https://understat.com/match/9472
# https://understat.com/match/9470
# https://understat.com/match/9473
# https://understat.com/match/9469
# https://understat.com/match/9468
# https://understat.com/match/9467
# https://understat.com/match/9466
# https://understat.com/match/9459
# https://understat.com/match/9460
# https://understat.com/match/9458
# https://understat.com/match/9465
# https://understat.com/match/9464
# https://understat.com/match/9457
# https://understat.com/match/9463
# https://understat.com/match/9450
# https://understat.com/match/9454
# https://understat.com/match/9452
# https://understat.com/match/9449
# https://understat.com/match/9448
# https://understat.com/match/9451
# https://understat.com/match/9453
# https://understat.com/match/9455
# https://understat.com/match/9456
# https://understat.com/match/9447
# https://understat.com/match/9461
# https://understat.com/match/9437
# https://understat.com/match/9439
# https://understat.com/match/9440
# https://understat.com/match/9444
# https://understat.com/match/9445
# https://understat.com/match/9443
# https://understat.com/match/9441
# https://understat.com/match/9446
# https://understat.com/match/9442
# https://understat.com/match/9438
# https://understat.com/match/9435
# https://understat.com/match/9436
# https://understat.com/match/9433
# https://understat.com/match/9430
# https://understat.com/match/9434
# https://understat.com/match/9432
# https://understat.com/match/9431
# https://understat.com/match/9429
# https://understat.com/match/9428
# https://understat.com/match/9427
# https://understat.com/match/9424
# https://understat.com/match/9423
# https://understat.com/match/9426
# https://understat.com/match/9425
# https://understat.com/match/9422
# https://understat.com/match/9421
# https://understat.com/match/9420
# https://understat.com/match/9419
# https://understat.com/match/9418
# https://understat.com/match/9417
# https://understat.com/match/9409
# https://understat.com/match/9408
# https://understat.com/match/9411
# https://understat.com/match/9413
# https://understat.com/match/9415
# https://understat.com/match/9414
# https://understat.com/match/9412
# https://understat.com/match/9410
# https://understat.com/match/9416
# https://understat.com/match/9407
# https://understat.com/match/9400
# https://understat.com/match/9399
# https://understat.com/match/9403
# https://understat.com/match/9398
# https://understat.com/match/9397
# https://understat.com/match/9405
# https://understat.com/match/9401
# https://understat.com/match/9404
# https://understat.com/match/9406
# https://understat.com/match/9402
# https://understat.com/match/9390
# https://understat.com/match/9395
# https://understat.com/match/9389
# https://understat.com/match/9394
# https://understat.com/match/9391
# https://understat.com/match/9393
# https://understat.com/match/9388
# https://understat.com/match/9396
# https://understat.com/match/9392
# https://understat.com/match/9387
# https://understat.com/match/9379
# https://understat.com/match/9377
# https://understat.com/match/9386
# https://understat.com/match/9385
# https://understat.com/match/9384
# https://understat.com/match/9382
# https://understat.com/match/9381
# https://understat.com/match/9380
# https://understat.com/match/9378
# https://understat.com/match/9383
# https://understat.com/match/9372
# https://understat.com/match/9374
# https://understat.com/match/9375
# https://understat.com/match/9373
# https://understat.com/match/9371
# https://understat.com/match/9370
# https://understat.com/match/9369
# https://understat.com/match/9368
# https://understat.com/match/9376
# https://understat.com/match/9367
# https://understat.com/match/9362
# https://understat.com/match/9366
# https://understat.com/match/9360
# https://understat.com/match/9364
# https://understat.com/match/9365
# https://understat.com/match/9363
# https://understat.com/match/9359
# https://understat.com/match/9358
# https://understat.com/match/9357
# https://understat.com/match/9361
# https://understat.com/match/9351
# https://understat.com/match/9348
# https://understat.com/match/9350
# https://understat.com/match/9352
# https://understat.com/match/9356
# https://understat.com/match/9354
# https://understat.com/match/9353
# https://understat.com/match/9349
# https://understat.com/match/9347
# https://understat.com/match/9355
# https://understat.com/match/9346
# https://understat.com/match/9344
# https://understat.com/match/9343
# https://understat.com/match/9339
# https://understat.com/match/9345
# https://understat.com/match/9342
# https://understat.com/match/9341
# https://understat.com/match/9340
# https://understat.com/match/9338
# https://understat.com/match/9337
# https://understat.com/match/9330
# https://understat.com/match/9336
# https://understat.com/match/9334
# https://understat.com/match/9327
# https://understat.com/match/9329
# https://understat.com/match/9328
# https://understat.com/match/9331
# https://understat.com/match/9332
# https://understat.com/match/9333
# https://understat.com/match/9335
# https://understat.com/match/9326
# https://understat.com/match/9325
# https://understat.com/match/9324
# https://understat.com/match/9323
# https://understat.com/match/9320
# https://understat.com/match/9317
# https://understat.com/match/9318
# https://understat.com/match/9319
# https://understat.com/match/9322
# https://understat.com/match/9321
# https://understat.com/match/9316
# https://understat.com/match/9315
# https://understat.com/match/9314
# https://understat.com/match/9313
# https://understat.com/match/9312
# https://understat.com/match/9308
# https://understat.com/match/9309
# https://understat.com/match/9310
# https://understat.com/match/9311
# https://understat.com/match/9307
# https://understat.com/match/9306
# https://understat.com/match/9305
# https://understat.com/match/9300
# https://understat.com/match/9304
# https://understat.com/match/9303
# https://understat.com/match/9301
# https://understat.com/match/9299
# https://understat.com/match/9298
# https://understat.com/match/9302
# https://understat.com/match/9297
# https://understat.com/match/9296
# https://understat.com/match/9287
# https://understat.com/match/9294
# https://understat.com/match/9295
# https://understat.com/match/9293
# https://understat.com/match/9291
# https://understat.com/match/9290
# https://understat.com/match/9289
# https://understat.com/match/9288
# https://understat.com/match/9292
# https://understat.com/match/9286
# https://understat.com/match/9285
# https://understat.com/match/9284
# https://understat.com/match/9281
# https://understat.com/match/9280
# https://understat.com/match/9278
# https://understat.com/match/9279
# https://understat.com/match/9282
# https://understat.com/match/9283
# https://understat.com/match/9277
# https://understat.com/match/9276
# https://understat.com/match/9275
# https://understat.com/match/9274
# https://understat.com/match/9273
# https://understat.com/match/9268
# https://understat.com/match/9270
# https://understat.com/match/9269
# https://understat.com/match/9272
# https://understat.com/match/9271
# https://understat.com/match/9267
# https://understat.com/match/9266
# https://understat.com/match/9265
# https://understat.com/match/9264
# https://understat.com/match/9261
# https://understat.com/match/9258
# https://understat.com/match/9259
# https://understat.com/match/9260
# https://understat.com/match/9262
# https://understat.com/match/9263
# https://understat.com/match/9257
# https://understat.com/match/9256
# https://understat.com/match/9255
# https://understat.com/match/9254
# https://understat.com/match/9251
# https://understat.com/match/9249
# https://understat.com/match/9250
# https://understat.com/match/9248
# https://understat.com/match/9252
# https://understat.com/match/9253
# https://understat.com/match/9247
# https://understat.com/match/9246
# https://understat.com/match/9245
# https://understat.com/match/9244
# https://understat.com/match/9243
# https://understat.com/match/9242
# https://understat.com/match/9241
# https://understat.com/match/9240
# https://understat.com/match/9239
# https://understat.com/match/9238
# https://understat.com/match/9237
# https://understat.com/match/9232
# https://understat.com/match/9236
# https://understat.com/match/9235
# https://understat.com/match/9234
# https://understat.com/match/9233
# https://understat.com/match/9231
# https://understat.com/match/9230
# https://understat.com/match/9229
# https://understat.com/match/9228
# https://understat.com/match/9227
# https://understat.com/match/9226
# https://understat.com/match/9225
# https://understat.com/match/9224
# https://understat.com/match/9223
# https://understat.com/match/9222
# https://understat.com/match/9221
# https://understat.com/match/9220
# https://understat.com/match/9219
# https://understat.com/match/9218
# https://understat.com/match/9217
# https://understat.com/match/9216
# https://understat.com/match/9215
# https://understat.com/match/9213
# https://understat.com/match/9214
# https://understat.com/match/9212
# https://understat.com/match/9211
# https://understat.com/match/9210
# https://understat.com/match/9209
# https://understat.com/match/9208
# https://understat.com/match/9207
# https://understat.com/match/9206
# https://understat.com/match/9204
# https://understat.com/match/9205
# https://understat.com/match/9203
# https://understat.com/match/9201
# https://understat.com/match/9199
# https://understat.com/match/9202
# https://understat.com/match/9200
# https://understat.com/match/9198
# https://understat.com/match/9197
# https://understat.com/match/7498
# https://understat.com/match/7489
# https://understat.com/match/7497
# https://understat.com/match/7496
# https://understat.com/match/7495
# https://understat.com/match/7494
# https://understat.com/match/7493
# https://understat.com/match/7492
# https://understat.com/match/7491
# https://understat.com/match/7490
# https://understat.com/match/7428
# https://understat.com/match/7427
# https://understat.com/match/7424
# https://understat.com/match/7460
# https://understat.com/match/7422
# https://understat.com/match/7426
# https://understat.com/match/7487
# https://understat.com/match/7485
# https://understat.com/match/7480
# https://understat.com/match/7486
# https://understat.com/match/7482
# https://understat.com/match/7479
# https://understat.com/match/7483
# https://understat.com/match/7488
# https://understat.com/match/7481
# https://understat.com/match/7484
# https://understat.com/match/7477
# https://understat.com/match/7473
# https://understat.com/match/7478
# https://understat.com/match/7476
# https://understat.com/match/7470
# https://understat.com/match/7469
# https://understat.com/match/7471
# https://understat.com/match/7474
# https://understat.com/match/7475
# https://understat.com/match/7472
# https://understat.com/match/7461
# https://understat.com/match/7465
# https://understat.com/match/7466
# https://understat.com/match/7459
# https://understat.com/match/7467
# https://understat.com/match/7468
# https://understat.com/match/7464
# https://understat.com/match/7420
# https://understat.com/match/7463
# https://understat.com/match/7462
# https://understat.com/match/7458
# https://understat.com/match/7453
# https://understat.com/match/7454
# https://understat.com/match/7457
# https://understat.com/match/7452
# https://understat.com/match/7456
# https://understat.com/match/7451
# https://understat.com/match/7450
# https://understat.com/match/7449
# https://understat.com/match/7455
# https://understat.com/match/7442
# https://understat.com/match/7439
# https://understat.com/match/7445
# https://understat.com/match/7448
# https://understat.com/match/7447
# https://understat.com/match/7446
# https://understat.com/match/7444
# https://understat.com/match/7441
# https://understat.com/match/7440
# https://understat.com/match/7443
# https://understat.com/match/7431
# https://understat.com/match/7429
# https://understat.com/match/7433
# https://understat.com/match/7438
# https://understat.com/match/7437
# https://understat.com/match/7436
# https://understat.com/match/7435
# https://understat.com/match/7434
# https://understat.com/match/7430
# https://understat.com/match/7432
# https://understat.com/match/7423
# https://understat.com/match/7419
# https://understat.com/match/7421
# https://understat.com/match/7425
# https://understat.com/match/7416
# https://understat.com/match/7410
# https://understat.com/match/7409
# https://understat.com/match/7411
# https://understat.com/match/7412
# https://understat.com/match/7418
# https://understat.com/match/7417
# https://understat.com/match/7415
# https://understat.com/match/7413
# https://understat.com/match/7414
# https://understat.com/match/7401
# https://understat.com/match/7404
# https://understat.com/match/7399
# https://understat.com/match/7403
# https://understat.com/match/7408
# https://understat.com/match/7407
# https://understat.com/match/7406
# https://understat.com/match/7405
# https://understat.com/match/7402
# https://understat.com/match/7400
# https://understat.com/match/7389
# https://understat.com/match/7393
# https://understat.com/match/7397
# https://understat.com/match/7392
# https://understat.com/match/7394
# https://understat.com/match/7390
# https://understat.com/match/7391
# https://understat.com/match/7398
# https://understat.com/match/7395
# https://understat.com/match/7396
# https://understat.com/match/7379
# https://understat.com/match/7384
# https://understat.com/match/7383
# https://understat.com/match/7381
# https://understat.com/match/7382
# https://understat.com/match/7385
# https://understat.com/match/7380
# https://understat.com/match/7386
# https://understat.com/match/7388
# https://understat.com/match/7387
# https://understat.com/match/7377
# https://understat.com/match/7375
# https://understat.com/match/7373
# https://understat.com/match/7369
# https://understat.com/match/7370
# https://understat.com/match/7374
# https://understat.com/match/7371
# https://understat.com/match/7376
# https://understat.com/match/7378
# https://understat.com/match/7372
# https://understat.com/match/7368
# https://understat.com/match/7367
# https://understat.com/match/7366
# https://understat.com/match/7365
# https://understat.com/match/7364
# https://understat.com/match/7363
# https://understat.com/match/7362
# https://understat.com/match/7359
# https://understat.com/match/7360
# https://understat.com/match/7361
# https://understat.com/match/7357
# https://understat.com/match/7355
# https://understat.com/match/7354
# https://understat.com/match/7358
# https://understat.com/match/7356
# https://understat.com/match/7353
# https://understat.com/match/7352
# https://understat.com/match/7351
# https://understat.com/match/7349
# https://understat.com/match/7350
# https://understat.com/match/7344
# https://understat.com/match/7343
# https://understat.com/match/7339
# https://understat.com/match/7346
# https://understat.com/match/7340
# https://understat.com/match/7348
# https://understat.com/match/7347
# https://understat.com/match/7345
# https://understat.com/match/7342
# https://understat.com/match/7341
# https://understat.com/match/7326
# https://understat.com/match/7330
# https://understat.com/match/7335
# https://understat.com/match/7338
# https://understat.com/match/7336
# https://understat.com/match/7329
# https://understat.com/match/7333
# https://understat.com/match/7337
# https://understat.com/match/7334
# https://understat.com/match/7332
# https://understat.com/match/7331
# https://understat.com/match/7328
# https://understat.com/match/7321
# https://understat.com/match/7324
# https://understat.com/match/7327
# https://understat.com/match/7325
# https://understat.com/match/7323
# https://understat.com/match/7322
# https://understat.com/match/7320
# https://understat.com/match/7319
# https://understat.com/match/7311
# https://understat.com/match/7315
# https://understat.com/match/7313
# https://understat.com/match/7314
# https://understat.com/match/7312
# https://understat.com/match/7309
# https://understat.com/match/7317
# https://understat.com/match/7318
# https://understat.com/match/7310
# https://understat.com/match/7316
# https://understat.com/match/7302
# https://understat.com/match/7304
# https://understat.com/match/7308
# https://understat.com/match/7307
# https://understat.com/match/7306
# https://understat.com/match/7305
# https://understat.com/match/7300
# https://understat.com/match/7299
# https://understat.com/match/7303
# https://understat.com/match/7301
# https://understat.com/match/7293
# https://understat.com/match/7290
# https://understat.com/match/7295
# https://understat.com/match/7298
# https://understat.com/match/7297
# https://understat.com/match/7296
# https://understat.com/match/7292
# https://understat.com/match/7291
# https://understat.com/match/7289
# https://understat.com/match/7294
# https://understat.com/match/7287
# https://understat.com/match/7283
# https://understat.com/match/7286
# https://understat.com/match/7288
# https://understat.com/match/7285
# https://understat.com/match/7284
# https://understat.com/match/7281
# https://understat.com/match/7282
# https://understat.com/match/7280
# https://understat.com/match/7279
# https://understat.com/match/7276
# https://understat.com/match/7275
# https://understat.com/match/7278
# https://understat.com/match/7277
# https://understat.com/match/7274
# https://understat.com/match/7273
# https://understat.com/match/7272
# https://understat.com/match/7271
# https://understat.com/match/7270
# https://understat.com/match/7269
# https://understat.com/match/7262
# https://understat.com/match/7267
# https://understat.com/match/7266
# https://understat.com/match/7260
# https://understat.com/match/7263
# https://understat.com/match/7261
# https://understat.com/match/7264
# https://understat.com/match/7268
# https://understat.com/match/7265
# https://understat.com/match/7259
# https://understat.com/match/7258
# https://understat.com/match/7257
# https://understat.com/match/7256
# https://understat.com/match/7253
# https://understat.com/match/7255
# https://understat.com/match/7254
# https://understat.com/match/7252
# https://understat.com/match/7251
# https://understat.com/match/7250
# https://understat.com/match/7249
# https://understat.com/match/7245
# https://understat.com/match/7248
# https://understat.com/match/7241
# https://understat.com/match/7244
# https://understat.com/match/7243
# https://understat.com/match/7242
# https://understat.com/match/7239
# https://understat.com/match/7246
# https://understat.com/match/7240
# https://understat.com/match/7247
# https://understat.com/match/7238
# https://understat.com/match/7230
# https://understat.com/match/7232
# https://understat.com/match/7229
# https://understat.com/match/7237
# https://understat.com/match/7235
# https://understat.com/match/7234
# https://understat.com/match/7233
# https://understat.com/match/7231
# https://understat.com/match/7236
# https://understat.com/match/7220
# https://understat.com/match/7219
# https://understat.com/match/7228
# https://understat.com/match/7226
# https://understat.com/match/7227
# https://understat.com/match/7221
# https://understat.com/match/7225
# https://understat.com/match/7223
# https://understat.com/match/7222
# https://understat.com/match/7224
# https://understat.com/match/7212
# https://understat.com/match/7214
# https://understat.com/match/7211
# https://understat.com/match/7210
# https://understat.com/match/7209
# https://understat.com/match/7215
# https://understat.com/match/7213
# https://understat.com/match/7217
# https://understat.com/match/7216
# https://understat.com/match/7218
# https://understat.com/match/7207
# https://understat.com/match/7200
# https://understat.com/match/7199
# https://understat.com/match/7204
# https://understat.com/match/7203
# https://understat.com/match/7201
# https://understat.com/match/7202
# https://understat.com/match/7205
# https://understat.com/match/7206
# https://understat.com/match/7208
# https://understat.com/match/7192
# https://understat.com/match/7195
# https://understat.com/match/7189
# https://understat.com/match/7198
# https://understat.com/match/7190
# https://understat.com/match/7197
# https://understat.com/match/7196
# https://understat.com/match/7194
# https://understat.com/match/7191
# https://understat.com/match/7193
# https://understat.com/match/7188
# https://understat.com/match/7187
# https://understat.com/match/7186
# https://understat.com/match/7185
# https://understat.com/match/7184
# https://understat.com/match/7183
# https://understat.com/match/7182
# https://understat.com/match/7181
# https://understat.com/match/7180
# https://understat.com/match/7179
# https://understat.com/match/7178
# https://understat.com/match/7177
# https://understat.com/match/7176
# https://understat.com/match/7175
# https://understat.com/match/7174
# https://understat.com/match/7173
# https://understat.com/match/7172
# https://understat.com/match/7171
# https://understat.com/match/7170
# https://understat.com/match/7169
# https://understat.com/match/7168
# https://understat.com/match/7167
# https://understat.com/match/7166
# https://understat.com/match/7165
# https://understat.com/match/7164
# https://understat.com/match/7163
# https://understat.com/match/7162
# https://understat.com/match/7161
# https://understat.com/match/7160
# https://understat.com/match/7159
# https://understat.com/match/7158
# https://understat.com/match/7157
# https://understat.com/match/7156
# https://understat.com/match/7155
# https://understat.com/match/7154
# https://understat.com/match/7153
# https://understat.com/match/7152
# https://understat.com/match/7151
# https://understat.com/match/7150
# https://understat.com/match/7149
# https://understat.com/match/7147
# https://understat.com/match/7148
# https://understat.com/match/7140
# https://understat.com/match/7146
# https://understat.com/match/7145
# https://understat.com/match/7143
# https://understat.com/match/7142
# https://understat.com/match/7141
# https://understat.com/match/7144
# https://understat.com/match/7139
# https://understat.com/match/7138
# https://understat.com/match/7137
# https://understat.com/match/7136
# https://understat.com/match/7135
# https://understat.com/match/7132
# https://understat.com/match/7130
# https://understat.com/match/7131
# https://understat.com/match/7134
# https://understat.com/match/7133
# https://understat.com/match/7129
# https://understat.com/match/7128
# https://understat.com/match/7127
# https://understat.com/match/7126
# https://understat.com/match/7124
# https://understat.com/match/7123
# https://understat.com/match/7121
# https://understat.com/match/7125
# https://understat.com/match/7122
# https://understat.com/match/7120
# https://understat.com/match/7119
# https://understat.com/match/3519
# https://understat.com/match/3514
# https://understat.com/match/3511
# https://understat.com/match/3512
# https://understat.com/match/3513
# https://understat.com/match/3510
# https://understat.com/match/3515
# https://understat.com/match/3516
# https://understat.com/match/3517
# https://understat.com/match/3518
# https://understat.com/match/3475
# https://understat.com/match/3412
# https://understat.com/match/3477
# https://understat.com/match/3470
# https://understat.com/match/3414
# https://understat.com/match/3507
# https://understat.com/match/3509
# https://understat.com/match/3501
# https://understat.com/match/3505
# https://understat.com/match/3504
# https://understat.com/match/3500
# https://understat.com/match/3506
# https://understat.com/match/3503
# https://understat.com/match/3508
# https://understat.com/match/3502
# https://understat.com/match/3390
# https://understat.com/match/3493
# https://understat.com/match/3490
# https://understat.com/match/3496
# https://understat.com/match/3498
# https://understat.com/match/3492
# https://understat.com/match/3491
# https://understat.com/match/3494
# https://understat.com/match/3495
# https://understat.com/match/3497
# https://understat.com/match/3499
# https://understat.com/match/3488
# https://understat.com/match/3487
# ...
# https://understat.com/match/188
# https://understat.com/match/187
# https://understat.com/match/186
# https://understat.com/match/185
# https://understat.com/match/184
# https://understat.com/match/183
# https://understat.com/match/182
# https://understat.com/match/181
# https://understat.com/match/180
# https://understat.com/match/179
# https://understat.com/match/178
# https://understat.com/match/177
# https://understat.com/match/176
# https://understat.com/match/174
# https://understat.com/match/173
# https://understat.com/match/172
# https://understat.com/match/171
# https://understat.com/match/175
# https://understat.com/match/170
# https://understat.com/match/169
# https://understat.com/match/168
# https://understat.com/match/165
# https://understat.com/match/164
# https://understat.com/match/162
# https://understat.com/match/163
# https://understat.com/match/166
# https://understat.com/match/167
# https://understat.com/match/161
# https://understat.com/match/160
# https://understat.com/match/159
# https://understat.com/match/158
# https://understat.com/match/157
# https://understat.com/match/152
# https://understat.com/match/154
# https://understat.com/match/153
# https://understat.com/match/156
# https://understat.com/match/155
# https://understat.com/match/151
# https://understat.com/match/150
# https://understat.com/match/149
# https://understat.com/match/148
# https://understat.com/match/145
# https://understat.com/match/142
# https://understat.com/match/143
# https://understat.com/match/144
# https://understat.com/match/146
# https://understat.com/match/147
# https://understat.com/match/141
# https://understat.com/match/140
# https://understat.com/match/139
# https://understat.com/match/138
# https://understat.com/match/137
# https://understat.com/match/134
# https://understat.com/match/133
# https://understat.com/match/132
# https://understat.com/match/135
# https://understat.com/match/136
# https://understat.com/match/131
# https://understat.com/match/130
# https://understat.com/match/129
# https://understat.com/match/128
# https://understat.com/match/127
# https://understat.com/match/126
# https://understat.com/match/125
# https://understat.com/match/124
# https://understat.com/match/123
# https://understat.com/match/122
# https://understat.com/match/121
# https://understat.com/match/120
# https://understat.com/match/119
# https://understat.com/match/118
# https://understat.com/match/117
# https://understat.com/match/116
# https://understat.com/match/115
# https://understat.com/match/114
# https://understat.com/match/113
# https://understat.com/match/112
# https://understat.com/match/111
# https://understat.com/match/110
# https://understat.com/match/108
# https://understat.com/match/109
# https://understat.com/match/107
# https://understat.com/match/106
# https://understat.com/match/105
# https://understat.com/match/104
# https://understat.com/match/103
# https://understat.com/match/102
# https://understat.com/match/101
# https://understat.com/match/100
# https://understat.com/match/99
# https://understat.com/match/98
# https://understat.com/match/97
# https://understat.com/match/96
# https://understat.com/match/95
# https://understat.com/match/94
# https://understat.com/match/93
# https://understat.com/match/92
# https://understat.com/match/91
# https://understat.com/match/90
# https://understat.com/match/89
# https://understat.com/match/88
# https://understat.com/match/87
# https://understat.com/match/86
# https://understat.com/match/84
# https://understat.com/match/83
# https://understat.com/match/82
# https://understat.com/match/85
# https://understat.com/match/81
# https://understat.com/match/4439
# https://understat.com/match/4434
# https://understat.com/match/4431
# https://understat.com/match/4432
# https://understat.com/match/4433
# https://understat.com/match/4430
# https://understat.com/match/4435
# https://understat.com/match/4436
# https://understat.com/match/4437
# https://understat.com/match/4438
# https://understat.com/match/4429
# https://understat.com/match/4428
# https://understat.com/match/4427
# https://understat.com/match/4426
# https://understat.com/match/4425
# https://understat.com/match/4424
# https://understat.com/match/4423
# https://understat.com/match/4422
# https://understat.com/match/4421
# https://understat.com/match/4420
# https://understat.com/match/4419
# https://understat.com/match/4418
# https://understat.com/match/4417
# https://understat.com/match/4416
# https://understat.com/match/4415
# https://understat.com/match/4414
# https://understat.com/match/4413
# https://understat.com/match/4412
# https://understat.com/match/4411
# https://understat.com/match/4410
# https://understat.com/match/4409
# https://understat.com/match/4408
# https://understat.com/match/4407
# https://understat.com/match/4406
# https://understat.com/match/4405
# https://understat.com/match/4404
# https://understat.com/match/4403
# https://understat.com/match/4402
# https://understat.com/match/4401
# https://understat.com/match/4400
# https://understat.com/match/4399
# https://understat.com/match/4479
# https://understat.com/match/4478
# https://understat.com/match/4477
# https://understat.com/match/4476
# https://understat.com/match/4475
# https://understat.com/match/4474
# https://understat.com/match/4473
# https://understat.com/match/4472
# https://understat.com/match/4471
# https://understat.com/match/4470
# https://understat.com/match/4469
# https://understat.com/match/4468
# https://understat.com/match/4467
# https://understat.com/match/4466
# https://understat.com/match/4465
# https://understat.com/match/4464
# https://understat.com/match/4463
# https://understat.com/match/4462
# https://understat.com/match/4461
# https://understat.com/match/4460
# https://understat.com/match/4459
# https://understat.com/match/4458
# https://understat.com/match/4457
# https://understat.com/match/4454
# https://understat.com/match/4452
# https://understat.com/match/4453
# https://understat.com/match/4455
# https://understat.com/match/4456
# https://understat.com/match/4451
# https://understat.com/match/4450
# https://understat.com/match/4449
# https://understat.com/match/4448
# https://understat.com/match/4447
# https://understat.com/match/4446
# https://understat.com/match/4443
# https://understat.com/match/4441
# https://understat.com/match/4442
# https://understat.com/match/4444
# https://understat.com/match/4445
# https://understat.com/match/4440
# https://understat.com/match/4512
# https://understat.com/match/4511
# https://understat.com/match/4510
# https://understat.com/match/4509
# https://understat.com/match/4508
# https://understat.com/match/4507
# https://understat.com/match/4506
# https://understat.com/match/4505
# https://understat.com/match/4504
# https://understat.com/match/4503
# https://understat.com/match/4502
# https://understat.com/match/4501
# https://understat.com/match/4500
# https://understat.com/match/4499
# https://understat.com/match/4498
# https://understat.com/match/4497
# https://understat.com/match/4496
# https://understat.com/match/4495
# https://understat.com/match/4494
# https://understat.com/match/4493
# https://understat.com/match/4492
# https://understat.com/match/4491
# https://understat.com/match/4487
# https://understat.com/match/4485
# https://understat.com/match/4486
# https://understat.com/match/4489
# https://understat.com/match/4488
# https://understat.com/match/4490
# https://understat.com/match/4484
# https://understat.com/match/4483
# https://understat.com/match/4482
# https://understat.com/match/4481
# https://understat.com/match/4480
# https://understat.com/match/4547
# https://understat.com/match/4546
# https://understat.com/match/4548
# https://understat.com/match/4549
# https://understat.com/match/4550
# https://understat.com/match/4545
# https://understat.com/match/4544
# https://understat.com/match/4543
# https://understat.com/match/4542
# https://understat.com/match/4541
# https://understat.com/match/4537
# https://understat.com/match/4535
# https://understat.com/match/4536
# https://understat.com/match/4538
# https://understat.com/match/4539
# https://understat.com/match/4540
# https://understat.com/match/4534
# https://understat.com/match/4533
# https://understat.com/match/4532
# https://understat.com/match/4531
# https://understat.com/match/4530
# https://understat.com/match/4529
# https://understat.com/match/4528
# https://understat.com/match/4527
# https://understat.com/match/4525
# https://understat.com/match/4526
# https://understat.com/match/4524
# https://understat.com/match/4523
# https://understat.com/match/4522
# https://understat.com/match/4521
# https://understat.com/match/4520
# https://understat.com/match/4519
# https://understat.com/match/4518
# https://understat.com/match/4517
# https://understat.com/match/4516
# https://understat.com/match/4515
# https://understat.com/match/4514
# https://understat.com/match/4513
# https://understat.com/match/4588
# https://understat.com/match/4582
# https://understat.com/match/4587
# https://understat.com/match/4586
# https://understat.com/match/4585
# https://understat.com/match/4584
# https://understat.com/match/4583
# https://understat.com/match/4581
# https://understat.com/match/4580
# https://understat.com/match/4579
# https://understat.com/match/4578
# https://understat.com/match/4577
# https://understat.com/match/4576
# https://understat.com/match/4575
# https://understat.com/match/4574
# https://understat.com/match/4573
# https://understat.com/match/4572
# https://understat.com/match/4571
# https://understat.com/match/4570
# https://understat.com/match/4569
# https://understat.com/match/4568
# https://understat.com/match/4567
# https://understat.com/match/4566
# https://understat.com/match/4565
# https://understat.com/match/4564
# https://understat.com/match/4563
# https://understat.com/match/4562
# https://understat.com/match/4561
# https://understat.com/match/4560
# https://understat.com/match/4554
# https://understat.com/match/4556
# https://understat.com/match/4555
# https://understat.com/match/4552
# https://understat.com/match/4557
# https://understat.com/match/4558
# https://understat.com/match/4559
# https://understat.com/match/4553
# https://understat.com/match/4551
# https://understat.com/match/4648
# https://understat.com/match/4647
# https://understat.com/match/4646
# https://understat.com/match/4645
# https://understat.com/match/4644
# https://understat.com/match/4643
# https://understat.com/match/4642
# https://understat.com/match/4641
# https://understat.com/match/4640
# https://understat.com/match/4639
# https://understat.com/match/4638
# https://understat.com/match/4637
# https://understat.com/match/4636
# https://understat.com/match/4635
# https://understat.com/match/4634
# https://understat.com/match/4633
# https://understat.com/match/4632
# https://understat.com/match/4631
# https://understat.com/match/4630
# https://understat.com/match/4629
# https://understat.com/match/4628
# https://understat.com/match/4627
# https://understat.com/match/4626
# https://understat.com/match/4625
# https://understat.com/match/4624
# https://understat.com/match/4623
# https://understat.com/match/4622
# https://understat.com/match/4621
# https://understat.com/match/4620
# https://understat.com/match/4619
# https://understat.com/match/4618
# https://understat.com/match/4617
# https://understat.com/match/4616
# https://understat.com/match/4615
# https://understat.com/match/4614
# https://understat.com/match/4613
# https://understat.com/match/4612
# https://understat.com/match/4611
# https://understat.com/match/4610
# https://understat.com/match/4609
# https://understat.com/match/4608
# https://understat.com/match/4607
# https://understat.com/match/4606
# https://understat.com/match/4605
# https://understat.com/match/4602
# https://understat.com/match/4600
# https://understat.com/match/4601
# https://understat.com/match/4603
# https://understat.com/match/4604
# https://understat.com/match/4599
# https://understat.com/match/4598
# https://understat.com/match/4597
# https://understat.com/match/4596
# https://understat.com/match/4595
# https://understat.com/match/4594
# https://understat.com/match/4593
# https://understat.com/match/4590
# https://understat.com/match/4589
# https://understat.com/match/4591
# https://understat.com/match/4592
# https://understat.com/match/4688
# https://understat.com/match/4687
# https://understat.com/match/4686
# https://understat.com/match/4685
# https://understat.com/match/4684
# https://understat.com/match/4683
# https://understat.com/match/4682
# https://understat.com/match/4681
# https://understat.com/match/4680
# https://understat.com/match/4679
# https://understat.com/match/4678
# https://understat.com/match/4677
# https://understat.com/match/4676
# https://understat.com/match/4675
# https://understat.com/match/4674
# https://understat.com/match/4673
# https://understat.com/match/4672
# https://understat.com/match/4671
# https://understat.com/match/4670
# https://understat.com/match/4669
# https://understat.com/match/4668
# https://understat.com/match/4665
# https://understat.com/match/4666
# https://understat.com/match/4667
# https://understat.com/match/4664
# https://understat.com/match/4663
# https://understat.com/match/4662
# https://understat.com/match/4661
# https://understat.com/match/4660
# https://understat.com/match/4659
# https://understat.com/match/4658
# https://understat.com/match/4657
# https://understat.com/match/4656
# https://understat.com/match/4650
# https://understat.com/match/4651
# https://understat.com/match/4652
# https://understat.com/match/4654
# https://understat.com/match/4653
# https://understat.com/match/4655
# https://understat.com/match/4649
# https://understat.com/match/4718
# https://understat.com/match/4717
# https://understat.com/match/4716
# https://understat.com/match/4715
# https://understat.com/match/4714
# https://understat.com/match/4711
# https://understat.com/match/4710
# https://understat.com/match/4713
# https://understat.com/match/4712
# https://understat.com/match/4709
# https://understat.com/match/4708
# https://understat.com/match/4707
# https://understat.com/match/4706
# https://understat.com/match/4703
# https://understat.com/match/4701
# https://understat.com/match/4702
# https://understat.com/match/4700
# https://understat.com/match/4704
# https://understat.com/match/4705
# https://understat.com/match/4699
# https://understat.com/match/4698
# https://understat.com/match/4697
# https://understat.com/match/4696
# https://understat.com/match/4695
# https://understat.com/match/4694
# https://understat.com/match/4691
# https://understat.com/match/4689
# https://understat.com/match/4690
# https://understat.com/match/4692
# https://understat.com/match/4693
# https://understat.com/match/4748
# https://understat.com/match/4747
# https://understat.com/match/4746
# https://understat.com/match/4745
# https://understat.com/match/4744
# https://understat.com/match/4743
# https://understat.com/match/4742
# https://understat.com/match/4741
# https://understat.com/match/4740
# https://understat.com/match/4739
# https://understat.com/match/4737
# https://understat.com/match/4738
# https://understat.com/match/4736
# https://understat.com/match/4735
# https://understat.com/match/4734
# https://understat.com/match/4733
# https://understat.com/match/4732
# https://understat.com/match/4731
# https://understat.com/match/4730
# https://understat.com/match/4729
# https://understat.com/match/4728
# https://understat.com/match/4727
# https://understat.com/match/4726
# https://understat.com/match/4725
# https://understat.com/match/4724
# https://understat.com/match/4723
# https://understat.com/match/4722
# https://understat.com/match/4721
# https://understat.com/match/4720
# https://understat.com/match/4719
# https://understat.com/match/4778
# https://understat.com/match/4776
# https://understat.com/match/4777
# https://understat.com/match/4775
# https://understat.com/match/4774
# https://understat.com/match/4773
# https://understat.com/match/4772
# https://understat.com/match/4771
# https://understat.com/match/4770
# https://understat.com/match/4769
# https://understat.com/match/4768
# https://understat.com/match/4767
# https://understat.com/match/4765
# https://understat.com/match/4766
# https://understat.com/match/4764
# https://understat.com/match/4763
# https://understat.com/match/4762
# https://understat.com/match/4761
# https://understat.com/match/4760
# https://understat.com/match/4759
# https://understat.com/match/4758
# https://understat.com/match/4757
# https://understat.com/match/4756
# https://understat.com/match/4755
# https://understat.com/match/4752
# https://understat.com/match/4751
# https://understat.com/match/4750
# https://understat.com/match/4753
# https://understat.com/match/4754
# https://understat.com/match/4749

# %%
merged_df = pd.concat(dfs)
merged_df
# Out:
#         id minute       result                   X                    Y  \
# 0   418051      7  BlockedShot  0.7980000305175782   0.5890000152587891
# 1   418052      8         Goal               0.885                  0.5
# 2   418056     28    SavedShot  0.7759999847412109    0.649000015258789
# 3   418057     30  MissedShots  0.9630000305175781                0.395
# 4   418058     32    SavedShot  0.8180000305175781   0.7419999694824219
# ..     ...    ...          ...                 ...                  ...
# 0    14510     11    SavedShot  0.7619999694824219   0.3160000038146973
# 1    14515     27         Goal                0.82   0.5420000076293945
# 2    14519     50    SavedShot  0.7180000305175781  0.48900001525878906
# 3    14524     71         Goal  0.9219999694824219   0.5259999847412109
# 4    14525     77  BlockedShot  0.7659999847412109                 0.66
#
#                       xG            player h_a player_id situation  ...  \
# 0    0.03415979817509651    Anwar El Ghazi   h      5612  OpenPlay  ...
# 1     0.7611688375473022    Anwar El Ghazi   h      5612   Penalty  ...
# 2    0.02307983487844467    Anwar El Ghazi   h      5612  OpenPlay  ...
# 3    0.07580874860286713   Bertrand Traoré   h       695  OpenPlay  ...
# 4   0.024960270151495934      Ross Barkley   h       592  OpenPlay  ...
# ..                   ...               ...  ..       ...       ...  ...
# 0   0.020646924152970314  Gylfi Sigurdsson   a       714  OpenPlay  ...
# 1    0.06372921168804169     Ki Sung-yueng   a       723  OpenPlay  ...
# 2   0.021781764924526215     Wilfried Bony   a       622  OpenPlay  ...
# 3    0.14339357614517212  Gylfi Sigurdsson   a       714  OpenPlay  ...
# 4   0.028524409979581833   Bafétimbi Gomis   a       717  OpenPlay  ...
#
#    match_id             h_team                a_team h_goals a_goals  \
# 0     14756        Aston Villa  West Bromwich Albion       2       2
# 1     14756        Aston Villa  West Bromwich Albion       2       2
# 2     14756        Aston Villa  West Bromwich Albion       2       2
# 3     14756        Aston Villa  West Bromwich Albion       2       2
# 4     14756        Aston Villa  West Bromwich Albion       2       2
# ..      ...                ...                   ...     ...     ...
# 0      4749  Manchester United               Swansea       1       2
# 1      4749  Manchester United               Swansea       1       2
# 2      4749  Manchester United               Swansea       1       2
# 3      4749  Manchester United               Swansea       1       2
# 4      4749  Manchester United               Swansea       1       2
#
#                    date   player_assisted    lastAction league HomeAway
# 0   2021-04-25 18:00:00   Bertrand Traoré          Pass    EPL     Home
# 1   2021-04-25 18:00:00              None      Standard    EPL     Home
# 2   2021-04-25 18:00:00       John McGinn          Pass    EPL     Home
# 3   2021-04-25 18:00:00      Matt Targett         Cross    EPL     Home
# 4   2021-04-25 18:00:00      Matt Targett          Pass    EPL     Home
# ..                  ...               ...           ...    ...      ...
# 0   2014-08-16 12:45:00      Angel Rangel          Pass    EPL     Away
# 1   2014-08-16 12:45:00  Gylfi Sigurdsson          Pass    EPL     Away
# 2   2014-08-16 12:45:00   Wayne Routledge          Pass    EPL     Away
# 3   2014-08-16 12:45:00   Wayne Routledge          Pass    EPL     Away
# 4   2014-08-16 12:45:00   Ashley Williams  BallRecovery    EPL     Away
#
# [65662 rows x 22 columns]

# %%
merged_df.to_csv('dfs/shots/shots.csv', index=False)

# %%
del dfs

# %%
from tqdm.auto import tqdm

base_url = 'https://understat.com/match/'

dfs = []

for _, row in tqdm(matches_df.iterrows()):
    if row['isResult'] == True:
        match_id = row['id']
        url = base_url + str(match_id)

        #Use requests to get the webpage and BeautifulSoup to parse the page
        res = get_page(url)
        soup = BeautifulSoup(res, 'lxml')
        scripts = soup.find_all('script')

        #get only the shotsData
        strings = scripts[2].string
        # strip unnecessary symbols and get only JSON data 
        ind_start = strings.index("('")+2 
        ind_end = strings.index("')") 
        json_data = strings[ind_start:ind_end] 
        json_data = json_data.encode('utf8').decode('unicode_escape')

        #convert string to json format
        data = json.loads(json_data)
        data_home = data['h']
        data_away = data['a']
        
        data_home = [data_home[key] for key in data_home]
        data_away = [data_away[key] for key in data_away]

        df_h = pd.DataFrame(data_home)
        df_h['season'] = row['season']
        df_h['league'] = row['league']
        df_h['match_id'] = row['id']
        df_h['HomeAway'] = 'Home'

        df_a = pd.DataFrame(data_away)
        df_a['season'] = row['season']
        df_a['league'] = row['league']
        df_a['match_id'] = row['id']
        df_a['HomeAway'] = 'Away'

        df = pd.concat([df_h, df_a])

        dfs.append(df)
# Out:
# 0it [00:00, ?it/s]

# %%
roster_df = pd.concat(dfs)
roster_df
# Out:
#         id goals own_goals shots                    xG time player_id team_id  \
# 0   466340     0         0     0                     0   90      4401      71
# 1   466341     0         0     2    0.0507240854203701   90      1685      71
# 2   466342     0         0     3   0.10185212641954422   90      7726      71
# 3   466343     0         1     1   0.08413901180028915   90      1024      71
# 4   466344     0         0     0                     0   90       884      71
# ..     ...   ...       ...   ...                   ...  ...       ...     ...
# 9    17156     0         0     0                     0   90       719      84
# 10   17157     0         0     1  0.021781764924526215   80       622      84
# 11   17160     0         0     0                     0   34      4448      84
# 12   17158     0         0     0                     0   20       715      84
# 13   17159     0         0     1  0.028524409979581833   10       717      84
#
#    position             player  ... key_passes assists                   xA  \
# 0        GK  Emiliano Martinez  ...          0       0                    0
# 1        DR   Ahmed Elmohamady  ...          3       0  0.06234762817621231
# 2        DC   Ezri Konsa Ngoyo  ...          0       0                    0
# 3        DC       Tyrone Mings  ...          1       0  0.13328632712364197
# 4        DL       Matt Targett  ...          4       0   0.1633511483669281
# ..      ...                ...  ...        ...     ...                  ...
# 9       AML    Wayne Routledge  ...          2       1  0.16517533361911774
# 10       FW      Wilfried Bony  ...          0       0                    0
# 11      Sub   Dwight Tiendalli  ...          0       0                    0
# 12      Sub  Jefferson Montero  ...          0       0                    0
# 13      Sub    Bafétimbi Gomis  ...          0       0                    0
#
#                  xGChain            xGBuildup positionOrder     season league  \
# 0    0.19965820014476776  0.19965820014476776             1  2020-2021    EPL
# 1     0.3797950744628906  0.30373573303222656             2  2020-2021    EPL
# 2    0.03415979817509651  0.03415979817509651             3  2020-2021    EPL
# 3    0.40749111771583557  0.40749111771583557             3  2020-2021    EPL
# 4    0.29705607891082764  0.19628706574440002             4  2020-2021    EPL
# ..                   ...                  ...           ...        ...    ...
# 9    0.22890454530715942  0.06372921168804169            13  2014-2015    EPL
# 10   0.22890454530715942   0.2071227878332138            15  2014-2015    EPL
# 11                     0                    0            17  2014-2015    EPL
# 12   0.14339357614517212  0.14339357614517212            17  2014-2015    EPL
# 13  0.028524409979581833                    0            17  2014-2015    EPL
#
#    match_id HomeAway
# 0     14756     Home
# 1     14756     Home
# 2     14756     Home
# 3     14756     Home
# 4     14756     Home
# ..      ...      ...
# 9      4749     Away
# 10     4749     Away
# 11     4749     Away
# 12     4749     Away
# 13     4749     Away
#
# [71854 rows x 25 columns]

# %%
roster_df.to_csv('dfs/rosters/rosters.csv', index=False)
