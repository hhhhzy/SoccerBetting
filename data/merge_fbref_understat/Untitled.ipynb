# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2014-2015/player_rk_1.csv')
# Out:
#        Season        Date  Day            Comp         Round Venue Result  \
# 0   2014-2015  2014-08-16  Sat  Premier League   Matchweek 1  Away  D 2–2
# 1   2014-2015  2014-08-24  Sun  Premier League   Matchweek 2  Home  D 1–1
# 2   2014-2015  2014-08-27  Wed      League Cup  Second round  Away  W 3–0
# 3   2014-2015  2014-08-30  Sat  Premier League   Matchweek 3  Away  L 0–1
# 4   2014-2015  2014-09-13  Sat  Premier League   Matchweek 4  Home  D 2–2
# 5   2014-2015  2014-09-20  Sat  Premier League   Matchweek 5  Away  D 0–0
# 6   2014-2015  2014-09-23  Tue      League Cup   Third round  Home  L 1–2
# 7   2014-2015  2014-09-27  Sat  Premier League   Matchweek 6  Home  D 0–0
# 8   2014-2015  2014-10-04  Sat  Premier League   Matchweek 7  Home  W 3–1
# 9   2014-2015  2014-10-18  Sat  Premier League   Matchweek 8  Away  L 0–8
# 10  2014-2015  2014-10-25  Sat  Premier League   Matchweek 9  Home  L 0–2
# 11  2014-2015  2014-11-03  Mon  Premier League  Matchweek 10  Away  W 3–1
# ...

# %%
pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2015-2016/player_rk_1.csv')
# Out:
#        Season        Date  Day            Comp           Round Venue Result  \
# 0   2015-2016  2015-08-08  Sat  Premier League     Matchweek 1  Away  L 2–4
# 1   2015-2016  2015-08-15  Sat  Premier League     Matchweek 2  Home  L 1–3
# 2   2015-2016  2015-08-22  Sat  Premier League     Matchweek 3  Home  D 1–1
# 3   2015-2016  2015-08-25  Tue      League Cup    Second round  Home  W 6–3
# 4   2015-2016  2015-08-29  Sat  Premier League     Matchweek 4  Away  D 2–2
# 5   2015-2016  2015-09-13  Sun  Premier League     Matchweek 5  Home  L 0–1
# 6   2015-2016  2015-09-19  Sat  Premier League     Matchweek 6  Away  L 0–2
# 7   2015-2016  2015-09-22  Tue      League Cup     Third round  Home  L 1–4
# 8   2015-2016  2015-09-26  Sat  Premier League     Matchweek 7  Away  L 0–3
# 9   2015-2016  2015-10-03  Sat  Premier League     Matchweek 8  Home  D 2–2
# 10  2015-2016  2015-10-17  Sat  Premier League     Matchweek 9  Away  L 0–1
# ...

# %%
pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2016-2017/player_rk_1.csv')
# Out:
#        Season        Date  Day            Comp           Round Venue Result  \
# 0   2016-2017  2016-08-13  Sat  Premier League     Matchweek 1  Away  L 1–2
# 1   2016-2017  2016-08-21  Sun  Premier League     Matchweek 2  Home  L 1–2
# 2   2016-2017  2016-08-24  Wed         EFL Cup    Second round  Home  W 1–0
# 3   2016-2017  2016-08-27  Sat  Premier League     Matchweek 3  Away  D 1–1
# 4   2016-2017  2016-09-01  Thu  Friendlies (M)  Friendlies (M)  Home  L 1–2
# 5   2016-2017  2016-09-06  Tue  WCQ — UEFA (M)     First round  Away  D 1–1
# 6   2016-2017  2016-09-12  Mon  Premier League     Matchweek 4  Home  L 0–3
# 7   2016-2017  2016-09-21  Wed         EFL Cup     Third round  Away  W 2–1
# 8   2016-2017  2016-09-24  Sat  Premier League     Matchweek 6  Home  L 2–3
# 9   2016-2017  2016-10-01  Sat  Premier League     Matchweek 7  Home  D 1–1
# 10  2016-2017  2016-10-15  Sat  Premier League     Matchweek 8  Away  L 0–2
# ...

# %%
df_17 = pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2017-2018/player_rk_1.csv')

# %%
df_16 = pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2016-2017/player_rk_1.csv')

# %%
df_14 = pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2014-2015/player_rk_1.csv')

# %%
df_19 = pd.read_csv('../fbref_scraper/dfs/EPL/players_matches/2019-2020/player_rk_1.csv')

# %%
set(df_16.columns) - set(df_17.columns)
# Out:
# {'Crs', 'Fld', 'Fls', 'OG', 'Off', 'PKcon', 'PKwon', 'TklW'}

# %%
set(df_17.columns) - set(df_16.columns)
# Out:
# {'Att_2_Dribbles',
#  'Att_Passes',
#  'Blocks',
#  'Carries',
#  'Cmp',
#  'Cmp%',
#  'GCA',
#  'Press',
#  'Prog_2_Carries',
#  'Prog_Passes',
#  'SCA',
#  'Succ',
#  'Tkl',
#  'Touches',
#  'npxG',
#  'xA',
#  'xG'}

# %%
set(df_17.columns).intersection(set(df_16.columns))
# Out:
# {'Ast',
#  'Comp',
#  'CrdR',
#  'CrdY',
#  'Date',
#  'Day',
#  'Gls',
#  'Int',
#  'Match Report',
#  'Min',
#  'Opponent',
#  'PK',
#  'PKatt',
#  'Pos',
#  'Result',
#  'Round',
#  'Season',
#  'Sh',
#  'SoT',
#  'Squad',
#  'Start',
#  'Venue'}

# %%
set(df_14.columns) - set(df_19.columns)
# Out:
# {'Crs', 'Fld', 'Fls', 'OG', 'Off', 'PKcon', 'PKwon', 'TklW'}

# %%
set(df_19.columns) - set(df_14.columns)
# Out:
# {'Att_2_Dribbles',
#  'Att_Passes',
#  'Blocks',
#  'Carries',
#  'Cmp',
#  'Cmp%',
#  'GCA',
#  'Press',
#  'Prog_2_Carries',
#  'Prog_Passes',
#  'SCA',
#  'Succ',
#  'Tkl',
#  'Touches',
#  'npxG',
#  'xA',
#  'xG'}

# %%
set(df_14.columns).intersection(set(df_19.columns))
# Out:
# {'Ast',
#  'Comp',
#  'CrdR',
#  'CrdY',
#  'Date',
#  'Day',
#  'Gls',
#  'Int',
#  'Match Report',
#  'Min',
#  'Opponent',
#  'PK',
#  'PKatt',
#  'Pos',
#  'Result',
#  'Round',
#  'Season',
#  'Sh',
#  'SoT',
#  'Squad',
#  'Start',
#  'Venue'}

# %%
pd.read_csv('../understat_scraper/dfs/rosters/rosters.csv').columns
# Out:
# Index(['id', 'goals', 'own_goals', 'shots', 'xG', 'time', 'player_id',
#        'team_id', 'position', 'player', 'h_a', 'yellow_card', 'red_card',
#        'roster_in', 'roster_out', 'key_passes', 'assists', 'xA', 'xGChain',
#        'xGBuildup', 'positionOrder', 'season', 'league', 'match_id',
#        'HomeAway'],
#       dtype='object')

# %%
pd.read_csv('../understat_scraper/dfs/rosters/rosters.csv')
# Out:
#            id  goals  own_goals  shots        xG  time  player_id  team_id  \
# 0      466340      0          0      0  0.000000    90       4401       71
# 1      466341      0          0      2  0.050724    90       1685       71
# 2      466342      0          0      3  0.101852    90       7726       71
# 3      466343      0          1      1  0.084139    90       1024       71
# 4      466344      0          0      0  0.000000    90        884       71
# ...       ...    ...        ...    ...       ...   ...        ...      ...
# 71849   17156      0          0      0  0.000000    90        719       84
# 71850   17157      0          0      1  0.021782    80        622       84
# 71851   17160      0          0      0  0.000000    34       4448       84
# 71852   17158      0          0      0  0.000000    20        715       84
# 71853   17159      0          0      1  0.028524    10        717       84
#
# ...
