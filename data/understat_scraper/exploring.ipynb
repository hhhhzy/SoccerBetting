# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
base_url = 'https://understat.com/league/EPL/'
year = str(input('Please enter the year: '))
url = base_url+year
# Out:
# Please enter the year: 2019

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
strings = scripts[1].string

# %%
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')


data = json.loads(json_data)

# %%
data
# Out:
# [{'id': '11643',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '4', 'a': '1'},
#   'xG': {'h': '2.23456', 'a': '0.842407'},
#   'datetime': '2019-08-09 20:00:00',
#   'forecast': {'w': '0.7377', 'd': '0.1732', 'l': '0.0891'}},
#  {'id': '11644',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '0', 'a': '5'},
#   'xG': {'h': '1.2003', 'a': '3.18377'},
#   'datetime': '2019-08-10 12:30:00',
#   'forecast': {'w': '0.0452', 'd': '0.1166', 'l': '0.8382'}},
#  {'id': '11645',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.34099', 'a': '1.59864'},
#   'datetime': '2019-08-10 15:00:00',
#   'forecast': {'w': '0.2083', 'd': '0.3923', 'l': '0.3994'}},
#  {'id': '11646',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '0.909241', 'a': '1.08752'},
#   'datetime': '2019-08-10 15:00:00',
#   'forecast': {'w': '0.266', 'd': '0.3442', 'l': '0.3898'}},
#  {'id': '11647',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.87159', 'a': '1.2246'},
#   'datetime': '2019-08-10 15:00:00',
#   'forecast': {'w': '0.2427', 'd': '0.3231', 'l': '0.4342'}},
#  {'id': '11648',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '0', 'a': '3'},
#   'xG': {'h': '0.670022', 'a': '0.855516'},
#   'datetime': '2019-08-10 15:00:00',
#   'forecast': {'w': '0.2434', 'd': '0.362', 'l': '0.3946'}},
#  {'id': '11649',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '2.57262', 'a': '0.639599'},
#   'datetime': '2019-08-10 17:30:00',
#   'forecast': {'w': '0.822', 'd': '0.1273', 'l': '0.0507'}},
#  {'id': '11650',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '0.380551', 'a': '1.13309'},
#   'datetime': '2019-08-11 14:00:00',
#   'forecast': {'w': '0.1052', 'd': '0.3057', 'l': '0.5891'}},
#  {'id': '11651',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.543759', 'a': '0.812949'},
#   'datetime': '2019-08-11 14:00:00',
#   'forecast': {'w': '0.2174', 'd': '0.3819', 'l': '0.4007'}},
#  {'id': '11652',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '4', 'a': '0'},
#   'xG': {'h': '2.37442', 'a': '1.09534'},
#   'datetime': '2019-08-11 16:30:00',
#   'forecast': {'w': '0.7148', 'd': '0.1782', 'l': '0.107'}},
#  {'id': '11653',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.1644', 'a': '1.39172'},
#   'datetime': '2019-08-17 12:30:00',
#   'forecast': {'w': '0.2899', 'd': '0.2836', 'l': '0.4265'}},
#  {'id': '11654',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.65069', 'a': '1.62777'},
#   'datetime': '2019-08-17 15:00:00',
#   'forecast': {'w': '0.3658', 'd': '0.2724', 'l': '0.3618'}},
#  {'id': '11655',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '2.40461', 'a': '1.00856'},
#   'datetime': '2019-08-17 15:00:00',
#   'forecast': {'w': '0.7183', 'd': '0.179', 'l': '0.1027'}},
#  {'id': '11656',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.832913', 'a': '1.17279'},
#   'datetime': '2019-08-17 15:00:00',
#   'forecast': {'w': '0.231', 'd': '0.322', 'l': '0.447'}},
#  {'id': '11657',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '2.09572', 'a': '0.920429'},
#   'datetime': '2019-08-17 15:00:00',
#   'forecast': {'w': '0.68', 'd': '0.1975', 'l': '0.1225'}},
#  {'id': '11658',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '2.14047', 'a': '1.52022'},
#   'datetime': '2019-08-17 15:00:00',
#   'forecast': {'w': '0.5327', 'd': '0.2278', 'l': '0.2395'}},
#  {'id': '11659',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '3.20076', 'a': '0.074542'},
#   'datetime': '2019-08-17 17:30:00',
#   'forecast': {'w': '0.9674', 'd': '0.0301', 'l': '0.0025'}},
#  {'id': '11660',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '1.84778', 'a': '0.241912'},
#   'datetime': '2019-08-18 14:00:00',
#   'forecast': {'w': '0.8326', 'd': '0.1408', 'l': '0.0266'}},
#  {'id': '11661',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.22629', 'a': '0.947941'},
#   'datetime': '2019-08-18 16:30:00',
#   'forecast': {'w': '0.4391', 'd': '0.3008', 'l': '0.2601'}},
#  {'id': '11662',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.307356', 'a': '1.14332'},
#   'datetime': '2019-08-19 20:00:00',
#   'forecast': {'w': '0.0594', 'd': '0.2597', 'l': '0.6809'}},
#  {'id': '11663',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '0.855926', 'a': '1.25668'},
#   'datetime': '2019-08-23 20:00:00',
#   'forecast': {'w': '0.2213', 'd': '0.3058', 'l': '0.4729'}},
#  {'id': '11664',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '2', 'a': '3'},
#   'xG': {'h': '1.07904', 'a': '1.89428'},
#   'datetime': '2019-08-24 12:30:00',
#   'forecast': {'w': '0.1759', 'd': '0.2595', 'l': '0.5646'}},
#  {'id': '11665',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '0.654318', 'a': '0.704879'},
#   'datetime': '2019-08-24 15:00:00',
#   'forecast': {'w': '0.2916', 'd': '0.4017', 'l': '0.3067'}},
#  {'id': '11666',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.997711', 'a': '2.07795'},
#   'datetime': '2019-08-24 15:00:00',
#   'forecast': {'w': '0.1192', 'd': '0.2115', 'l': '0.6693'}},
#  {'id': '11667',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '2.29348', 'a': '3.45768'},
#   'datetime': '2019-08-24 15:00:00',
#   'forecast': {'w': '0.1537', 'd': '0.1778', 'l': '0.6685'}},
#  {'id': '11669',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '2.23561', 'a': '0.676993'},
#   'datetime': '2019-08-24 15:00:00',
#   'forecast': {'w': '0.7755', 'd': '0.1616', 'l': '0.0629'}},
#  {'id': '11670',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '2.78821', 'a': '0.985542'},
#   'datetime': '2019-08-24 17:30:00',
#   'forecast': {'w': '0.7948', 'd': '0.1361', 'l': '0.0691'}},
#  {'id': '11671',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '1.89345', 'a': '3.12856'},
#   'datetime': '2019-08-25 14:00:00',
#   'forecast': {'w': '0.1625', 'd': '0.1736', 'l': '0.6639'}},
#  {'id': '11668',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.32793', 'a': '1.22762'},
#   'datetime': '2019-08-25 16:30:00',
#   'forecast': {'w': '0.3879', 'd': '0.307', 'l': '0.3051'}},
#  {'id': '11672',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '1.25927', 'a': '0.51428'},
#   'datetime': '2019-08-25 16:30:00',
#   'forecast': {'w': '0.5898', 'd': '0.2775', 'l': '0.1327'}},
#  {'id': '11673',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.769616', 'a': '1.90356'},
#   'datetime': '2019-08-31 12:30:00',
#   'forecast': {'w': '0.1186', 'd': '0.2211', 'l': '0.6603'}},
#  {'id': '11674',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '2.20657', 'a': '1.1674'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.6298', 'd': '0.2265', 'l': '0.1437'}},
#  {'id': '11675',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '2.30579', 'a': '1.04649'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.6944', 'd': '0.1949', 'l': '0.1107'}},
#  {'id': '11676',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '1.41394', 'a': '0.30354'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.6771', 'd': '0.2444', 'l': '0.0785'}},
#  {'id': '11677',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '2.23766', 'a': '0.554726'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.8226', 'd': '0.1353', 'l': '0.0421'}},
#  {'id': '11678',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '4', 'a': '0'},
#   'xG': {'h': '2.30818', 'a': '0.861035'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.7359', 'd': '0.1772', 'l': '0.0869'}},
#  {'id': '11679',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.04131', 'a': '1.1068'},
#   'datetime': '2019-08-31 15:00:00',
#   'forecast': {'w': '0.3299', 'd': '0.3121', 'l': '0.358'}},
#  {'id': '11680',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '0', 'a': '3'},
#   'xG': {'h': '0.61739', 'a': '1.20057'},
#   'datetime': '2019-08-31 17:30:00',
#   'forecast': {'w': '0.1772', 'd': '0.3171', 'l': '0.5057'}},
#  {'id': '11681',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '1.48842', 'a': '2.00172'},
#   'datetime': '2019-09-01 14:00:00',
#   'forecast': {'w': '0.2455', 'd': '0.2459', 'l': '0.5086'}},
#  {'id': '11682',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '1.92509', 'a': '1.95514'},
#   'datetime': '2019-09-01 16:30:00',
#   'forecast': {'w': '0.3461', 'd': '0.2536', 'l': '0.4003'}},
#  {'id': '11683',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '2.93281', 'a': '0.291073'},
#   'datetime': '2019-09-14 11:30:00',
#   'forecast': {'w': '0.9452', 'd': '0.0464', 'l': '0.0084'}},
#  {'id': '11684',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '1.10019', 'a': '0.459141'},
#   'datetime': '2019-09-14 14:00:00',
#   'forecast': {'w': '0.5865', 'd': '0.3062', 'l': '0.1073'}},
#  {'id': '11685',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.68545', 'a': '0.341654'},
#   'datetime': '2019-09-14 14:00:00',
#   'forecast': {'w': '0.7641', 'd': '0.1893', 'l': '0.0466'}},
#  {'id': '11686',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '1.88034', 'a': '1.57659'},
#   'datetime': '2019-09-14 14:00:00',
#   'forecast': {'w': '0.4428', 'd': '0.2527', 'l': '0.3045'}},
#  {'id': '11687',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '4', 'a': '0'},
#   'xG': {'h': '1.04944', 'a': '0.577323'},
#   'datetime': '2019-09-14 14:00:00',
#   'forecast': {'w': '0.4879', 'd': '0.3328', 'l': '0.1793'}},
#  {'id': '11688',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '2', 'a': '5'},
#   'xG': {'h': '1.49359', 'a': '3.06799'},
#   'datetime': '2019-09-14 14:00:00',
#   'forecast': {'w': '0.0809', 'd': '0.1625', 'l': '0.7566'}},
#  {'id': '11689',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '1.7413', 'a': '2.34436'},
#   'datetime': '2019-09-14 16:30:00',
#   'forecast': {'w': '0.2487', 'd': '0.2462', 'l': '0.5051'}},
#  {'id': '11690',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '1.41542', 'a': '1.50641'},
#   'datetime': '2019-09-15 13:00:00',
#   'forecast': {'w': '0.3385', 'd': '0.2793', 'l': '0.3822'}},
#  {'id': '11691',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '2.83209', 'a': '1.00616'},
#   'datetime': '2019-09-15 15:30:00',
#   'forecast': {'w': '0.8062', 'd': '0.1365', 'l': '0.0573'}},
#  {'id': '11692',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '1.40502', 'a': '0.535279'},
#   'datetime': '2019-09-16 19:00:00',
#   'forecast': {'w': '0.6373', 'd': '0.2496', 'l': '0.1131'}},
#  {'id': '11693',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '2.18021', 'a': '1.29773'},
#   'datetime': '2019-09-20 19:00:00',
#   'forecast': {'w': '0.5961', 'd': '0.2395', 'l': '0.1644'}},
#  {'id': '11694',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.28752', 'a': '1.33735'},
#   'datetime': '2019-09-21 11:30:00',
#   'forecast': {'w': '0.3433', 'd': '0.2798', 'l': '0.3769'}},
#  {'id': '11695',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '8', 'a': '0'},
#   'xG': {'h': '6.63049', 'a': '0.344718'},
#   'datetime': '2019-09-21 14:00:00',
#   'forecast': {'w': '0.9996', 'd': '0.0004', 'l': '0'}},
#  {'id': '11696',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '2.39312', 'a': '0.801428'},
#   'datetime': '2019-09-21 14:00:00',
#   'forecast': {'w': '0.7897', 'd': '0.1472', 'l': '0.0631'}},
#  {'id': '11698',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '1.26041', 'a': '0.508011'},
#   'datetime': '2019-09-21 14:00:00',
#   'forecast': {'w': '0.5598', 'd': '0.3092', 'l': '0.131'}},
#  {'id': '11699',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '1.09807', 'a': '1.21592'},
#   'datetime': '2019-09-21 16:30:00',
#   'forecast': {'w': '0.3232', 'd': '0.3006', 'l': '0.3762'}},
#  {'id': '11697',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.984777', 'a': '1.75572'},
#   'datetime': '2019-09-22 13:00:00',
#   'forecast': {'w': '0.1739', 'd': '0.2419', 'l': '0.5842'}},
#  {'id': '11700',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '0.51376', 'a': '1.27826'},
#   'datetime': '2019-09-22 13:00:00',
#   'forecast': {'w': '0.1197', 'd': '0.2714', 'l': '0.6089'}},
#  {'id': '11701',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.23321', 'a': '1.03003'},
#   'datetime': '2019-09-22 15:30:00',
#   'forecast': {'w': '0.4027', 'd': '0.311', 'l': '0.2863'}},
#  {'id': '11702',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '2.53209', 'a': '1.71546'},
#   'datetime': '2019-09-22 15:30:00',
#   'forecast': {'w': '0.5722', 'd': '0.2195', 'l': '0.2083'}},
#  {'id': '11703',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '1.17022', 'a': '1.97079'},
#   'datetime': '2019-09-28 11:30:00',
#   'forecast': {'w': '0.18', 'd': '0.2402', 'l': '0.5798'}},
#  {'id': '11704',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.19008', 'a': '1.16256'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.3564', 'd': '0.3113', 'l': '0.3323'}},
#  {'id': '11705',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.16363', 'a': '1.06615'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.3492', 'd': '0.3828', 'l': '0.268'}},
#  {'id': '11706',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '0.914266', 'a': '1.66919'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.1745', 'd': '0.2428', 'l': '0.5827'}},
#  {'id': '11707',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '2.31957', 'a': '1.29546'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.6247', 'd': '0.2012', 'l': '0.1741'}},
#  {'id': '11708',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '4.26443', 'a': '0.616263'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.9712', 'd': '0.0225', 'l': '0.0063'}},
#  {'id': '11709',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.80497', 'a': '0.712129'},
#   'datetime': '2019-09-28 14:00:00',
#   'forecast': {'w': '0.6775', 'd': '0.2208', 'l': '0.1017'}},
#  {'id': '11711',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '2.35854', 'a': '3.1082'},
#   'datetime': '2019-09-28 16:30:00',
#   'forecast': {'w': '0.2424', 'd': '0.2121', 'l': '0.5455'}},
#  {'id': '11710',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '5', 'a': '0'},
#   'xG': {'h': '1.82438', 'a': '0.054134'},
#   'datetime': '2019-09-29 15:30:00',
#   'forecast': {'w': '0.8912', 'd': '0.1032', 'l': '0.0056'}},
#  {'id': '11712',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.1335', 'a': '1.70399'},
#   'datetime': '2019-09-30 19:00:00',
#   'forecast': {'w': '0.2214', 'd': '0.2554', 'l': '0.5232'}},
#  {'id': '11713',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '2.60017', 'a': '0.478504'},
#   'datetime': '2019-10-05 12:30:00',
#   'forecast': {'w': '0.9194', 'd': '0.067', 'l': '0.0136'}},
#  {'id': '11714',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.558912', 'a': '1.30723'},
#   'datetime': '2019-10-05 15:00:00',
#   'forecast': {'w': '0.1354', 'd': '0.2707', 'l': '0.5939'}},
#  {'id': '11715',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '3.74867', 'a': '0.0982107'},
#   'datetime': '2019-10-05 15:00:00',
#   'forecast': {'w': '0.9902', 'd': '0.009', 'l': '0.0008'}},
#  {'id': '11717',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '1', 'a': '5'},
#   'xG': {'h': '1.84838', 'a': '3.67827'},
#   'datetime': '2019-10-05 15:00:00',
#   'forecast': {'w': '0.0918', 'd': '0.1263', 'l': '0.7819'}},
#  {'id': '11719',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '1.44318', 'a': '0.353724'},
#   'datetime': '2019-10-05 15:00:00',
#   'forecast': {'w': '0.7252', 'd': '0.212', 'l': '0.0628'}},
#  {'id': '11720',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.23577', 'a': '2.0682'},
#   'datetime': '2019-10-05 17:30:00',
#   'forecast': {'w': '0.1412', 'd': '0.2336', 'l': '0.6252'}},
#  {'id': '11716',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '1.61884', 'a': '1.18825'},
#   'datetime': '2019-10-06 14:00:00',
#   'forecast': {'w': '0.4735', 'd': '0.2691', 'l': '0.2574'}},
#  {'id': '11718',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '1', 'a': '4'},
#   'xG': {'h': '1.27044', 'a': '2.15201'},
#   'datetime': '2019-10-06 14:00:00',
#   'forecast': {'w': '0.1721', 'd': '0.2325', 'l': '0.5954'}},
#  {'id': '11722',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '1.24109', 'a': '0.683967'},
#   'datetime': '2019-10-06 14:00:00',
#   'forecast': {'w': '0.5216', 'd': '0.3114', 'l': '0.167'}},
#  {'id': '11721',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.650296', 'a': '0.969204'},
#   'datetime': '2019-10-06 16:30:00',
#   'forecast': {'w': '0.2281', 'd': '0.346', 'l': '0.4259'}},
#  {'id': '11727',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '2.23324', 'a': '0.459112'},
#   'datetime': '2019-10-19 12:30:00',
#   'forecast': {'w': '0.8303', 'd': '0.1277', 'l': '0.042'}},
#  {'id': '11723',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '2.96692', 'a': '1.32184'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.7539', 'd': '0.1481', 'l': '0.098'}},
#  {'id': '11724',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.675554', 'a': '0.402873'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.3837', 'd': '0.4302', 'l': '0.1861'}},
#  {'id': '11725',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '2.30068', 'a': '0.197082'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.8936', 'd': '0.0932', 'l': '0.0132'}},
#  {'id': '11728',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '0.8291', 'a': '1.79569'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.1307', 'd': '0.2209', 'l': '0.6484'}},
#  {'id': '11731',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.891617', 'a': '0.846851'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.3498', 'd': '0.3494', 'l': '0.3008'}},
#  {'id': '11732',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.887495', 'a': '1.37695'},
#   'datetime': '2019-10-19 15:00:00',
#   'forecast': {'w': '0.2018', 'd': '0.3345', 'l': '0.4637'}},
#  {'id': '11726',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.616864', 'a': '4.02104'},
#   'datetime': '2019-10-19 17:30:00',
#   'forecast': {'w': '0.007', 'd': '0.0293', 'l': '0.9637'}},
#  {'id': '11729',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.791862', 'a': '1.03212'},
#   'datetime': '2019-10-20 16:30:00',
#   'forecast': {'w': '0.2391', 'd': '0.3812', 'l': '0.3797'}},
#  {'id': '11730',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.895722', 'a': '0.949735'},
#   'datetime': '2019-10-21 20:00:00',
#   'forecast': {'w': '0.2926', 'd': '0.3964', 'l': '0.311'}},
#  {'id': '11740',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '0', 'a': '9'},
#   'xG': {'h': '0.457334', 'a': '4.38046'},
#   'datetime': '2019-10-25 20:00:00',
#   'forecast': {'w': '0.0032', 'd': '0.0132', 'l': '0.9836'}},
#  {'id': '11737',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '3.19004', 'a': '0.980145'},
#   'datetime': '2019-10-26 12:30:00',
#   'forecast': {'w': '0.8517', 'd': '0.1', 'l': '0.0483'}},
#  {'id': '11734',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '1.15279', 'a': '1.04723'},
#   'datetime': '2019-10-26 15:00:00',
#   'forecast': {'w': '0.3737', 'd': '0.3492', 'l': '0.2771'}},
#  {'id': '11741',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.674903', 'a': '0.899526'},
#   'datetime': '2019-10-26 15:00:00',
#   'forecast': {'w': '0.2583', 'd': '0.3633', 'l': '0.3784'}},
#  {'id': '11742',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '2.33891', 'a': '1.16171'},
#   'datetime': '2019-10-26 15:00:00',
#   'forecast': {'w': '0.7017', 'd': '0.1979', 'l': '0.1004'}},
#  {'id': '11735',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '2', 'a': '4'},
#   'xG': {'h': '2.23494', 'a': '0.988321'},
#   'datetime': '2019-10-26 17:30:00',
#   'forecast': {'w': '0.7194', 'd': '0.1734', 'l': '0.1072'}},
#  {'id': '11738',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.603104', 'a': '1.93255'},
#   'datetime': '2019-10-27 14:00:00',
#   'forecast': {'w': '0.0764', 'd': '0.1803', 'l': '0.7433'}},
#  {'id': '11733',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '1.54014', 'a': '1.77892'},
#   'datetime': '2019-10-27 16:30:00',
#   'forecast': {'w': '0.2675', 'd': '0.2977', 'l': '0.4348'}},
#  {'id': '11736',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '2.18851', 'a': '1.35143'},
#   'datetime': '2019-10-27 16:30:00',
#   'forecast': {'w': '0.5907', 'd': '0.2368', 'l': '0.1725'}},
#  {'id': '11739',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '0.8924', 'a': '4.51232'},
#   'datetime': '2019-10-27 16:30:00',
#   'forecast': {'w': '0.0079', 'd': '0.0224', 'l': '0.9697'}},
#  {'id': '11745',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '1.86862', 'a': '0.641129'},
#   'datetime': '2019-11-02 12:30:00',
#   'forecast': {'w': '0.7315', 'd': '0.1875', 'l': '0.081'}},
#  {'id': '11743',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.02552', 'a': '1.5103'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.2334', 'd': '0.281', 'l': '0.4856'}},
#  {'id': '11744',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '0.741615', 'a': '2.38824'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.0731', 'd': '0.1563', 'l': '0.7706'}},
#  {'id': '11746',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '2.65496', 'a': '0.455082'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.8783', 'd': '0.094', 'l': '0.0277'}},
#  {'id': '11749',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '3.36132', 'a': '0.893889'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.9119', 'd': '0.074', 'l': '0.0141'}},
#  {'id': '11750',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '2.58392', 'a': '0.716613'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.83', 'd': '0.1251', 'l': '0.0449'}},
#  {'id': '11752',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '2', 'a': '3'},
#   'xG': {'h': '1.53597', 'a': '1.93192'},
#   'datetime': '2019-11-02 15:00:00',
#   'forecast': {'w': '0.271', 'd': '0.258', 'l': '0.471'}},
#  {'id': '11751',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.4744', 'a': '2.18313'},
#   'datetime': '2019-11-02 17:30:00',
#   'forecast': {'w': '0.2033', 'd': '0.2538', 'l': '0.5429'}},
#  {'id': '11747',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.44291', 'a': '0.981167'},
#   'datetime': '2019-11-03 14:00:00',
#   'forecast': {'w': '0.155', 'd': '0.3517', 'l': '0.4933'}},
#  {'id': '11748',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.15532', 'a': '0.243393'},
#   'datetime': '2019-11-03 16:30:00',
#   'forecast': {'w': '0.6632', 'd': '0.2752', 'l': '0.0616'}},
#  {'id': '11757',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.62104', 'a': '1.36017'},
#   'datetime': '2019-11-08 20:00:00',
#   'forecast': {'w': '0.1585', 'd': '0.28', 'l': '0.5615'}},
#  {'id': '11754',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '3.28903', 'a': '0.479488'},
#   'datetime': '2019-11-09 12:30:00',
#   'forecast': {'w': '0.9423', 'd': '0.0481', 'l': '0.0096'}},
#  {'id': '11753',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '2.4158', 'a': '0.474281'},
#   'datetime': '2019-11-09 15:00:00',
#   'forecast': {'w': '0.8586', 'd': '0.1051', 'l': '0.0363'}},
#  {'id': '11756',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '2.3306', 'a': '1.9213'},
#   'datetime': '2019-11-09 15:00:00',
#   'forecast': {'w': '0.4754', 'd': '0.2446', 'l': '0.28'}},
#  {'id': '11758',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '0.742281', 'a': '2.08883'},
#   'datetime': '2019-11-09 15:00:00',
#   'forecast': {'w': '0.0761', 'd': '0.2071', 'l': '0.7168'}},
#  {'id': '11759',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.5104', 'a': '0.923443'},
#   'datetime': '2019-11-09 15:00:00',
#   'forecast': {'w': '0.5262', 'd': '0.2654', 'l': '0.2084'}},
#  {'id': '11762',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.37055', 'a': '0.961339'},
#   'datetime': '2019-11-09 17:30:00',
#   'forecast': {'w': '0.4439', 'd': '0.3099', 'l': '0.2462'}},
#  {'id': '11760',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '2.09891', 'a': '0.473225'},
#   'datetime': '2019-11-10 14:00:00',
#   'forecast': {'w': '0.7939', 'd': '0.1511', 'l': '0.055'}},
#  {'id': '11761',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '3.65299', 'a': '1.1342'},
#   'datetime': '2019-11-10 14:00:00',
#   'forecast': {'w': '0.8833', 'd': '0.0828', 'l': '0.0339'}},
#  {'id': '11755',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '1.3319', 'a': '1.48104'},
#   'datetime': '2019-11-10 16:30:00',
#   'forecast': {'w': '0.3127', 'd': '0.2881', 'l': '0.3992'}},
#  {'id': '11772',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '2', 'a': '3'},
#   'xG': {'h': '0.661449', 'a': '2.20681'},
#   'datetime': '2019-11-23 12:30:00',
#   'forecast': {'w': '0.0614', 'd': '0.1533', 'l': '0.7853'}},
#  {'id': '11763',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '1.60823', 'a': '2.60312'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.1668', 'd': '0.2108', 'l': '0.6224'}},
#  {'id': '11765',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '0.849789', 'a': '1.2765'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.2059', 'd': '0.3272', 'l': '0.4669'}},
#  {'id': '11766',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.784706', 'a': '3.50917'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.017', 'd': '0.0549', 'l': '0.9281'}},
#  {'id': '11767',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.02306', 'a': '1.64291'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.1967', 'd': '0.2659', 'l': '0.5374'}},
#  {'id': '11768',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.812693', 'a': '1.80849'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.1424', 'd': '0.2108', 'l': '0.6468'}},
#  {'id': '11771',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '0', 'a': '3'},
#   'xG': {'h': '0.902384', 'a': '2.66281'},
#   'datetime': '2019-11-23 15:00:00',
#   'forecast': {'w': '0.0541', 'd': '0.1127', 'l': '0.8332'}},
#  {'id': '11769',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.23596', 'a': '0.820474'},
#   'datetime': '2019-11-23 17:30:00',
#   'forecast': {'w': '0.4647', 'd': '0.3041', 'l': '0.2312'}},
#  {'id': '11770',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '3', 'a': '3'},
#   'xG': {'h': '1.56025', 'a': '1.33065'},
#   'datetime': '2019-11-24 16:30:00',
#   'forecast': {'w': '0.4198', 'd': '0.3029', 'l': '0.2773'}},
#  {'id': '11764',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '2.6985', 'a': '0.69784'},
#   'datetime': '2019-11-25 20:00:00',
#   'forecast': {'w': '0.8515', 'd': '0.1083', 'l': '0.0402'}},
#  {'id': '11777',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '0.208252', 'a': '2.44389'},
#   'datetime': '2019-11-30 12:30:00',
#   'forecast': {'w': '0.0129', 'd': '0.0872', 'l': '0.8999'}},
#  {'id': '11773',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '1.8509', 'a': '0.936732'},
#   'datetime': '2019-11-30 15:00:00',
#   'forecast': {'w': '0.617', 'd': '0.2446', 'l': '0.1384'}},
#  {'id': '11774',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '2.73185', 'a': '1.12034'},
#   'datetime': '2019-11-30 15:00:00',
#   'forecast': {'w': '0.7651', 'd': '0.1557', 'l': '0.0792'}},
#  {'id': '11776',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.36832', 'a': '0.867601'},
#   'datetime': '2019-11-30 15:00:00',
#   'forecast': {'w': '0.5044', 'd': '0.2797', 'l': '0.2159'}},
#  {'id': '11779',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '2.93189', 'a': '1.02949'},
#   'datetime': '2019-11-30 15:00:00',
#   'forecast': {'w': '0.8068', 'd': '0.1241', 'l': '0.0691'}},
#  {'id': '11778',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.9671', 'a': '0.504005'},
#   'datetime': '2019-11-30 17:30:00',
#   'forecast': {'w': '0.826', 'd': '0.1455', 'l': '0.0285'}},
#  {'id': '11780',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.27422', 'a': '1.47296'},
#   'datetime': '2019-12-01 14:00:00',
#   'forecast': {'w': '0.3147', 'd': '0.2737', 'l': '0.4116'}},
#  {'id': '11781',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '0.810596', 'a': '1.96157'},
#   'datetime': '2019-12-01 14:00:00',
#   'forecast': {'w': '0.1015', 'd': '0.191', 'l': '0.7075'}},
#  {'id': '11775',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '2.24348', 'a': '1.24986'},
#   'datetime': '2019-12-01 16:30:00',
#   'forecast': {'w': '0.6223', 'd': '0.2153', 'l': '0.1624'}},
# ...
#   'datetime': '2020-07-08 17:00:00',
#   'forecast': {'w': '0.9575', 'd': '0.0363', 'l': '0.0062'}},
#  {'id': '11980',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.470483', 'a': '0.326909'},
#   'datetime': '2020-07-08 17:00:00',
#   'forecast': {'w': '0.2959', 'd': '0.5174', 'l': '0.1867'}},
#  {'id': '11982',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '1.99821', 'a': '1.05291'},
#   'datetime': '2020-07-08 17:00:00',
#   'forecast': {'w': '0.6154', 'd': '0.2222', 'l': '0.1624'}},
#  {'id': '11976',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '2.3646', 'a': '2.61624'},
#   'datetime': '2020-07-08 19:15:00',
#   'forecast': {'w': '0.3527', 'd': '0.2139', 'l': '0.4334'}},
#  {'id': '11975',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.960349', 'a': '0.479274'},
#   'datetime': '2020-07-09 17:00:00',
#   'forecast': {'w': '0.4893', 'd': '0.3526', 'l': '0.1581'}},
#  {'id': '11978',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.671442', 'a': '2.29684'},
#   'datetime': '2020-07-09 17:00:00',
#   'forecast': {'w': '0.0437', 'd': '0.1349', 'l': '0.8214'}},
#  {'id': '11974',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '0', 'a': '3'},
#   'xG': {'h': '0.598873', 'a': '2.86531'},
#   'datetime': '2020-07-09 19:15:00',
#   'forecast': {'w': '0.0244', 'd': '0.0809', 'l': '0.8947'}},
#  {'id': '11988',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '0', 'a': '4'},
#   'xG': {'h': '0.613251', 'a': '3.81088'},
#   'datetime': '2020-07-11 11:30:00',
#   'forecast': {'w': '0.0069', 'd': '0.029', 'l': '0.9641'}},
#  {'id': '11991',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '3.12855', 'a': '1.49134'},
#   'datetime': '2020-07-11 11:30:00',
#   'forecast': {'w': '0.782', 'd': '0.1508', 'l': '0.0672'}},
#  {'id': '11986',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '2.17649', 'a': '0.452331'},
#   'datetime': '2020-07-11 14:00:00',
#   'forecast': {'w': '0.8039', 'd': '0.1477', 'l': '0.0484'}},
#  {'id': '11989',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '2.00632', 'a': '1.17509'},
#   'datetime': '2020-07-11 16:30:00',
#   'forecast': {'w': '0.6044', 'd': '0.2302', 'l': '0.1654'}},
#  {'id': '11985',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '0', 'a': '5'},
#   'xG': {'h': '0.149588', 'a': '5.51767'},
#   'datetime': '2020-07-11 19:00:00',
#   'forecast': {'w': '0', 'd': '0.0003', 'l': '0.9997'}},
#  {'id': '11992',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '2.86724', 'a': '0.286561'},
#   'datetime': '2020-07-12 11:00:00',
#   'forecast': {'w': '0.9515', 'd': '0.04', 'l': '0.0085'}},
#  {'id': '11983',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.6977', 'a': '0.974181'},
#   'datetime': '2020-07-12 13:15:00',
#   'forecast': {'w': '0.5655', 'd': '0.2501', 'l': '0.1844'}},
#  {'id': '11990',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.81846', 'a': '0.68991'},
#   'datetime': '2020-07-12 15:30:00',
#   'forecast': {'w': '0.6852', 'd': '0.2064', 'l': '0.1084'}},
#  {'id': '11984',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '4', 'a': '1'},
#   'xG': {'h': '2.54311', 'a': '1.66084'},
#   'datetime': '2020-07-12 18:00:00',
#   'forecast': {'w': '0.6175', 'd': '0.2228', 'l': '0.1597'}},
#  {'id': '11987',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '2', 'a': '2'},
#   'xG': {'h': '1.5033', 'a': '1.8051'},
#   'datetime': '2020-07-13 19:00:00',
#   'forecast': {'w': '0.2591', 'd': '0.3093', 'l': '0.4316'}},
#  {'id': '11995',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '3.05119', 'a': '0.0631109'},
#   'datetime': '2020-07-14 19:15:00',
#   'forecast': {'w': '0.971', 'd': '0.0274', 'l': '0.0016'}},
#  {'id': '11994',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '1.53435', 'a': '1.2857'},
#   'datetime': '2020-07-15 17:00:00',
#   'forecast': {'w': '0.4308', 'd': '0.3045', 'l': '0.2647'}},
#  {'id': '11999',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '0.82755', 'a': '1.66635'},
#   'datetime': '2020-07-15 17:00:00',
#   'forecast': {'w': '0.1546', 'd': '0.2441', 'l': '0.6013'}},
#  {'id': '12000',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '1.05748', 'a': '1.7498'},
#   'datetime': '2020-07-15 17:00:00',
#   'forecast': {'w': '0.159', 'd': '0.2568', 'l': '0.5842'}},
#  {'id': '11993',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '2', 'a': '1'},
#   'xG': {'h': '1.31516', 'a': '2.2233'},
#   'datetime': '2020-07-15 19:15:00',
#   'forecast': {'w': '0.1866', 'd': '0.2257', 'l': '0.5877'}},
#  {'id': '11997',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.944434', 'a': '1.52021'},
#   'datetime': '2020-07-16 17:00:00',
#   'forecast': {'w': '0.1951', 'd': '0.2819', 'l': '0.523'}},
#  {'id': '11998',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '3.05752', 'a': '0.660214'},
#   'datetime': '2020-07-16 17:00:00',
#   'forecast': {'w': '0.9014', 'd': '0.0746', 'l': '0.024'}},
#  {'id': '11996',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.572141', 'a': '1.90448'},
#   'datetime': '2020-07-16 19:15:00',
#   'forecast': {'w': '0.0851', 'd': '0.191', 'l': '0.7239'}},
#  {'id': '12002',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '2.33745', 'a': '0.67264'},
#   'datetime': '2020-07-16 19:15:00',
#   'forecast': {'w': '0.7883', 'd': '0.1493', 'l': '0.0624'}},
#  {'id': '12001',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '0.833995', 'a': '1.03402'},
#   'datetime': '2020-07-17 19:00:00',
#   'forecast': {'w': '0.2662', 'd': '0.3363', 'l': '0.3975'}},
#  {'id': '12008',
#   'isResult': True,
#   'h': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'a': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.576602', 'a': '1.8233'},
#   'datetime': '2020-07-18 16:30:00',
#   'forecast': {'w': '0.0925', 'd': '0.2089', 'l': '0.6986'}},
#  {'id': '12004',
#   'isResult': True,
#   'h': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'a': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.583117', 'a': '2.24527'},
#   'datetime': '2020-07-19 13:00:00',
#   'forecast': {'w': '0.0504', 'd': '0.1363', 'l': '0.8133'}},
#  {'id': '12010',
#   'isResult': True,
#   'h': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'a': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'goals': {'h': '3', 'a': '0'},
#   'xG': {'h': '0.766922', 'a': '1.20085'},
#   'datetime': '2020-07-19 15:00:00',
#   'forecast': {'w': '0.227', 'd': '0.3092', 'l': '0.4638'}},
#  {'id': '12005',
#   'isResult': True,
#   'h': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'a': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'goals': {'h': '0', 'a': '0'},
#   'xG': {'h': '0.855896', 'a': '0.929091'},
#   'datetime': '2020-07-20 17:00:00',
#   'forecast': {'w': '0.3094', 'd': '0.3412', 'l': '0.3494'}},
#  {'id': '12009',
#   'isResult': True,
#   'h': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'a': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'goals': {'h': '0', 'a': '1'},
#   'xG': {'h': '0.468461', 'a': '0.624814'},
#   'datetime': '2020-07-20 17:00:00',
#   'forecast': {'w': '0.2122', 'd': '0.4242', 'l': '0.3636'}},
#  {'id': '12012',
#   'isResult': True,
#   'h': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'a': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.48696', 'a': '0.440119'},
#   'datetime': '2020-07-20 19:15:00',
#   'forecast': {'w': '0.7139', 'd': '0.2176', 'l': '0.0685'}},
#  {'id': '12011',
#   'isResult': True,
#   'h': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'a': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'goals': {'h': '0', 'a': '4'},
#   'xG': {'h': '0.131868', 'a': '3.73814'},
#   'datetime': '2020-07-21 17:00:00',
#   'forecast': {'w': '0.0002', 'd': '0.0069', 'l': '0.9929'}},
#  {'id': '12003',
#   'isResult': True,
#   'h': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'a': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'goals': {'h': '1', 'a': '0'},
#   'xG': {'h': '0.57408', 'a': '0.737137'},
#   'datetime': '2020-07-21 19:15:00',
#   'forecast': {'w': '0.247', 'd': '0.3967', 'l': '0.3563'}},
#  {'id': '12007',
#   'isResult': True,
#   'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'a': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.984161', 'a': '1.29009'},
#   'datetime': '2020-07-22 17:00:00',
#   'forecast': {'w': '0.2391', 'd': '0.325', 'l': '0.4359'}},
#  {'id': '12006',
#   'isResult': True,
#   'h': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'a': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'goals': {'h': '5', 'a': '3'},
#   'xG': {'h': '1.45179', 'a': '2.38205'},
#   'datetime': '2020-07-22 19:15:00',
#   'forecast': {'w': '0.1498', 'd': '0.2219', 'l': '0.6283'}},
#  {'id': '12013',
#   'isResult': True,
#   'h': {'id': '81', 'title': 'West Ham', 'short_title': 'WHU'},
#   'a': {'id': '71', 'title': 'Aston Villa', 'short_title': 'AVL'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.781465', 'a': '0.983594'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.2721', 'd': '0.3463', 'l': '0.3816'}},
#  {'id': '12014',
#   'isResult': True,
#   'h': {'id': '83', 'title': 'Arsenal', 'short_title': 'ARS'},
#   'a': {'id': '90', 'title': 'Watford', 'short_title': 'WAT'},
#   'goals': {'h': '3', 'a': '2'},
#   'xG': {'h': '1.95282', 'a': '3.9197'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.0736', 'd': '0.1256', 'l': '0.8008'}},
#  {'id': '12015',
#   'isResult': True,
#   'h': {'id': '74', 'title': 'Southampton', 'short_title': 'SOU'},
#   'a': {'id': '238', 'title': 'Sheffield United', 'short_title': 'SHE'},
#   'goals': {'h': '3', 'a': '1'},
#   'xG': {'h': '1.64306', 'a': '1.41051'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.4064', 'd': '0.2985', 'l': '0.2951'}},
#  {'id': '12016',
#   'isResult': True,
#   'h': {'id': '86', 'title': 'Newcastle United', 'short_title': 'NEW'},
#   'a': {'id': '87', 'title': 'Liverpool', 'short_title': 'LIV'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '0.339294', 'a': '0.56818'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.1985', 'd': '0.4726', 'l': '0.3289'}},
#  {'id': '12017',
#   'isResult': True,
#   'h': {'id': '88', 'title': 'Manchester City', 'short_title': 'MCI'},
#   'a': {'id': '79', 'title': 'Norwich', 'short_title': 'NOR'},
#   'goals': {'h': '5', 'a': '0'},
#   'xG': {'h': '3.56749', 'a': '0.786563'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.9055', 'd': '0.0714', 'l': '0.0231'}},
#  {'id': '12018',
#   'isResult': True,
#   'h': {'id': '75', 'title': 'Leicester', 'short_title': 'LEI'},
#   'a': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#   'goals': {'h': '0', 'a': '2'},
#   'xG': {'h': '0.754668', 'a': '1.41019'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.153', 'd': '0.281', 'l': '0.566'}},
#  {'id': '12019',
#   'isResult': True,
#   'h': {'id': '72', 'title': 'Everton', 'short_title': 'EVE'},
#   'a': {'id': '73', 'title': 'Bournemouth', 'short_title': 'BOU'},
#   'goals': {'h': '1', 'a': '3'},
#   'xG': {'h': '1.74699', 'a': '1.46461'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.4243', 'd': '0.3157', 'l': '0.26'}},
#  {'id': '12020',
#   'isResult': True,
#   'h': {'id': '78', 'title': 'Crystal Palace', 'short_title': 'CRY'},
#   'a': {'id': '82', 'title': 'Tottenham', 'short_title': 'TOT'},
#   'goals': {'h': '1', 'a': '1'},
#   'xG': {'h': '0.988534', 'a': '0.310302'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.5715', 'd': '0.3333', 'l': '0.0952'}},
#  {'id': '12021',
#   'isResult': True,
#   'h': {'id': '80', 'title': 'Chelsea', 'short_title': 'CHE'},
#   'a': {'id': '229', 'title': 'Wolverhampton Wanderers', 'short_title': 'WOL'},
#   'goals': {'h': '2', 'a': '0'},
#   'xG': {'h': '1.15938', 'a': '0.164561'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.659', 'd': '0.2977', 'l': '0.0433'}},
#  {'id': '12022',
#   'isResult': True,
#   'h': {'id': '92', 'title': 'Burnley', 'short_title': 'BUR'},
#   'a': {'id': '220', 'title': 'Brighton', 'short_title': 'BRI'},
#   'goals': {'h': '1', 'a': '2'},
#   'xG': {'h': '1.44244', 'a': '1.3696'},
#   'datetime': '2020-07-26 15:00:00',
#   'forecast': {'w': '0.3839', 'd': '0.2779', 'l': '0.3382'}}]

# %%
import sys
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
flatten(data[0])
# Out:
# {'id': '11643',
#  'isResult': True,
#  'h_id': '87',
#  'h_title': 'Liverpool',
#  'h_short_title': 'LIV',
#  'a_id': '79',
#  'a_title': 'Norwich',
#  'a_short_title': 'NOR',
#  'goals_h': '4',
#  'goals_a': '1',
#  'xG_h': '2.23456',
#  'xG_a': '0.842407',
#  'datetime': '2019-08-09 20:00:00',
#  'forecast_w': '0.7377',
#  'forecast_d': '0.1732',
#  'forecast_l': '0.0891'}

# %%
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id: 4749

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
strings = scripts[2].string

ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')


data = json.loads(json_data)
data
# Out:
# {'h': {'17133': {'id': '17133',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '546',
#    'team_id': '89',
#    'position': 'GK',
#    'player': 'David de Gea',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0',
#    'xGBuildup': '0',
#    'positionOrder': '1'},
#   '17135': {'id': '17135',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '4463',
#    'team_id': '89',
#    'position': 'DC',
#    'player': 'Tyler Blackett',
#    'h_a': 'h',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.0748569518327713',
#    'xGBuildup': '0.0748569518327713',
#    'positionOrder': '3'},
#   '17136': {'id': '17136',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.10321104526519775',
#    'time': '90',
#    'player_id': '628',
#    'team_id': '89',
#    'position': 'DC',
#    'player': 'Chris Smalling',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.17448090016841888',
#    'xGBuildup': '0.07126984745264053',
#    'positionOrder': '3'},
#   '17134': {'id': '17134',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.06947857141494751',
#    'time': '90',
#    'player_id': '951',
#    'team_id': '89',
#    'position': 'DC',
#    'player': 'Phil Jones',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.052528832107782364',
#    'xGChain': '0.14983858168125153',
#    'xGBuildup': '0.14983858168125153',
#    'positionOrder': '3'},
#   '17137': {'id': '17137',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '23',
#    'player_id': '558',
#    'team_id': '89',
#    'position': 'MR',
#    'player': 'Jesse Lingard',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '17145',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.01874101348221302',
#    'xGBuildup': '0.01874101348221302',
#    'positionOrder': '8'},
#   '17138': {'id': '17138',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '70',
#    'player_id': '552',
#    'team_id': '89',
#    'position': 'MC',
#    'player': 'Ander Herrera',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '17144',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.11031637340784073',
#    'xGBuildup': '0.11031637340784073',
#    'positionOrder': '9'},
#   '17139': {'id': '17139',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.03097105398774147',
#    'time': '90',
#    'player_id': '809',
#    'team_id': '89',
#    'position': 'MC',
#    'player': 'Darren Fletcher',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.01874101348221302',
#    'xGChain': '0.1753900647163391',
#    'xGBuildup': '0.12567798793315887',
#    'positionOrder': '9'},
#   '17140': {'id': '17140',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.01703321933746338',
#    'time': '90',
#    'player_id': '631',
#    'team_id': '89',
#    'position': 'ML',
#    'player': 'Ashley Young',
#    'h_a': 'h',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '2',
#    'assists': '0',
#    'xA': '0.16099858283996582',
#    'xGChain': '0.23056064546108246',
#    'xGBuildup': '0.052528832107782364',
#    'positionOrder': '10'},
#   '17141': {'id': '17141',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.06492315977811813',
#    'time': '90',
#    'player_id': '554',
#    'team_id': '89',
#    'position': 'AMC',
#    'player': 'Juan Mata',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '3',
#    'assists': '0',
#    'xA': '0.14925062656402588',
#    'xGChain': '0.190987691283226',
#    'xGBuildup': '0.16001664102077484',
#    'positionOrder': '12'},
#   '17142': {'id': '17142',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '49',
#    'player_id': '191',
#    'team_id': '89',
#    'position': 'FW',
#    'player': 'Chicharito',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '17146',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.015597633086144924',
#    'xGChain': '0.04656868800520897',
#    'xGBuildup': '0.04656868800520897',
#    'positionOrder': '15'},
#   '17143': {'id': '17143',
#    'goals': '1',
#    'own_goals': '0',
#    'shots': '6',
#    'xG': '0.7865491509437561',
#    'time': '90',
#    'player_id': '629',
#    'team_id': '89',
#    'position': 'FW',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.02559618093073368',
#    'xGChain': '0.11772236227989197',
#    'xGBuildup': '0',
#    'positionOrder': '15'},
#   '17144': {'id': '17144',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '20',
#    'player_id': '630',
#    'team_id': '89',
#    'position': 'Sub',
#    'player': 'Marouane Fellaini',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17138',
#    'key_passes': '2',
#    'assists': '0',
#    'xA': '0.07314915955066681',
#    'xGChain': '0.07314915955066681',
#    'xGBuildup': '0.05611593648791313',
#    'positionOrder': '17'},
#   '17145': {'id': '17145',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '3',
#    'xG': '0.13424095511436462',
#    'time': '67',
#    'player_id': '323',
#    'team_id': '89',
#    'position': 'Sub',
#    'player': 'Adnan Januzaj',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17137',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.1920284926891327',
#    'xGBuildup': '0.057787537574768066',
#    'positionOrder': '17'},
#   '17146': {'id': '17146',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '41',
#    'player_id': '4536',
#    'team_id': '89',
#    'position': 'Sub',
#    'player': 'Nani',
#    'h_a': 'h',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17142',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.07314915955066681',
#    'xGBuildup': '0.07314915955066681',
#    'positionOrder': '17'}},
#  'a': {'17147': {'id': '17147',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '706',
#    'team_id': '84',
#    'position': 'GK',
#    'player': 'Lukasz Fabianski',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.06372921168804169',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '1'},
#   '17148': {'id': '17148',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '707',
#    'team_id': '84',
#    'position': 'DR',
#    'player': 'Angel Rangel',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.020646924152970314',
#    'xGChain': '0.08437613397836685',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '2'},
#   '17150': {'id': '17150',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '709',
#    'team_id': '84',
#    'position': 'DC',
#    'player': 'Ashley Williams',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '0',
#    'xA': '0.028524409979581833',
#    'xGChain': '0.09225361794233322',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '3'},
#   '17149': {'id': '17149',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '721',
#    'team_id': '84',
#    'position': 'DC',
#    'player': 'Jordi Amat',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.06372921168804169',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '3'},
#   '17151': {'id': '17151',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '56',
#    'player_id': '710',
#    'team_id': '84',
#    'position': 'DL',
#    'player': 'Neil Taylor',
#    'h_a': 'a',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '17160',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.06372921168804169',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '4'},
#   '17153': {'id': '17153',
#    'goals': '1',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.06372921168804169',
#    'time': '90',
#    'player_id': '723',
#    'team_id': '84',
#    'position': 'DMC',
#    'player': 'Ki Sung-yueng',
#    'h_a': 'a',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.06372921168804169',
#    'xGBuildup': '0',
#    'positionOrder': '7'},
#   '17152': {'id': '17152',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '769',
#    'team_id': '84',
#    'position': 'DMC',
#    'player': 'Jonjo Shelvey',
#    'h_a': 'a',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.06372921168804169',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '7'},
#   '17154': {'id': '17154',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '70',
#    'player_id': '783',
#    'team_id': '84',
#    'position': 'AMR',
#    'player': 'Nathan Dyer',
#    'h_a': 'a',
#    'yellow_card': '1',
#    'red_card': '0',
#    'roster_in': '17158',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.08437613397836685',
#    'xGBuildup': '0.08437613397836685',
#    'positionOrder': '11'},
#   '17155': {'id': '17155',
#    'goals': '1',
#    'own_goals': '0',
#    'shots': '2',
#    'xG': '0.1640404909849167',
#    'time': '90',
#    'player_id': '714',
#    'team_id': '84',
#    'position': 'AMC',
#    'player': 'Gylfi Sigurdsson',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '1',
#    'assists': '1',
#    'xA': '0.06372921168804169',
#    'xGChain': '0.22776970267295837',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '12'},
#   '17156': {'id': '17156',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '90',
#    'player_id': '719',
#    'team_id': '84',
#    'position': 'AML',
#    'player': 'Wayne Routledge',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '0',
#    'key_passes': '2',
#    'assists': '1',
#    'xA': '0.16517533361911774',
#    'xGChain': '0.22890454530715942',
#    'xGBuildup': '0.06372921168804169',
#    'positionOrder': '13'},
#   '17157': {'id': '17157',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.021781764924526215',
#    'time': '80',
#    'player_id': '622',
#    'team_id': '84',
#    'position': 'FW',
#    'player': 'Wilfried Bony',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '17159',
#    'roster_out': '0',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.22890454530715942',
#    'xGBuildup': '0.2071227878332138',
#    'positionOrder': '15'},
#   '17158': {'id': '17158',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '20',
#    'player_id': '715',
#    'team_id': '84',
#    'position': 'Sub',
#    'player': 'Jefferson Montero',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17154',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.14339357614517212',
#    'xGBuildup': '0.14339357614517212',
#    'positionOrder': '17'},
#   '17159': {'id': '17159',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '1',
#    'xG': '0.028524409979581833',
#    'time': '10',
#    'player_id': '717',
#    'team_id': '84',
#    'position': 'Sub',
#    'player': 'Bafétimbi Gomis',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17157',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0.028524409979581833',
#    'xGBuildup': '0',
#    'positionOrder': '17'},
#   '17160': {'id': '17160',
#    'goals': '0',
#    'own_goals': '0',
#    'shots': '0',
#    'xG': '0',
#    'time': '34',
#    'player_id': '4448',
#    'team_id': '84',
#    'position': 'Sub',
#    'player': 'Dwight Tiendalli',
#    'h_a': 'a',
#    'yellow_card': '0',
#    'red_card': '0',
#    'roster_in': '0',
#    'roster_out': '17151',
#    'key_passes': '0',
#    'assists': '0',
#    'xA': '0',
#    'xGChain': '0',
#    'xGBuildup': '0',
#    'positionOrder': '17'}}}

# %%
strings = scripts[1].string

ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')


data = json.loads(json_data)
data
# Out:
# {'h': [{'id': '14511',
#    'minute': '12',
#    'result': 'SavedShot',
#    'X': '0.7280000305175781',
#    'Y': '0.500999984741211',
#    'xG': '0.01874101348221302',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Darren Fletcher',
#    'lastAction': 'Pass'},
#   {'id': '14512',
#    'minute': '16',
#    'result': 'BlockedShot',
#    'X': '0.789000015258789',
#    'Y': '0.33599998474121096',
#    'xG': '0.015597633086144924',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Chicharito',
#    'lastAction': 'TakeOn'},
#   {'id': '14513',
#    'minute': '25',
#    'result': 'SavedShot',
#    'X': '0.914000015258789',
#    'Y': '0.18799999237060547',
#    'xG': '0.06492315977811813',
#    'player': 'Juan Mata',
#    'h_a': 'h',
#    'player_id': '554',
#    'situation': 'DirectFreekick',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '14514',
#    'minute': '26',
#    'result': 'SavedShot',
#    'X': '0.92',
#    'Y': '0.48200000762939454',
#    'xG': '0.057787537574768066',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'Head',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Ashley Young',
#    'lastAction': 'Aerial'},
#   {'id': '14516',
#    'minute': '33',
#    'result': 'MissedShots',
#    'X': '0.9219999694824219',
#    'Y': '0.59',
#    'xG': '0.0488010048866272',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'FromCorner',
#    'season': '2014',
#    'shotType': 'Head',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Juan Mata',
#    'lastAction': 'Cross'},
#   {'id': '14517',
#    'minute': '40',
#    'result': 'BlockedShot',
#    'X': '0.774000015258789',
#    'Y': '0.46599998474121096',
#    'xG': '0.03097105398774147',
#    'player': 'Darren Fletcher',
#    'h_a': 'h',
#    'player_id': '809',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Juan Mata',
#    'lastAction': 'Pass'},
#   {'id': '14518',
#    'minute': '45',
#    'result': 'MissedShots',
#    'X': '0.9119999694824219',
#    'Y': '0.21899999618530275',
#    'xG': '0.02559618093073368',
#    'player': 'Adnan Januzaj',
#    'h_a': 'h',
#    'player_id': '323',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Wayne Rooney',
#    'lastAction': 'TakeOn'},
#   {'id': '14520',
#    'minute': '52',
#    'result': 'BlockedShot',
#    'X': '0.9619999694824218',
#    'Y': '0.44',
#    'xG': '0.06947857141494751',
#    'player': 'Phil Jones',
#    'h_a': 'h',
#    'player_id': '951',
#    'situation': 'FromCorner',
#    'season': '2014',
#    'shotType': 'Head',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Juan Mata',
#    'lastAction': 'Aerial'},
#   {'id': '14521',
#    'minute': '52',
#    'result': 'Goal',
#    'X': '0.9490000152587891',
#    'Y': '0.5359999847412109',
#    'xG': '0.5765787363052368',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'FromCorner',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '14522',
#    'minute': '61',
#    'result': 'MissedShots',
#    'X': '0.8619999694824219',
#    'Y': '0.30700000762939456',
#    'xG': '0.052528832107782364',
#    'player': 'Adnan Januzaj',
#    'h_a': 'h',
#    'player_id': '323',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Phil Jones',
#    'lastAction': 'TakeOn'},
#   {'id': '14523',
#    'minute': '65',
#    'result': 'ShotOnPost',
#    'X': '0.7659999847412109',
#    'Y': '0.3990000152587891',
#    'xG': '0.06904318183660507',
#    'player': 'Wayne Rooney',
#    'h_a': 'h',
#    'player_id': '629',
#    'situation': 'DirectFreekick',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '14526',
#    'minute': '84',
#    'result': 'SavedShot',
#    'X': '0.745',
#    'Y': '0.6469999694824219',
#    'xG': '0.01703321933746338',
#    'player': 'Ashley Young',
#    'h_a': 'h',
#    'player_id': '631',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Marouane Fellaini',
#    'lastAction': 'Pass'},
#   {'id': '14527',
#    'minute': '94',
#    'result': 'BlockedShot',
#    'X': '0.88',
#    'Y': '0.575',
#    'xG': '0.05611593648791313',
#    'player': 'Adnan Januzaj',
#    'h_a': 'h',
#    'player_id': '323',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Marouane Fellaini',
#    'lastAction': 'HeadPass'},
#   {'id': '14528',
#    'minute': '95',
#    'result': 'MissedShots',
#    'X': '0.925',
#    'Y': '0.5479999923706055',
#    'xG': '0.10321104526519775',
#    'player': 'Chris Smalling',
#    'h_a': 'h',
#    'player_id': '628',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'Head',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Ashley Young',
#    'lastAction': 'Cross'}],
#  'a': [{'id': '14510',
#    'minute': '11',
#    'result': 'SavedShot',
#    'X': '0.7619999694824219',
#    'Y': '0.3160000038146973',
#    'xG': '0.020646924152970314',
#    'player': 'Gylfi Sigurdsson',
#    'h_a': 'a',
#    'player_id': '714',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Angel Rangel',
#    'lastAction': 'Pass'},
#   {'id': '14515',
#    'minute': '27',
#    'result': 'Goal',
#    'X': '0.82',
#    'Y': '0.5420000076293945',
#    'xG': '0.06372921168804169',
#    'player': 'Ki Sung-yueng',
#    'h_a': 'a',
#    'player_id': '723',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Gylfi Sigurdsson',
#    'lastAction': 'Pass'},
#   {'id': '14519',
#    'minute': '50',
#    'result': 'SavedShot',
#    'X': '0.7180000305175781',
#    'Y': '0.48900001525878906',
#    'xG': '0.021781764924526215',
#    'player': 'Wilfried Bony',
#    'h_a': 'a',
#    'player_id': '622',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'RightFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Wayne Routledge',
#    'lastAction': 'Pass'},
#   {'id': '14524',
#    'minute': '71',
#    'result': 'Goal',
#    'X': '0.9219999694824219',
#    'Y': '0.5259999847412109',
#    'xG': '0.14339357614517212',
#    'player': 'Gylfi Sigurdsson',
#    'h_a': 'a',
#    'player_id': '714',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Wayne Routledge',
#    'lastAction': 'Pass'},
#   {'id': '14525',
#    'minute': '77',
#    'result': 'BlockedShot',
#    'X': '0.7659999847412109',
#    'Y': '0.66',
#    'xG': '0.028524409979581833',
#    'player': 'Bafétimbi Gomis',
#    'h_a': 'a',
#    'player_id': '717',
#    'situation': 'OpenPlay',
#    'season': '2014',
#    'shotType': 'LeftFoot',
#    'match_id': '4749',
#    'h_team': 'Manchester United',
#    'a_team': 'Swansea',
#    'h_goals': '1',
#    'a_goals': '2',
#    'date': '2014-08-16 12:45:00',
#    'player_assisted': 'Ashley Williams',
#    'lastAction': 'BallRecovery'}]}
