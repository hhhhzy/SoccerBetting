# %%
import pandas as pd

# %%
df = pd.read_csv('dfs/spi_matches.csv', parse_dates = ['date'])
df
# Out:
#        season       date  league_id                   league  \
# 0        2016 2016-07-09       7921  FA Women's Super League
# 1        2016 2016-07-10       7921  FA Women's Super League
# 2        2016 2016-07-10       7921  FA Women's Super League
# 3        2016 2016-07-16       7921  FA Women's Super League
# 4        2016 2016-07-17       7921  FA Women's Super League
# ...       ...        ...        ...                      ...
# 44710    2021 2021-12-05       1874      Swedish Allsvenskan
# 44711    2021 2021-12-05       1874      Swedish Allsvenskan
# 44712    2021 2021-12-05       1874      Swedish Allsvenskan
# 44713    2021 2021-12-05       1874      Swedish Allsvenskan
# 44714    2021 2021-12-05       1874      Swedish Allsvenskan
#
#                   team1                team2   spi1   spi2   prob1   prob2  \
# 0       Liverpool Women              Reading  51.56  50.42  0.4389  0.2767
# 1         Arsenal Women  Notts County Ladies  46.61  54.03  0.3572  0.3608
# 2      Chelsea FC Women      Birmingham City  59.85  54.64  0.4799  0.2487
# 3       Liverpool Women  Notts County Ladies  53.00  52.35  0.4289  0.2699
# 4      Chelsea FC Women        Arsenal Women  59.43  60.99  0.4124  0.3157
# ...                 ...                  ...    ...    ...     ...     ...
# 44710          Hammarby            Kalmar FF  36.62  19.65  0.6086  0.1594
# 44711  Varbergs BoIS FC              Mjallby  23.31  26.65  0.3934  0.3301
# 44712               AIK            IK Sirius  32.16  25.61  0.5217  0.2055
# 44713          Malmo FF         Halmstads BK  55.34  19.20  0.7923  0.0577
# 44714         BK Hacken       Djurgardens IF  35.90  43.45  0.3607  0.3495
#
#        ...  importance1  importance2  score1  score2  xg1  xg2  nsxg1  nsxg2  \
# 0      ...          NaN          NaN     2.0     0.0  NaN  NaN    NaN    NaN
# 1      ...          NaN          NaN     2.0     0.0  NaN  NaN    NaN    NaN
# 2      ...          NaN          NaN     1.0     1.0  NaN  NaN    NaN    NaN
# 3      ...          NaN          NaN     0.0     0.0  NaN  NaN    NaN    NaN
# 4      ...          NaN          NaN     1.0     2.0  NaN  NaN    NaN    NaN
# ...    ...          ...          ...     ...     ...  ...  ...    ...    ...
# 44710  ...          NaN          NaN     NaN     NaN  NaN  NaN    NaN    NaN
# 44711  ...          NaN          NaN     NaN     NaN  NaN  NaN    NaN    NaN
# 44712  ...          NaN          NaN     NaN     NaN  NaN  NaN    NaN    NaN
# 44713  ...          NaN          NaN     NaN     NaN  NaN  NaN    NaN    NaN
# 44714  ...          NaN          NaN     NaN     NaN  NaN  NaN    NaN    NaN
#
#        adj_score1  adj_score2
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 44710         NaN         NaN
# 44711         NaN         NaN
# 44712         NaN         NaN
# 44713         NaN         NaN
# 44714         NaN         NaN
#
# [44715 rows x 23 columns]

# %%
leagues = [
    'French Ligue 1',
    'Barclays Premier League',
    'Spanish Primera Division',
    'Italy Serie A',
    'German Bundesliga'
]

# %%
df = df[df['league'].isin(leagues) & (df['season'] >= 2017)]

# %%
df[df['date'] < '2021-05-05']['date'].min()
# Out:
# Timestamp('2017-08-04 00:00:00')

# %%
df
# Out:
#        season       date  league_id                    league  \
# 2992     2017 2017-08-04       1843            French Ligue 1
# 3018     2017 2017-08-05       1843            French Ligue 1
# 3026     2017 2017-08-05       1843            French Ligue 1
# 3027     2017 2017-08-05       1843            French Ligue 1
# 3028     2017 2017-08-05       1843            French Ligue 1
# ...       ...        ...        ...                       ...
# 43450    2020 2021-05-23       1869  Spanish Primera Division
# 43451    2020 2021-05-23       1869  Spanish Primera Division
# 43452    2020 2021-05-23       1869  Spanish Primera Division
# 43453    2020 2021-05-23       1854             Italy Serie A
# 43454    2020 2021-05-23       1854             Italy Serie A
#
#                      team1            team2   spi1   spi2   prob1   prob2  \
# 2992             AS Monaco         Toulouse  81.07  57.82  0.7184  0.1002
# 3018   Paris Saint-Germain           Amiens  88.47  37.61  0.9394  0.0110
# 3026                  Metz         Guingamp  52.38  57.17  0.4107  0.3334
# 3027            St Etienne             Nice  57.93  65.03  0.3847  0.3445
# 3028                Troyes     Stade Rennes  45.87  57.87  0.3353  0.3928
# ...                    ...              ...    ...    ...     ...     ...
# 43450      Real Valladolid  Atletico Madrid  62.46  84.15  0.2007  0.5416
# 43451              Granada           Getafe  65.53  73.10  0.3568  0.3219
# 43452          Real Madrid       Villarreal  86.65  80.01  0.5385  0.2248
# 43453              Bologna         Juventus  59.20  81.77  0.1901  0.5957
# 43454               Napoli           Verona  77.65  61.78  0.6053  0.1640
#
#        ...  importance1  importance2  score1  score2   xg1   xg2  nsxg1  \
# 2992   ...         55.2         17.6     3.0     2.0  2.13  0.24   1.56
# 3018   ...         83.3         35.4     2.0     0.0  3.00  0.28   3.35
# 3026   ...         24.2         15.5     1.0     3.0  0.61  1.54   0.63
# 3027   ...         14.4         29.7     1.0     0.0  0.85  0.62   0.58
# 3028   ...         39.3         16.5     1.0     1.0  1.38  1.95   0.92
# ...    ...          ...          ...     ...     ...   ...   ...    ...
# 43450  ...          NaN          NaN     NaN     NaN   NaN   NaN    NaN
# 43451  ...          NaN          NaN     NaN     NaN   NaN   NaN    NaN
# 43452  ...          NaN          NaN     NaN     NaN   NaN   NaN    NaN
# 43453  ...          NaN          NaN     NaN     NaN   NaN   NaN    NaN
# 43454  ...          NaN          NaN     NaN     NaN   NaN   NaN    NaN
#
#        nsxg2  adj_score1  adj_score2
# 2992    0.35        3.15        2.10
# 3018    0.34        1.84        0.00
# 3026    0.96        1.05        2.79
# 3027    1.25        1.05        0.00
# 3028    1.71        1.05        1.05
# ...      ...         ...         ...
# 43450    NaN         NaN         NaN
# 43451    NaN         NaN         NaN
# 43452    NaN         NaN         NaN
# 43453    NaN         NaN         NaN
# 43454    NaN         NaN         NaN
#
# [7304 rows x 23 columns]

# %%
df = df[~df.isna().any(axis=1)]
df
# Out:
#        season       date  league_id                    league  \
# 2992     2017 2017-08-04       1843            French Ligue 1
# 3018     2017 2017-08-05       1843            French Ligue 1
# 3026     2017 2017-08-05       1843            French Ligue 1
# 3027     2017 2017-08-05       1843            French Ligue 1
# 3028     2017 2017-08-05       1843            French Ligue 1
# ...       ...        ...        ...                       ...
# 42437    2020 2021-04-26       1854             Italy Serie A
# 42438    2020 2021-04-26       2411   Barclays Premier League
# 42440    2020 2021-04-26       1869  Spanish Primera Division
# 42479    2020 2021-04-28       1869  Spanish Primera Division
# 42490    2020 2021-04-29       1869  Spanish Primera Division
#
#                      team1            team2   spi1   spi2   prob1   prob2  \
# 2992             AS Monaco         Toulouse  81.07  57.82  0.7184  0.1002
# 3018   Paris Saint-Germain           Amiens  88.47  37.61  0.9394  0.0110
# 3026                  Metz         Guingamp  52.38  57.17  0.4107  0.3334
# 3027            St Etienne             Nice  57.93  65.03  0.3847  0.3445
# 3028                Troyes     Stade Rennes  45.87  57.87  0.3353  0.3928
# ...                    ...              ...    ...    ...     ...     ...
# 42437                Lazio         AC Milan  72.90  74.33  0.3719  0.3798
# 42438       Leicester City   Crystal Palace  79.73  58.67  0.7363  0.0784
# 42440                Eibar    Real Sociedad  65.65  79.49  0.2911  0.4301
# 42479      Athletic Bilbao  Real Valladolid  77.84  61.74  0.5180  0.1970
# 42490            Barcelona          Granada  92.01  64.62  0.8823  0.0312
#
#        ...  importance1  importance2  score1  score2   xg1   xg2  nsxg1  \
# 2992   ...         55.2         17.6     3.0     2.0  2.13  0.24   1.56
# 3018   ...         83.3         35.4     2.0     0.0  3.00  0.28   3.35
# 3026   ...         24.2         15.5     1.0     3.0  0.61  1.54   0.63
# 3027   ...         14.4         29.7     1.0     0.0  0.85  0.62   0.58
# 3028   ...         39.3         16.5     1.0     1.0  1.38  1.95   0.92
# ...    ...          ...          ...     ...     ...   ...   ...    ...
# 42437  ...         52.7        100.0     3.0     0.0  1.73  2.02   1.68
# 42438  ...         94.7          0.4     2.0     1.0  1.21  0.64   1.98
# 42440  ...         22.3          0.0     0.0     1.0  0.98  0.68   1.44
# 42479  ...          0.0         75.9     2.0     2.0  1.66  0.80   1.43
# 42490  ...        100.0          0.0     1.0     2.0  1.76  0.73   4.27
#
#        nsxg2  adj_score1  adj_score2
# 2992    0.35        3.15        2.10
# 3018    0.34        1.84        0.00
# 3026    0.96        1.05        2.79
# 3027    1.25        1.05        0.00
# 3028    1.71        1.05        1.05
# ...      ...         ...         ...
# 42437   2.36        2.72        0.00
# 42438   0.42        2.10        1.05
# 42440   0.52        0.00        1.05
# 42479   1.24        2.10        2.10
# 42490   0.33        1.05        2.10
#
# [6935 rows x 23 columns]

# %%
fbref_teams = ['Monaco', 'Paris S-G', 'Saint-Étienne', 'Montpellier', 'Metz',
       'Lyon', 'Troyes', 'Lille', 'Marseille', 'Angers', 'Nice', 'Rennes',
       'Arsenal', 'Bordeaux', 'Caen', 'Nantes', 'Amiens', 'Toulouse',
       'Brighton', 'Watford', 'West Brom', 'Everton', 'Southampton',
       'Chelsea', 'Crystal Palace', 'Dijon', 'Strasbourg',
       'Manchester Utd', 'Guingamp', 'Newcastle Utd', 'Bayern Munich',
       'Leganés', 'Valencia', 'Schalke 04', 'Hertha BSC', 'Hamburger SV',
       'Sevilla', 'Girona', 'Celta Vigo', 'Burnley', 'Bournemouth',
       'Leicester City', 'Swansea City', 'Mainz 05', 'Wolfsburg',
       'Hellas Verona', 'Liverpool', 'Stoke City', 'Juventus',
       'Hoffenheim', 'Udinese', 'Sampdoria', 'Lazio', 'Crotone',
       'Bologna', 'Sassuolo', 'Inter', 'Tottenham', 'Huddersfield',
       'Atalanta', "M'Gladbach", 'Freiburg', 'Athletic Club', 'La Coruña',
       'Barcelona', 'Manchester City', 'Levante', 'Málaga', 'Köln',
       'Betis', 'Real Sociedad', 'Stuttgart', 'Eint Frankfurt',
       'Werder Bremen', 'Augsburg', 'Leverkusen', 'Dortmund',
       'Las Palmas', 'Roma', 'Genoa', 'Benevento', 'Alavés', 'RB Leipzig',
       'Hannover 96', 'Napoli', 'Fiorentina', 'Milan', 'Eibar', 'SPAL',
       'Real Madrid', 'Espanyol', 'Chievo', 'Getafe', 'Torino',
       'Villarreal', 'Cagliari', 'West Ham', 'Atlético Madrid', 'Fulham',
       'Wolves', 'Reims', 'Cardiff City', 'Empoli', 'Parma',
       'Rayo Vallecano', 'Nîmes', 'Düsseldorf', 'Valladolid', 'Frosinone',
       'Nürnberg', 'Huesca', 'Brest', 'Aston Villa', 'Norwich City',
       'Mallorca', 'Union Berlin', 'Sheffield Utd', 'Granada', 'Osasuna',
       'Paderborn 07', 'Lecce', 'Brescia', 'Lorient', 'Lens', 'Cádiz',
       'Leeds United', 'Elche', 'Arminia', 'Spezia']

len(fbref_teams)
# Out:
# 129

# %%
df['team1'].unique()
# Out:
# array(['AS Monaco', 'Paris Saint-Germain', 'Metz', 'St Etienne', 'Troyes',
#        'Lyon', 'Montpellier', 'Lille', 'Angers', 'Marseille', 'Nice',
#        'Stade Rennes', 'Arsenal', 'Watford', 'West Bromwich Albion',
#        'Southampton', 'Crystal Palace', 'Chelsea', 'Everton', 'Nantes',
#        'Brighton and Hove Albion', 'Amiens', 'Bordeaux', 'Toulouse',
#        'Caen', 'Newcastle', 'Strasbourg', 'Dijon FCO',
#        'Manchester United', 'Guingamp', 'Leganes', 'Bayern Munich',
#        'Valencia', 'Swansea City', 'VfL Wolfsburg', 'Mainz',
#        'TSG Hoffenheim', 'Hertha Berlin', 'Hamburg SV', 'Burnley',
#        'Liverpool', 'Leicester City', 'AFC Bournemouth', 'Juventus',
#        'Celta Vigo', 'Stoke City', 'Schalke 04', 'Girona FC', 'Verona',
#        'Sevilla FC', 'Huddersfield Town', 'SC Freiburg',
#        'Tottenham Hotspur', 'Atalanta', 'Borussia Monchengladbach',
#        'Athletic Bilbao', 'Barcelona', 'Internazionale', 'Sassuolo',
#        'Sampdoria', 'Lazio', 'Crotone', 'Bologna', 'Udinese',
#        'Deportivo La Coruña', 'Levante', 'Manchester City', 'Málaga',
#        'Real Sociedad', 'FC Cologne', 'Real Betis', 'FC Augsburg',
#        'Eintracht Frankfurt', 'VfB Stuttgart', 'Bayer Leverkusen',
#        'Werder Bremen', 'Benevento', 'Genoa', 'Alavés',
#        'Borussia Dortmund', 'AS Roma', 'Las Palmas', 'RB Leipzig',
#        'Hannover 96', 'Torino', 'Espanyol', 'Eibar', 'Getafe',
#        'Fiorentina', 'Chievo Verona', 'Spal', 'AC Milan', 'Napoli',
#        'Real Madrid', 'Cagliari', 'Villarreal', 'West Ham United',
#        'Atletico Madrid', 'Fulham', 'Wolverhampton', 'Reims',
#        'Cardiff City', 'Rayo Vallecano', 'Parma', 'Empoli', 'Nimes',
#        'Fortuna Düsseldorf', 'Real Valladolid', 'Frosinone',
#        '1. FC Nürnberg', 'SD Huesca', 'Brest', 'Aston Villa',
#        'Norwich City', 'Mallorca', 'Sheffield United',
#        '1. FC Union Berlin', 'Granada', 'SC Paderborn', 'Osasuna',
#        'Lecce', 'Brescia', 'Lens', 'Cadiz', 'Lorient', 'Leeds United',
#        'Arminia Bielefeld', 'Elche', 'Spezia'], dtype=object)

# %%
import numpy as np
def s(s, t, ratio_calc = False):
    """ levenshtein_ratio_and_distance:
        Calculates levenshtein distance between two strings.
        If ratio_calc = True, the function computes the
        levenshtein distance ratio of similarity between two strings
        For all i and j, distance[i,j] will contain the Levenshtein
        distance between the first i characters of s and the
        first j characters of t
    """
    # Initialize matrix of zeros
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    # Populate matrix of zeros with the indeces of each character of both strings
    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k

    # Iterate over the matrix to compute the cost of deletions,insertions and/or substitutions    
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0 # If the characters are the same in the two strings in a given position [i,j] then the cost is 0
            else:
                # In order to align the results with those of the Python Levenshtein package, if we choose to calculate the ratio
                # the cost of a substitution is 2. If we calculate just distance, then the cost of a substitution is 1.
                if ratio_calc == True:
                    cost = 2
                else:
                    cost = 1
            distance[row][col] = min(distance[row-1][col] + 1,      # Cost of deletions
                                 distance[row][col-1] + 1,          # Cost of insertions
                                 distance[row-1][col-1] + cost)     # Cost of substitutions
    if ratio_calc == True:
        # Computation of the Levenshtein Distance Ratio
        Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
        return Ratio
    else:
        # print(distance) # Uncomment if you want to see the matrix showing how the algorithm computes the cost of deletions,
        # insertions and/or substitutions
        # This is the minimum number of edits needed to convert string a to string b
        return "The strings are {} edits away".format(distance[row][col])

# %%
final_col_map = {}
for s in fbref_teams:
    closests = {}
    for t in df['team1'].unique():
        ratio = levenshtein_ratio_and_distance(s, t, True)
        closests[t] = ratio
    closests = {k: v for k, v in sorted(closests.items(), key=lambda item: item[1], reverse=True)}
    for c in closests:
        inp = input(f"{s}\t-> {c} =  {max_ratio}? (y/n)")
        if inp == 'y':
            break
    
    final_col_map[s] = c
# Out:
# Monaco	-> AS Monaco =  1.0? (y/n)y
# Paris S-G	-> Paris Saint-Germain =  1.0? (y/n)y
# Saint-Étienne	-> St Etienne =  1.0? (y/n)y
# Montpellier	-> Montpellier =  1.0? (y/n)y
# Metz	-> Metz =  1.0? (y/n)y
# Lyon	-> Lyon =  1.0? (y/n)y
# Troyes	-> Troyes =  1.0? (y/n)y
# Lille	-> Lille =  1.0? (y/n)y
# Marseille	-> Marseille =  1.0? (y/n)y
# Angers	-> Angers =  1.0? (y/n)y
# Nice	-> Nice =  1.0? (y/n)y
# Rennes	-> Stade Rennes =  1.0? (y/n)y
# Arsenal	-> Arsenal =  1.0? (y/n)y
# Bordeaux	-> Bordeaux =  1.0? (y/n)y
# Caen	-> Caen =  1.0? (y/n)y
# Nantes	-> Nantes =  1.0? (y/n)y
# Amiens	-> Amiens =  1.0? (y/n)y
# Toulouse	-> Toulouse =  1.0? (y/n)y
# Brighton	-> Everton =  1.0? (y/n)n
# Brighton	-> Crotone =  1.0? (y/n)n
# Brighton	-> Brighton and Hove Albion =  1.0? (y/n)y
# Watford	-> Watford =  1.0? (y/n)y
# West Brom	-> West Bromwich Albion =  1.0? (y/n)y
# Everton	-> Everton =  1.0? (y/n)y
# Southampton	-> Southampton =  1.0? (y/n)y
# Chelsea	-> Chelsea =  1.0? (y/n)y
# Crystal Palace	-> Crystal Palace =  1.0? (y/n)y
# Dijon	-> Dijon FCO =  1.0? (y/n)y
# Strasbourg	-> Strasbourg =  1.0? (y/n)y
# Manchester Utd	-> Manchester United =  1.0? (y/n)y
# Guingamp	-> Guingamp =  1.0? (y/n)y
# Newcastle Utd	-> Newcastle =  1.0? (y/n)y
# Bayern Munich	-> Bayern Munich =  1.0? (y/n)y
# Leganés	-> Leganes =  1.0? (y/n)y
# Valencia	-> Valencia =  1.0? (y/n)y
# Schalke 04	-> Schalke 04 =  1.0? (y/n)y
# Hertha BSC	-> Hertha Berlin =  1.0? (y/n)y
# Hamburger SV	-> Hamburg SV =  1.0? (y/n)y
# Sevilla	-> Sevilla FC =  1.0? (y/n)y
# Girona	-> Girona FC =  1.0? (y/n)y
# Celta Vigo	-> Celta Vigo =  1.0? (y/n)y
# Burnley	-> Burnley =  1.0? (y/n)y
# Bournemouth	-> AFC Bournemouth =  1.0? (y/n)y
# Leicester City	-> Leicester City =  1.0? (y/n)y
# Swansea City	-> Swansea City =  1.0? (y/n)y
# Mainz 05	-> Mainz =  1.0? (y/n)y
# Wolfsburg	-> VfL Wolfsburg =  1.0? (y/n)y
# Hellas Verona	-> Verona =  1.0? (y/n)y
# Liverpool	-> Liverpool =  1.0? (y/n)y
# Stoke City	-> Stoke City =  1.0? (y/n)y
# Juventus	-> Juventus =  1.0? (y/n)y
# Hoffenheim	-> TSG Hoffenheim =  1.0? (y/n)y
# Udinese	-> Udinese =  1.0? (y/n)y
# Sampdoria	-> Sampdoria =  1.0? (y/n)y
# Lazio	-> Lazio =  1.0? (y/n)y
# Crotone	-> Crotone =  1.0? (y/n)y
# Bologna	-> Bologna =  1.0? (y/n)y
# Sassuolo	-> Sassuolo =  1.0? (y/n)y
# Inter	-> Angers =  1.0? (y/n)n
# Inter	-> Nantes =  1.0? (y/n)n
# Inter	-> Internazionale =  1.0? (y/n)y
# Tottenham	-> Tottenham Hotspur =  1.0? (y/n)y
# Huddersfield	-> Huddersfield Town =  1.0? (y/n)y
# Atalanta	-> Atalanta =  1.0? (y/n)y
# M'Gladbach	-> Málaga =  1.0? (y/n)n
# M'Gladbach	-> Borussia Monchengladbach =  1.0? (y/n)y
# Freiburg	-> SC Freiburg =  1.0? (y/n)y
# Athletic Club	-> Athletic Bilbao =  1.0? (y/n)y
# La Coruña	-> Deportivo La Coruña =  1.0? (y/n)y
# Barcelona	-> Barcelona =  1.0? (y/n)y
# Manchester City	-> Manchester City =  1.0? (y/n)y
# Levante	-> Levante =  1.0? (y/n)y
# Málaga	-> Málaga =  1.0? (y/n)y
# Köln	-> Bologna =  1.0? (y/n)n
# Köln	-> Valencia =  1.0? (y/n)n
# Köln	-> Atalanta =  1.0? (y/n)n
# Köln	-> AC Milan =  1.0? (y/n)n
# Köln	-> Barcelona =  1.0? (y/n)n
# Köln	-> FC Cologne =  1.0? (y/n)y
# Betis	-> Real Betis =  1.0? (y/n)y
# Real Sociedad	-> Real Sociedad =  1.0? (y/n)y
# Stuttgart	-> VfB Stuttgart =  1.0? (y/n)y
# Eint Frankfurt	-> Eintracht Frankfurt =  1.0? (y/n)y
# Werder Bremen	-> Werder Bremen =  1.0? (y/n)y
# Augsburg	-> FC Augsburg =  1.0? (y/n)y
# Leverkusen	-> Bayer Leverkusen =  1.0? (y/n)y
# Dortmund	-> Borussia Dortmund =  1.0? (y/n)y
# Las Palmas	-> Las Palmas =  1.0? (y/n)y
# Roma	-> AS Roma =  1.0? (y/n)y
# Genoa	-> Genoa =  1.0? (y/n)y
# Benevento	-> Benevento =  1.0? (y/n)y
# Alavés	-> Alavés =  1.0? (y/n)y
# RB Leipzig	-> RB Leipzig =  1.0? (y/n)y
# Hannover 96	-> Hannover 96 =  1.0? (y/n)y
# Napoli	-> Napoli =  1.0? (y/n)y
# Fiorentina	-> Fiorentina =  1.0? (y/n)y
# Milan	-> AC Milan =  1.0? (y/n)y
# Eibar	-> Eibar =  1.0? (y/n)y
# SPAL	-> Lyon =  1.0? (y/n)n
# SPAL	-> Spal =  1.0? (y/n)y
# Real Madrid	-> Real Madrid =  1.0? (y/n)y
# Espanyol	-> Espanyol =  1.0? (y/n)y
# Chievo	-> Chievo Verona =  1.0? (y/n)y
# Getafe	-> Getafe =  1.0? (y/n)y
# Torino	-> Torino =  1.0? (y/n)y
# Villarreal	-> Villarreal =  1.0? (y/n)y
# Cagliari	-> Cagliari =  1.0? (y/n)y
# West Ham	-> West Ham United =  1.0? (y/n)y
# Atlético Madrid	-> Atletico Madrid =  1.0? (y/n)y
# Fulham	-> Fulham =  1.0? (y/n)y
# Wolves	-> Wolverhampton =  1.0? (y/n)y
# Reims	-> Reims =  1.0? (y/n)y
# Cardiff City	-> Cardiff City =  1.0? (y/n)y
# Empoli	-> Empoli =  1.0? (y/n)y
# Parma	-> Parma =  1.0? (y/n)y
# Rayo Vallecano	-> Rayo Vallecano =  1.0? (y/n)y
# Nîmes	-> Nimes =  1.0? (y/n)y
# Düsseldorf	-> Fortuna Düsseldorf =  1.0? (y/n)y
# Valladolid	-> Real Valladolid =  1.0? (y/n)y
# Frosinone	-> Frosinone =  1.0? (y/n)y
# Nürnberg	-> 1. FC Nürnberg =  1.0? (y/n)y
# Huesca	-> SD Huesca =  1.0? (y/n)y
# Brest	-> Brest =  1.0? (y/n)y
# Aston Villa	-> Aston Villa =  1.0? (y/n)y
# Norwich City	-> Norwich City =  1.0? (y/n)y
# Mallorca	-> Mallorca =  1.0? (y/n)y
# Union Berlin	-> 1. FC Union Berlin =  1.0? (y/n)y
# Sheffield Utd	-> Sheffield United =  1.0? (y/n)y
# Granada	-> Granada =  1.0? (y/n)y
# Osasuna	-> Osasuna =  1.0? (y/n)y
# Paderborn 07	-> SC Paderborn =  1.0? (y/n)y
# Lecce	-> Lecce =  1.0? (y/n)y
# Brescia	-> Brescia =  1.0? (y/n)y
# Lorient	-> Lorient =  1.0? (y/n)y
# Lens	-> Lens =  1.0? (y/n)y
# Cádiz	-> Cadiz =  1.0? (y/n)y
# Leeds United	-> Leeds United =  1.0? (y/n)y
# Elche	-> Elche =  1.0? (y/n)y
# Arminia	-> Amiens =  1.0? (y/n)n
# Arminia	-> Arminia Bielefeld =  1.0? (y/n)y
# Spezia	-> Spezia =  1.0? (y/n)y

# %%
final_col_map
# Out:
# {'Monaco': 'AS Monaco',
#  'Paris S-G': 'Paris Saint-Germain',
#  'Saint-Étienne': 'St Etienne',
#  'Montpellier': 'Montpellier',
#  'Metz': 'Metz',
#  'Lyon': 'Lyon',
#  'Troyes': 'Troyes',
#  'Lille': 'Lille',
#  'Marseille': 'Marseille',
#  'Angers': 'Angers',
#  'Nice': 'Nice',
#  'Rennes': 'Stade Rennes',
#  'Arsenal': 'Arsenal',
#  'Bordeaux': 'Bordeaux',
#  'Caen': 'Caen',
#  'Nantes': 'Nantes',
#  'Amiens': 'Amiens',
#  'Toulouse': 'Toulouse',
#  'Brighton': 'Brighton and Hove Albion',
#  'Watford': 'Watford',
#  'West Brom': 'West Bromwich Albion',
#  'Everton': 'Everton',
#  'Southampton': 'Southampton',
#  'Chelsea': 'Chelsea',
#  'Crystal Palace': 'Crystal Palace',
#  'Dijon': 'Dijon FCO',
#  'Strasbourg': 'Strasbourg',
#  'Manchester Utd': 'Manchester United',
#  'Guingamp': 'Guingamp',
#  'Newcastle Utd': 'Newcastle',
#  'Bayern Munich': 'Bayern Munich',
#  'Leganés': 'Leganes',
#  'Valencia': 'Valencia',
#  'Schalke 04': 'Schalke 04',
#  'Hertha BSC': 'Hertha Berlin',
#  'Hamburger SV': 'Hamburg SV',
#  'Sevilla': 'Sevilla FC',
#  'Girona': 'Girona FC',
#  'Celta Vigo': 'Celta Vigo',
#  'Burnley': 'Burnley',
#  'Bournemouth': 'AFC Bournemouth',
#  'Leicester City': 'Leicester City',
#  'Swansea City': 'Swansea City',
#  'Mainz 05': 'Mainz',
#  'Wolfsburg': 'VfL Wolfsburg',
#  'Hellas Verona': 'Verona',
#  'Liverpool': 'Liverpool',
#  'Stoke City': 'Stoke City',
#  'Juventus': 'Juventus',
#  'Hoffenheim': 'TSG Hoffenheim',
#  'Udinese': 'Udinese',
#  'Sampdoria': 'Sampdoria',
#  'Lazio': 'Lazio',
#  'Crotone': 'Crotone',
#  'Bologna': 'Bologna',
#  'Sassuolo': 'Sassuolo',
#  'Inter': 'Internazionale',
#  'Tottenham': 'Tottenham Hotspur',
#  'Huddersfield': 'Huddersfield Town',
#  'Atalanta': 'Atalanta',
#  "M'Gladbach": 'Borussia Monchengladbach',
#  'Freiburg': 'SC Freiburg',
#  'Athletic Club': 'Athletic Bilbao',
#  'La Coruña': 'Deportivo La Coruña',
#  'Barcelona': 'Barcelona',
#  'Manchester City': 'Manchester City',
#  'Levante': 'Levante',
#  'Málaga': 'Málaga',
#  'Köln': 'FC Cologne',
#  'Betis': 'Real Betis',
#  'Real Sociedad': 'Real Sociedad',
#  'Stuttgart': 'VfB Stuttgart',
#  'Eint Frankfurt': 'Eintracht Frankfurt',
#  'Werder Bremen': 'Werder Bremen',
#  'Augsburg': 'FC Augsburg',
#  'Leverkusen': 'Bayer Leverkusen',
#  'Dortmund': 'Borussia Dortmund',
#  'Las Palmas': 'Las Palmas',
#  'Roma': 'AS Roma',
#  'Genoa': 'Genoa',
#  'Benevento': 'Benevento',
#  'Alavés': 'Alavés',
#  'RB Leipzig': 'RB Leipzig',
#  'Hannover 96': 'Hannover 96',
#  'Napoli': 'Napoli',
#  'Fiorentina': 'Fiorentina',
#  'Milan': 'AC Milan',
#  'Eibar': 'Eibar',
#  'SPAL': 'Spal',
#  'Real Madrid': 'Real Madrid',
#  'Espanyol': 'Espanyol',
#  'Chievo': 'Chievo Verona',
#  'Getafe': 'Getafe',
#  'Torino': 'Torino',
#  'Villarreal': 'Villarreal',
#  'Cagliari': 'Cagliari',
#  'West Ham': 'West Ham United',
#  'Atlético Madrid': 'Atletico Madrid',
#  'Fulham': 'Fulham',
#  'Wolves': 'Wolverhampton',
#  'Reims': 'Reims',
#  'Cardiff City': 'Cardiff City',
#  'Empoli': 'Empoli',
#  'Parma': 'Parma',
#  'Rayo Vallecano': 'Rayo Vallecano',
#  'Nîmes': 'Nimes',
#  'Düsseldorf': 'Fortuna Düsseldorf',
#  'Valladolid': 'Real Valladolid',
#  'Frosinone': 'Frosinone',
#  'Nürnberg': '1. FC Nürnberg',
#  'Huesca': 'SD Huesca',
#  'Brest': 'Brest',
#  'Aston Villa': 'Aston Villa',
#  'Norwich City': 'Norwich City',
#  'Mallorca': 'Mallorca',
#  'Union Berlin': '1. FC Union Berlin',
#  'Sheffield Utd': 'Sheffield United',
#  'Granada': 'Granada',
#  'Osasuna': 'Osasuna',
#  'Paderborn 07': 'SC Paderborn',
#  'Lecce': 'Lecce',
#  'Brescia': 'Brescia',
#  'Lorient': 'Lorient',
#  'Lens': 'Lens',
#  'Cádiz': 'Cadiz',
#  'Leeds United': 'Leeds United',
#  'Elche': 'Elche',
#  'Arminia': 'Arminia Bielefeld',
#  'Spezia': 'Spezia'}

# %%
import pickle
f = open("final_col_map.pkl","wb")
pickle.dump(c,f)
f.close()

# %%
len(final_col_map.keys())
# Out:
# 129

# %%
len(set(final_col_map.values()))
# Out:
# 129

# %%
map_fbref_spi = final_col_map

# %%
map_spi_fbref = {}
for fbref_team in map_fbref_spi:
    map_spi_fbref[map_fbref_spi[fbref_team]] = fbref_team

# %%
map_spi_fbref
# Out:
# {'AS Monaco': 'Monaco',
#  'Paris Saint-Germain': 'Paris S-G',
#  'St Etienne': 'Saint-Étienne',
#  'Montpellier': 'Montpellier',
#  'Metz': 'Metz',
#  'Lyon': 'Lyon',
#  'Troyes': 'Troyes',
#  'Lille': 'Lille',
#  'Marseille': 'Marseille',
#  'Angers': 'Angers',
#  'Nice': 'Nice',
#  'Stade Rennes': 'Rennes',
#  'Arsenal': 'Arsenal',
#  'Bordeaux': 'Bordeaux',
#  'Caen': 'Caen',
#  'Nantes': 'Nantes',
#  'Amiens': 'Amiens',
#  'Toulouse': 'Toulouse',
#  'Brighton and Hove Albion': 'Brighton',
#  'Watford': 'Watford',
#  'West Bromwich Albion': 'West Brom',
#  'Everton': 'Everton',
#  'Southampton': 'Southampton',
#  'Chelsea': 'Chelsea',
#  'Crystal Palace': 'Crystal Palace',
#  'Dijon FCO': 'Dijon',
#  'Strasbourg': 'Strasbourg',
#  'Manchester United': 'Manchester Utd',
#  'Guingamp': 'Guingamp',
#  'Newcastle': 'Newcastle Utd',
#  'Bayern Munich': 'Bayern Munich',
#  'Leganes': 'Leganés',
#  'Valencia': 'Valencia',
#  'Schalke 04': 'Schalke 04',
#  'Hertha Berlin': 'Hertha BSC',
#  'Hamburg SV': 'Hamburger SV',
#  'Sevilla FC': 'Sevilla',
#  'Girona FC': 'Girona',
#  'Celta Vigo': 'Celta Vigo',
#  'Burnley': 'Burnley',
#  'AFC Bournemouth': 'Bournemouth',
#  'Leicester City': 'Leicester City',
#  'Swansea City': 'Swansea City',
#  'Mainz': 'Mainz 05',
#  'VfL Wolfsburg': 'Wolfsburg',
#  'Verona': 'Hellas Verona',
#  'Liverpool': 'Liverpool',
#  'Stoke City': 'Stoke City',
#  'Juventus': 'Juventus',
#  'TSG Hoffenheim': 'Hoffenheim',
#  'Udinese': 'Udinese',
#  'Sampdoria': 'Sampdoria',
#  'Lazio': 'Lazio',
#  'Crotone': 'Crotone',
#  'Bologna': 'Bologna',
#  'Sassuolo': 'Sassuolo',
#  'Internazionale': 'Inter',
#  'Tottenham Hotspur': 'Tottenham',
#  'Huddersfield Town': 'Huddersfield',
#  'Atalanta': 'Atalanta',
#  'Borussia Monchengladbach': "M'Gladbach",
#  'SC Freiburg': 'Freiburg',
#  'Athletic Bilbao': 'Athletic Club',
#  'Deportivo La Coruña': 'La Coruña',
#  'Barcelona': 'Barcelona',
#  'Manchester City': 'Manchester City',
#  'Levante': 'Levante',
#  'Málaga': 'Málaga',
#  'FC Cologne': 'Köln',
#  'Real Betis': 'Betis',
#  'Real Sociedad': 'Real Sociedad',
#  'VfB Stuttgart': 'Stuttgart',
#  'Eintracht Frankfurt': 'Eint Frankfurt',
#  'Werder Bremen': 'Werder Bremen',
#  'FC Augsburg': 'Augsburg',
#  'Bayer Leverkusen': 'Leverkusen',
#  'Borussia Dortmund': 'Dortmund',
#  'Las Palmas': 'Las Palmas',
#  'AS Roma': 'Roma',
#  'Genoa': 'Genoa',
#  'Benevento': 'Benevento',
#  'Alavés': 'Alavés',
#  'RB Leipzig': 'RB Leipzig',
#  'Hannover 96': 'Hannover 96',
#  'Napoli': 'Napoli',
#  'Fiorentina': 'Fiorentina',
#  'AC Milan': 'Milan',
#  'Eibar': 'Eibar',
#  'Spal': 'SPAL',
#  'Real Madrid': 'Real Madrid',
#  'Espanyol': 'Espanyol',
#  'Chievo Verona': 'Chievo',
#  'Getafe': 'Getafe',
#  'Torino': 'Torino',
#  'Villarreal': 'Villarreal',
#  'Cagliari': 'Cagliari',
#  'West Ham United': 'West Ham',
#  'Atletico Madrid': 'Atlético Madrid',
#  'Fulham': 'Fulham',
#  'Wolverhampton': 'Wolves',
#  'Reims': 'Reims',
#  'Cardiff City': 'Cardiff City',
#  'Empoli': 'Empoli',
#  'Parma': 'Parma',
#  'Rayo Vallecano': 'Rayo Vallecano',
#  'Nimes': 'Nîmes',
#  'Fortuna Düsseldorf': 'Düsseldorf',
#  'Real Valladolid': 'Valladolid',
#  'Frosinone': 'Frosinone',
#  '1. FC Nürnberg': 'Nürnberg',
#  'SD Huesca': 'Huesca',
#  'Brest': 'Brest',
#  'Aston Villa': 'Aston Villa',
#  'Norwich City': 'Norwich City',
#  'Mallorca': 'Mallorca',
#  '1. FC Union Berlin': 'Union Berlin',
#  'Sheffield United': 'Sheffield Utd',
#  'Granada': 'Granada',
#  'Osasuna': 'Osasuna',
#  'SC Paderborn': 'Paderborn 07',
#  'Lecce': 'Lecce',
#  'Brescia': 'Brescia',
#  'Lorient': 'Lorient',
#  'Lens': 'Lens',
#  'Cadiz': 'Cádiz',
#  'Leeds United': 'Leeds United',
#  'Elche': 'Elche',
#  'Arminia Bielefeld': 'Arminia',
#  'Spezia': 'Spezia'}

# %%
df['team1'] = df['team1'].replace(map_spi_fbref)
df['team2'] = df['team2'].replace(map_spi_fbref)
# Out:
# 2992             Monaco
# 3018          Paris S-G
# 3026               Metz
# 3027      Saint-Étienne
# 3028             Troyes
#               ...
# 42437             Lazio
# 42438    Leicester City
# 42440             Eibar
# 42479     Athletic Club
# 42490         Barcelona
# Name: team1, Length: 6935, dtype: object

# %%
league_spi_fbref = {
    'French Ligue 1': 'Ligue1',
    'Barclays Premier League': 'EPL',
    'Spanish Primera Division': 'LaLiga',
    'Italy Serie A': 'SerieA',
    'German Bundesliga': 'Bundesliga'
}

# %%
df['league'] = df['league'].replace(league_spi_fbref)
# Out:
# /opt/anaconda3/envs/general/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
df = df.rename(columns = {
    'season': 'Season',
    'date': 'Date',
    'league': 'League',
    'team1': 'Team_Home',
    'team2': 'Team_Away',
    'spi1': 'Spi_Home',
    'spi2': 'Spi_Away',
    'prob1': 'Prob_Home',
    'prob2': 'Prob_Away',
    'importance1': 'Importance_Home',
    'importance2': 'Importance_Away',
    'xg1': 'xg_Home',
    'xg2': 'xg_Away'    
})[['Season', 'Date', 'League', 'Team_Home', 'Team_Away', 'Spi_Home', 'Spi_Away', 'Prob_Home', 'Prob_Away', 'Importance_Home', 'Importance_Away', 'xg_Home', 'xg_Away']]

# %%
df
# Out:
#        Season       Date  League            Team_Home        Team_Away  \
# 2992     2017 2017-08-04  Ligue1            AS Monaco         Toulouse
# 3018     2017 2017-08-05  Ligue1  Paris Saint-Germain           Amiens
# 3026     2017 2017-08-05  Ligue1                 Metz         Guingamp
# 3027     2017 2017-08-05  Ligue1           St Etienne             Nice
# 3028     2017 2017-08-05  Ligue1               Troyes     Stade Rennes
# ...       ...        ...     ...                  ...              ...
# 42437    2020 2021-04-26  SerieA                Lazio         AC Milan
# 42438    2020 2021-04-26     EPL       Leicester City   Crystal Palace
# 42440    2020 2021-04-26  LaLiga                Eibar    Real Sociedad
# 42479    2020 2021-04-28  LaLiga      Athletic Bilbao  Real Valladolid
# 42490    2020 2021-04-29  LaLiga            Barcelona          Granada
#
#        Spi_Home  Spi_Away  Prob_Home  Prob_Away  Importance_Home  \
# 2992      81.07     57.82     0.7184     0.1002             55.2
# 3018      88.47     37.61     0.9394     0.0110             83.3
# 3026      52.38     57.17     0.4107     0.3334             24.2
# 3027      57.93     65.03     0.3847     0.3445             14.4
# 3028      45.87     57.87     0.3353     0.3928             39.3
# ...         ...       ...        ...        ...              ...
# 42437     72.90     74.33     0.3719     0.3798             52.7
# 42438     79.73     58.67     0.7363     0.0784             94.7
# 42440     65.65     79.49     0.2911     0.4301             22.3
# 42479     77.84     61.74     0.5180     0.1970              0.0
# 42490     92.01     64.62     0.8823     0.0312            100.0
#
#        Importance_Away  xg_Home  xg_Away
# 2992              17.6     2.13     0.24
# 3018              35.4     3.00     0.28
# 3026              15.5     0.61     1.54
# 3027              29.7     0.85     0.62
# 3028              16.5     1.38     1.95
# ...                ...      ...      ...
# 42437            100.0     1.73     2.02
# 42438              0.4     1.21     0.64
# 42440              0.0     0.98     0.68
# 42479             75.9     1.66     0.80
# 42490              0.0     1.76     0.73
#
# [6935 rows x 13 columns]

# %%
col_replace2 = {}
for col in df.columns:
    if col not in ['Season', 'Date', 'League', 'Team_Home', 'Team_Away']:
        col_replace2[col] = '538'+col
col_replace2
# Out:
# {'Spi_Home': '538Spi_Home',
#  'Spi_Away': '538Spi_Away',
#  'Prob_Home': '538Prob_Home',
#  'Prob_Away': '538Prob_Away',
#  'Importance_Home': '538Importance_Home',
#  'Importance_Away': '538Importance_Away',
#  'xg_Home': '538xg_Home',
#  'xg_Away': '538xg_Away'}

# %%
df = df.rename(columns = col_replace2)
df
# Out:
#        Season       Date  League            Team_Home        Team_Away  \
# 2992     2017 2017-08-04  Ligue1            AS Monaco         Toulouse
# 3018     2017 2017-08-05  Ligue1  Paris Saint-Germain           Amiens
# 3026     2017 2017-08-05  Ligue1                 Metz         Guingamp
# 3027     2017 2017-08-05  Ligue1           St Etienne             Nice
# 3028     2017 2017-08-05  Ligue1               Troyes     Stade Rennes
# ...       ...        ...     ...                  ...              ...
# 42437    2020 2021-04-26  SerieA                Lazio         AC Milan
# 42438    2020 2021-04-26     EPL       Leicester City   Crystal Palace
# 42440    2020 2021-04-26  LaLiga                Eibar    Real Sociedad
# 42479    2020 2021-04-28  LaLiga      Athletic Bilbao  Real Valladolid
# 42490    2020 2021-04-29  LaLiga            Barcelona          Granada
#
#        538Spi_Home  538Spi_Away  538Prob_Home  538Prob_Away  \
# 2992         81.07        57.82        0.7184        0.1002
# 3018         88.47        37.61        0.9394        0.0110
# 3026         52.38        57.17        0.4107        0.3334
# 3027         57.93        65.03        0.3847        0.3445
# 3028         45.87        57.87        0.3353        0.3928
# ...            ...          ...           ...           ...
# 42437        72.90        74.33        0.3719        0.3798
# 42438        79.73        58.67        0.7363        0.0784
# 42440        65.65        79.49        0.2911        0.4301
# 42479        77.84        61.74        0.5180        0.1970
# 42490        92.01        64.62        0.8823        0.0312
#
#        538Importance_Home  538Importance_Away  538xg_Home  538xg_Away
# 2992                 55.2                17.6        2.13        0.24
# 3018                 83.3                35.4        3.00        0.28
# 3026                 24.2                15.5        0.61        1.54
# 3027                 14.4                29.7        0.85        0.62
# 3028                 39.3                16.5        1.38        1.95
# ...                   ...                 ...         ...         ...
# 42437                52.7               100.0        1.73        2.02
# 42438                94.7                 0.4        1.21        0.64
# 42440                22.3                 0.0        0.98        0.68
# 42479                 0.0                75.9        1.66        0.80
# 42490               100.0                 0.0        1.76        0.73
#
# [6935 rows x 13 columns]

# %%
season_spi_fbref_map = {
    2017: '2017-2018',
    2018: '2018-2019',
    2019: '2019-2020',
    2020: '2020-2021'
}

# %%
df['Season'] = df['Season'].replace(season_spi_fbref_map)
df
# Out:
#           Season       Date  League            Team_Home        Team_Away  \
# 2992   2017-2018 2017-08-04  Ligue1            AS Monaco         Toulouse
# 3018   2017-2018 2017-08-05  Ligue1  Paris Saint-Germain           Amiens
# 3026   2017-2018 2017-08-05  Ligue1                 Metz         Guingamp
# 3027   2017-2018 2017-08-05  Ligue1           St Etienne             Nice
# 3028   2017-2018 2017-08-05  Ligue1               Troyes     Stade Rennes
# ...          ...        ...     ...                  ...              ...
# 42437  2020-2021 2021-04-26  SerieA                Lazio         AC Milan
# 42438  2020-2021 2021-04-26     EPL       Leicester City   Crystal Palace
# 42440  2020-2021 2021-04-26  LaLiga                Eibar    Real Sociedad
# 42479  2020-2021 2021-04-28  LaLiga      Athletic Bilbao  Real Valladolid
# 42490  2020-2021 2021-04-29  LaLiga            Barcelona          Granada
#
#        538Spi_Home  538Spi_Away  538Prob_Home  538Prob_Away  \
# 2992         81.07        57.82        0.7184        0.1002
# 3018         88.47        37.61        0.9394        0.0110
# 3026         52.38        57.17        0.4107        0.3334
# 3027         57.93        65.03        0.3847        0.3445
# 3028         45.87        57.87        0.3353        0.3928
# ...            ...          ...           ...           ...
# 42437        72.90        74.33        0.3719        0.3798
# 42438        79.73        58.67        0.7363        0.0784
# 42440        65.65        79.49        0.2911        0.4301
# 42479        77.84        61.74        0.5180        0.1970
# 42490        92.01        64.62        0.8823        0.0312
#
#        538Importance_Home  538Importance_Away  538xg_Home  538xg_Away
# 2992                 55.2                17.6        2.13        0.24
# 3018                 83.3                35.4        3.00        0.28
# 3026                 24.2                15.5        0.61        1.54
# 3027                 14.4                29.7        0.85        0.62
# 3028                 39.3                16.5        1.38        1.95
# ...                   ...                 ...         ...         ...
# 42437                52.7               100.0        1.73        2.02
# 42438                94.7                 0.4        1.21        0.64
# 42440                22.3                 0.0        0.98        0.68
# 42479                 0.0                75.9        1.66        0.80
# 42490               100.0                 0.0        1.76        0.73
#
# [6935 rows x 13 columns]

# %%
df.to_csv('../final_data/538/matches.csv', index=False)
