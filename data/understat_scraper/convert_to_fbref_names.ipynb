# %%
import pandas as pd

# %%
df = pd.read_csv('dfs/matches.csv', parse_dates = ['datetime']).sort_values('datetime')
df
# Out:
#           id  isResult  h_id      h_title h_short_title  a_id  \
# 12781   6185      True   177        Reims           REI   161
# 12779   6191      True   168       Nantes           NAN   210
# 12778   6190      True   166  Montpellier           MPL   176
# 12777   6186      True   162    SC Bastia           BAS   164
# 12776   6188      True   169     Guingamp           GUI   175
# ...      ...       ...   ...          ...           ...   ...
# 10127  16130     False   180         Metz           MET   164
# 10128  16129     False   178         Lyon           LYO   170
# 10129  16128     False   210         Lens           LEN   171
# 10130  16127     False   241        Brest           BRE   161
# 10131  16126     False   167       Angers           ANG   160
#
#                    a_title a_short_title  goals_h  goals_a     xG_h      xG_a  \
# 12781  Paris Saint Germain           PSG      2.0      2.0  1.36787  2.655380
# 12779                 Lens           LEN      1.0      0.0  1.02500  0.167128
# 12778             Bordeaux           BOR      0.0      1.0  1.01756  0.750184
# 12777            Marseille           MAR      3.0      3.0  1.39689  1.317510
# 12776        Saint-Etienne           SEN      0.0      2.0  0.63294  1.495320
# ...                    ...           ...      ...      ...      ...       ...
# 10127            Marseille           MAR      NaN      NaN      NaN       NaN
# 10128                 Nice           NIC      NaN      NaN      NaN       NaN
# 10129               Monaco           MON      NaN      NaN      NaN       NaN
# 10130  Paris Saint Germain           PSG      NaN      NaN      NaN       NaN
# 10131                Lille           LIL      NaN      NaN      NaN       NaN
#
#                  datetime  forecast_w  forecast_d  forecast_l     season  \
# 12781 2014-08-08 19:30:00      0.1036      0.1950      0.7014  2014-2015
# 12779 2014-08-09 20:00:00      0.6216      0.3219      0.0565  2014-2015
# 12778 2014-08-09 20:00:00      0.4117      0.3367      0.2516  2014-2015
# 12777 2014-08-09 20:00:00      0.3542      0.3444      0.3014  2014-2015
# 12776 2014-08-09 20:00:00      0.0911      0.2592      0.6497  2014-2015
# ...                   ...         ...         ...         ...        ...
# 10127 2021-05-23 19:00:00         NaN         NaN         NaN  2020-2021
# 10128 2021-05-23 19:00:00         NaN         NaN         NaN  2020-2021
# 10129 2021-05-23 19:00:00         NaN         NaN         NaN  2020-2021
# 10130 2021-05-23 19:00:00         NaN         NaN         NaN  2020-2021
# 10131 2021-05-23 19:00:00         NaN         NaN         NaN  2020-2021
#
#         league
# 12781  Ligue_1
# 12779  Ligue_1
# 12778  Ligue_1
# 12777  Ligue_1
# 12776  Ligue_1
# ...        ...
# 10127  Ligue_1
# 10128  Ligue_1
# 10129  Ligue_1
# 10130  Ligue_1
# 10131  Ligue_1
#
# [12782 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# id                 0
# isResult           0
# h_id               0
# h_title            0
# h_short_title     55
# a_id               0
# a_title            0
# a_short_title     55
# goals_h          317
# goals_a          317
# xG_h             317
# xG_a             317
# datetime           0
# forecast_w       317
# forecast_d       317
# forecast_l       317
# season             0
# league             0
# dtype: int64

# %%
df = df.drop(['h_short_title', 'a_short_title'], 1)

# %%
df[df['id'] == 15713]
# Out:
#          id  isResult  h_id h_title  a_id a_title  goals_h  goals_a     xG_h  \
# 7559  15713      True    96   Lazio   260  Spezia      2.0      1.0  2.36513
#
#           xG_a            datetime  forecast_w  forecast_d  forecast_l  \
# 7559  0.938101 2021-04-03 13:00:00      0.7522      0.1761      0.0717
#
#          season   league
# 7559  2020-2021  Serie_A

# %%
for i, row in df[df.isna().any(axis=1)].iterrows():
    print(f"{row['id']} -> {row['h_title']} \t vs \t {row['a_title']} \t on \t {row['datetime']}")
# Out:
# 12990 -> Lyon 	 vs 	 Reims 	 on 	 2020-03-13 18:45:00
# 12998 -> Montpellier 	 vs 	 Marseille 	 on 	 2020-03-14 15:30:00
# 12991 -> Nantes 	 vs 	 Nimes 	 on 	 2020-03-14 18:00:00
# 12992 -> Amiens 	 vs 	 Angers 	 on 	 2020-03-14 18:00:00
# 12993 -> Toulouse 	 vs 	 Metz 	 on 	 2020-03-14 18:00:00
# 12997 -> Strasbourg 	 vs 	 Dijon 	 on 	 2020-03-14 18:00:00
# 12994 -> Brest 	 vs 	 Lille 	 on 	 2020-03-14 18:00:00
# 12995 -> Bordeaux 	 vs 	 Rennes 	 on 	 2020-03-15 13:00:00
# 12996 -> Monaco 	 vs 	 Saint-Etienne 	 on 	 2020-03-15 15:00:00
# 12989 -> Paris Saint Germain 	 vs 	 Nice 	 on 	 2020-03-15 19:00:00
# 12980 -> Strasbourg 	 vs 	 Paris Saint Germain 	 on 	 2020-03-18 19:00:00
# 13001 -> Lille 	 vs 	 Monaco 	 on 	 2020-03-20 18:45:00
# 13007 -> Rennes 	 vs 	 Lyon 	 on 	 2020-03-21 15:30:00
# 13008 -> Dijon 	 vs 	 Amiens 	 on 	 2020-03-21 18:00:00
# 12999 -> Nice 	 vs 	 Montpellier 	 on 	 2020-03-21 18:00:00
# 13000 -> Metz 	 vs 	 Brest 	 on 	 2020-03-21 18:00:00
# 13005 -> Nimes 	 vs 	 Bordeaux 	 on 	 2020-03-21 18:00:00
# 13006 -> Angers 	 vs 	 Toulouse 	 on 	 2020-03-21 18:00:00
# 13004 -> Saint-Etienne 	 vs 	 Strasbourg 	 on 	 2020-03-22 13:00:00
# 13002 -> Reims 	 vs 	 Nantes 	 on 	 2020-03-22 15:00:00
# 13003 -> Marseille 	 vs 	 Paris Saint Germain 	 on 	 2020-03-22 19:00:00
# 13065 -> Metz 	 vs 	 Nice 	 on 	 2020-07-09 23:00:00
# 13063 -> Marseille 	 vs 	 Monaco 	 on 	 2020-07-09 23:00:00
# 13027 -> Reims 	 vs 	 Toulouse 	 on 	 2020-07-09 23:00:00
# 13026 -> Brest 	 vs 	 Monaco 	 on 	 2020-07-09 23:00:00
# 13016 -> Dijon 	 vs 	 Nice 	 on 	 2020-07-09 23:00:00
# 13010 -> Brest 	 vs 	 Marseille 	 on 	 2020-07-09 23:00:00
# 13011 -> Toulouse 	 vs 	 Saint-Etienne 	 on 	 2020-07-09 23:00:00
# 13012 -> Lyon 	 vs 	 Nimes 	 on 	 2020-07-09 23:00:00
# 15150 -> Granada 	 vs 	 Getafe 	 on 	 2021-05-23 15:00:00
# 15149 -> Eibar 	 vs 	 Barcelona 	 on 	 2021-05-23 15:00:00
# 15152 -> Levante 	 vs 	 Cadiz 	 on 	 2021-05-23 15:00:00
# 15157 -> Elche 	 vs 	 Athletic Club 	 on 	 2021-05-23 15:00:00
# 15151 -> SD Huesca 	 vs 	 Valencia 	 on 	 2021-05-23 15:00:00
# 15148 -> Celta Vigo 	 vs 	 Real Betis 	 on 	 2021-05-23 15:00:00
# 16135 -> Strasbourg 	 vs 	 Lorient 	 on 	 2021-05-23 19:00:00
# 16134 -> Saint-Etienne 	 vs 	 Dijon 	 on 	 2021-05-23 19:00:00
# 16133 -> Rennes 	 vs 	 Nimes 	 on 	 2021-05-23 19:00:00
# 16132 -> Reims 	 vs 	 Bordeaux 	 on 	 2021-05-23 19:00:00
# 16131 -> Nantes 	 vs 	 Montpellier 	 on 	 2021-05-23 19:00:00
# 16130 -> Metz 	 vs 	 Marseille 	 on 	 2021-05-23 19:00:00
# 16129 -> Lyon 	 vs 	 Nice 	 on 	 2021-05-23 19:00:00
# 16128 -> Lens 	 vs 	 Monaco 	 on 	 2021-05-23 19:00:00
# 16127 -> Brest 	 vs 	 Paris Saint Germain 	 on 	 2021-05-23 19:00:00
# 16126 -> Angers 	 vs 	 Lille 	 on 	 2021-05-23 19:00:00

# %%
df = df.dropna()
df.head()
# Out:
#          id  isResult  h_id      h_title  a_id              a_title  goals_h  \
# 12781  6185      True   177        Reims   161  Paris Saint Germain      2.0
# 12779  6191      True   168       Nantes   210                 Lens      1.0
# 12778  6190      True   166  Montpellier   176             Bordeaux      0.0
# 12777  6186      True   162    SC Bastia   164            Marseille      3.0
# 12776  6188      True   169     Guingamp   175        Saint-Etienne      0.0
#
#        goals_a     xG_h      xG_a            datetime  forecast_w  forecast_d  \
# 12781      2.0  1.36787  2.655380 2014-08-08 19:30:00      0.1036      0.1950
# 12779      0.0  1.02500  0.167128 2014-08-09 20:00:00      0.6216      0.3219
# 12778      1.0  1.01756  0.750184 2014-08-09 20:00:00      0.4117      0.3367
# 12777      3.0  1.39689  1.317510 2014-08-09 20:00:00      0.3542      0.3444
# 12776      2.0  0.63294  1.495320 2014-08-09 20:00:00      0.0911      0.2592
#
#        forecast_l     season   league
# 12781      0.7014  2014-2015  Ligue_1
# 12779      0.0565  2014-2015  Ligue_1
# 12778      0.2516  2014-2015  Ligue_1
# 12777      0.3014  2014-2015  Ligue_1
# 12776      0.6497  2014-2015  Ligue_1

# %%
df = df[[
    'h_title',
    'a_title',
    'goals_h',
    'goals_a',
    'xG_h',
    'xG_a',
    'datetime',
    'forecast_w',
    'forecast_d',
    'forecast_l',
    'season',
    'league'
]]

# %%
df['datetime'] = pd.to_datetime(df['datetime']).dt.date
df
# Out:
#                    h_title              a_title  goals_h  goals_a      xG_h  \
# 12781                Reims  Paris Saint Germain      2.0      2.0  1.367870
# 12779               Nantes                 Lens      1.0      0.0  1.025000
# 12778          Montpellier             Bordeaux      0.0      1.0  1.017560
# 12777            SC Bastia            Marseille      3.0      3.0  1.396890
# 12776             Guingamp        Saint-Etienne      0.0      2.0  0.632940
# ...                    ...                  ...      ...      ...       ...
# 7512                Verona               Spezia      1.0      1.0  2.041220
# 2707                 Elche      Atletico Madrid      0.0      1.0  1.381180
# 10160  Paris Saint Germain                 Lens      2.0      1.0  1.377640
# 7511               Crotone                Inter      0.0      2.0  0.759966
# 2706             SD Huesca        Real Sociedad      1.0      0.0  0.446278
#
#            xG_a    datetime  forecast_w  forecast_d  forecast_l     season  \
# 12781  2.655380  2014-08-08      0.1036      0.1950      0.7014  2014-2015
# 12779  0.167128  2014-08-09      0.6216      0.3219      0.0565  2014-2015
# 12778  0.750184  2014-08-09      0.4117      0.3367      0.2516  2014-2015
# 12777  1.317510  2014-08-09      0.3542      0.3444      0.3014  2014-2015
# 12776  1.495320  2014-08-09      0.0911      0.2592      0.6497  2014-2015
# ...         ...         ...         ...         ...         ...        ...
# 7512   1.176410  2021-05-01      0.6142      0.2257      0.1601  2020-2021
# 2707   1.015160  2021-05-01      0.4723      0.3116      0.2161  2020-2021
# 10160  1.514980  2021-05-01      0.3156      0.2737      0.4107  2020-2021
# 7511   2.341690  2021-05-01      0.0715      0.1643      0.7642  2020-2021
# 2706   0.298366  2021-05-01      0.2880      0.5383      0.1737  2020-2021
#
#         league
# 12781  Ligue_1
# 12779  Ligue_1
# 12778  Ligue_1
# 12777  Ligue_1
# 12776  Ligue_1
# ...        ...
# 7512   Serie_A
# 2707   La_liga
# 10160  Ligue_1
# 7511   Serie_A
# 2706   La_liga
#
# [12465 rows x 12 columns]

# %%
df[df['datetime'] == pd.Timestamp(2017, 9, 15)]
# Out:
#            h_title       a_title  goals_h  goals_a      xG_h      xG_a  \
# 6516   Hannover 96  Hamburger SV      2.0      0.0  2.298200  0.453334
# 11591     Toulouse      Bordeaux      0.0      1.0  0.909141  0.733308
# 1479   Bournemouth      Brighton      2.0      1.0  1.395290  0.874276
#
#          datetime  forecast_w  forecast_d  forecast_l     season      league
# 6516   2017-09-15      0.8903      0.0894      0.0203  2017-2018  Bundesliga
# 11591  2017-09-15      0.3730      0.3569      0.2701  2017-2018     Ligue_1
# 1479   2017-09-15      0.4979      0.3047      0.1974  2017-2018         EPL

# %%
df = df[df['season'].isin(['2017-2018', '2018-2019', '2019-2020', '2020-2021'])]
df
# Out:
#                    h_title          a_title  goals_h  goals_a      xG_h  \
# 11641               Monaco         Toulouse      3.0      2.0  2.146360
# 11640  Paris Saint Germain           Amiens      2.0      0.0  2.252640
# 11638          Montpellier             Caen      1.0      0.0  1.461790
# 11637                 Lyon       Strasbourg      4.0      0.0  1.727830
# 11636        Saint-Etienne             Nice      1.0      0.0  0.943684
# ...                    ...              ...      ...      ...       ...
# 7512                Verona           Spezia      1.0      1.0  2.041220
# 2707                 Elche  Atletico Madrid      0.0      1.0  1.381180
# 10160  Paris Saint Germain             Lens      2.0      1.0  1.377640
# 7511               Crotone            Inter      0.0      2.0  0.759966
# 2706             SD Huesca    Real Sociedad      1.0      0.0  0.446278
#
#            xG_a    datetime  forecast_w  forecast_d  forecast_l     season  \
# 11641  0.248798  2017-08-04      0.8672      0.1105      0.0223  2017-2018
# 11640  0.190301  2017-08-05      0.8981      0.0875      0.0144  2017-2018
# 11638  0.319240  2017-08-05      0.7392      0.2061      0.0547  2017-2018
# 11637  0.292445  2017-08-05      0.8120      0.1553      0.0327  2017-2018
# 11636  0.593773  2017-08-05      0.4413      0.3855      0.1732  2017-2018
# ...         ...         ...         ...         ...         ...        ...
# 7512   1.176410  2021-05-01      0.6142      0.2257      0.1601  2020-2021
# 2707   1.015160  2021-05-01      0.4723      0.3116      0.2161  2020-2021
# 10160  1.514980  2021-05-01      0.3156      0.2737      0.4107  2020-2021
# 7511   2.341690  2021-05-01      0.0715      0.1643      0.7642  2020-2021
# 2706   0.298366  2021-05-01      0.2880      0.5383      0.1737  2020-2021
#
#         league
# 11641  Ligue_1
# 11640  Ligue_1
# 11638  Ligue_1
# 11637  Ligue_1
# 11636  Ligue_1
# ...        ...
# 7512   Serie_A
# 2707   La_liga
# 10160  Ligue_1
# 7511   Serie_A
# 2706   La_liga
#
# [6987 rows x 12 columns]

# %%
fbref_teams = ['Monaco', 'Paris S-G', 'Saint-Étienne', 'Montpellier', 'Metz',
       'Lyon', 'Troyes', 'Lille', 'Marseille', 'Angers', 'Nice', 'Rennes',
       'Arsenal', 'Bordeaux', 'Caen', 'Nantes', 'Amiens', 'Toulouse',
       'Brighton', 'Watford', 'West Brom', 'Everton', 'Southampton',
       'Chelsea', 'Crystal Palace', 'Dijon', 'Strasbourg',
       'Manchester Utd', 'Guingamp', 'Newcastle Utd', 'Bayern Munich',
       'Leganés', 'Valencia', 'Schalke 04', 'Hertha BSC', 'Hamburger SV',
       'Sevilla', 'Girona', 'Celta Vigo', 'Burnley', 'Bournemouth',
       'Leicester City', 'Swansea City', 'Mainz 05', 'Wolfsburg',
       'Hellas Verona', 'Liverpool', 'Stoke City', 'Juventus',
       'Hoffenheim', 'Udinese', 'Sampdoria', 'Lazio', 'Crotone',
       'Bologna', 'Sassuolo', 'Inter', 'Tottenham', 'Huddersfield',
       'Atalanta', "M'Gladbach", 'Freiburg', 'Athletic Club', 'La Coruña',
       'Barcelona', 'Manchester City', 'Levante', 'Málaga', 'Köln',
       'Betis', 'Real Sociedad', 'Stuttgart', 'Eint Frankfurt',
       'Werder Bremen', 'Augsburg', 'Leverkusen', 'Dortmund',
       'Las Palmas', 'Roma', 'Genoa', 'Benevento', 'Alavés', 'RB Leipzig',
       'Hannover 96', 'Napoli', 'Fiorentina', 'Milan', 'Eibar', 'SPAL',
       'Real Madrid', 'Espanyol', 'Chievo', 'Getafe', 'Torino',
       'Villarreal', 'Cagliari', 'West Ham', 'Atlético Madrid', 'Fulham',
       'Wolves', 'Reims', 'Cardiff City', 'Empoli', 'Parma',
       'Rayo Vallecano', 'Nîmes', 'Düsseldorf', 'Valladolid', 'Frosinone',
       'Nürnberg', 'Huesca', 'Brest', 'Aston Villa', 'Norwich City',
       'Mallorca', 'Union Berlin', 'Sheffield Utd', 'Granada', 'Osasuna',
       'Paderborn 07', 'Lecce', 'Brescia', 'Lorient', 'Lens', 'Cádiz',
       'Leeds United', 'Elche', 'Arminia', 'Spezia']

len(fbref_teams)
# Out:
# 129

# %%
import numpy as np
def levenshtein_ratio_and_distance(s, t, ratio_calc = False):
    """ levenshtein_ratio_and_distance:
        Calculates levenshtein distance between two strings.
        If ratio_calc = True, the function computes the
        levenshtein distance ratio of similarity between two strings
        For all i and j, distance[i,j] will contain the Levenshtein
        distance between the first i characters of s and the
        first j characters of t
    """
    # Initialize matrix of zeros
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    # Populate matrix of zeros with the indeces of each character of both strings
    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k

    # Iterate over the matrix to compute the cost of deletions,insertions and/or substitutions    
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0 # If the characters are the same in the two strings in a given position [i,j] then the cost is 0
            else:
                # In order to align the results with those of the Python Levenshtein package, if we choose to calculate the ratio
                # the cost of a substitution is 2. If we calculate just distance, then the cost of a substitution is 1.
                if ratio_calc == True:
                    cost = 2
                else:
                    cost = 1
            distance[row][col] = min(distance[row-1][col] + 1,      # Cost of deletions
                                 distance[row][col-1] + 1,          # Cost of insertions
                                 distance[row-1][col-1] + cost)     # Cost of substitutions
    if ratio_calc == True:
        # Computation of the Levenshtein Distance Ratio
        Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
        return Ratio
    else:
        # print(distance) # Uncomment if you want to see the matrix showing how the algorithm computes the cost of deletions,
        # insertions and/or substitutions
        # This is the minimum number of edits needed to convert string a to string b
        return "The strings are {} edits away".format(distance[row][col])

# %%
final_col_map = {}
for s in fbref_teams:
    closests = {}
    for t in df['h_title'].unique():
        ratio = levenshtein_ratio_and_distance(s, t, True)
        closests[t] = ratio
    closests = {k: v for k, v in sorted(closests.items(), key=lambda item: item[1], reverse=True)}
    for c in closests:
        inp = input(f"{s}\t-> {c} =  {closests[c]}? (y/n)")
        if inp == 'y':
            break
    
    final_col_map[s] = c
# Out:
# Monaco	-> Monaco =  1.0? (y/n)y
# Paris S-G	-> Paris Saint Germain =  0.5714285714285714? (y/n)y
# Saint-Étienne	-> Saint-Etienne =  0.9230769230769231? (y/n)y
# Montpellier	-> Montpellier =  1.0? (y/n)y
# Metz	-> Metz =  1.0? (y/n)y
# Lyon	-> Lyon =  1.0? (y/n)y
# Troyes	-> Troyes =  1.0? (y/n)y
# Lille	-> Lille =  1.0? (y/n)y
# Marseille	-> Marseille =  1.0? (y/n)y
# Angers	-> Angers =  1.0? (y/n)y
# Nice	-> Nice =  1.0? (y/n)y
# Rennes	-> Rennes =  1.0? (y/n)y
# Arsenal	-> Arsenal =  1.0? (y/n)y
# Bordeaux	-> Bordeaux =  1.0? (y/n)y
# Caen	-> Caen =  1.0? (y/n)y
# Nantes	-> Nantes =  1.0? (y/n)y
# Amiens	-> Amiens =  1.0? (y/n)y
# Toulouse	-> Toulouse =  1.0? (y/n)y
# Brighton	-> Brighton =  1.0? (y/n)y
# Watford	-> Watford =  1.0? (y/n)y
# West Brom	-> West Ham =  0.7058823529411765? (y/n)n
# West Brom	-> West Bromwich Albion =  0.6206896551724138? (y/n)y
# Everton	-> Everton =  1.0? (y/n)y
# Southampton	-> Southampton =  1.0? (y/n)y
# Chelsea	-> Chelsea =  1.0? (y/n)y
# Crystal Palace	-> Crystal Palace =  1.0? (y/n)y
# Dijon	-> Dijon =  1.0? (y/n)y
# Strasbourg	-> Strasbourg =  1.0? (y/n)y
# Manchester Utd	-> Manchester United =  0.9032258064516129? (y/n)y
# Guingamp	-> Guingamp =  1.0? (y/n)y
# Newcastle Utd	-> Newcastle United =  0.896551724137931? (y/n)y
# Bayern Munich	-> Bayern Munich =  1.0? (y/n)y
# Leganés	-> Leganes =  0.8571428571428571? (y/n)y
# Valencia	-> Valencia =  1.0? (y/n)y
# Schalke 04	-> Schalke 04 =  1.0? (y/n)y
# Hertha BSC	-> Hertha Berlin =  0.6956521739130435? (y/n)y
# Hamburger SV	-> Hamburger SV =  1.0? (y/n)y
# Sevilla	-> Sevilla =  1.0? (y/n)y
# Girona	-> Girona =  1.0? (y/n)y
# Celta Vigo	-> Celta Vigo =  1.0? (y/n)y
# Burnley	-> Burnley =  1.0? (y/n)y
# Bournemouth	-> Bournemouth =  1.0? (y/n)y
# Leicester City	-> Leicester =  0.782608695652174? (y/n)y
# Swansea City	-> Swansea =  0.7368421052631579? (y/n)y
# Mainz 05	-> Mainz 05 =  1.0? (y/n)y
# Wolfsburg	-> Wolfsburg =  1.0? (y/n)y
# Hellas Verona	-> Verona =  0.631578947368421? (y/n)y
# Liverpool	-> Liverpool =  1.0? (y/n)y
# Stoke City	-> Stoke =  0.6666666666666666? (y/n)y
# Juventus	-> Juventus =  1.0? (y/n)y
# Hoffenheim	-> Hoffenheim =  1.0? (y/n)y
# Udinese	-> Udinese =  1.0? (y/n)y
# Sampdoria	-> Sampdoria =  1.0? (y/n)y
# Lazio	-> Lazio =  1.0? (y/n)y
# Crotone	-> Crotone =  1.0? (y/n)y
# Bologna	-> Bologna =  1.0? (y/n)y
# Sassuolo	-> Sassuolo =  1.0? (y/n)y
# Inter	-> Inter =  1.0? (y/n)y
# Tottenham	-> Tottenham =  1.0? (y/n)y
# Huddersfield	-> Huddersfield =  1.0? (y/n)y
# Atalanta	-> Atalanta =  1.0? (y/n)y
# M'Gladbach	-> Borussia M.Gladbach =  0.6206896551724138? (y/n)y
# Freiburg	-> Freiburg =  1.0? (y/n)y
# Athletic Club	-> Athletic Club =  1.0? (y/n)y
# La Coruña	-> Deportivo La Coruna =  0.5714285714285714? (y/n)y
# Barcelona	-> Barcelona =  1.0? (y/n)y
# Manchester City	-> Manchester City =  1.0? (y/n)y
# Levante	-> Levante =  1.0? (y/n)y
# Málaga	-> Malaga =  0.8333333333333334? (y/n)y
# Köln	-> Bologna =  0.36363636363636365? (y/n)n
# Köln	-> Valencia =  0.3333333333333333? (y/n)n
# Köln	-> Atalanta =  0.3333333333333333? (y/n)n
# Köln	-> AC Milan =  0.3333333333333333? (y/n)n
# Köln	-> Barcelona =  0.3076923076923077? (y/n)n
# Köln	-> FC Cologne =  0.2857142857142857? (y/n)y
# Betis	-> Real Betis =  0.6666666666666666? (y/n)y
# Real Sociedad	-> Real Sociedad =  1.0? (y/n)y
# Stuttgart	-> VfB Stuttgart =  0.8181818181818182? (y/n)y
# Eint Frankfurt	-> Eintracht Frankfurt =  0.8484848484848485? (y/n)y
# Werder Bremen	-> Werder Bremen =  1.0? (y/n)y
# Augsburg	-> Augsburg =  1.0? (y/n)y
# Leverkusen	-> Bayer Leverkusen =  0.7692307692307693? (y/n)y
# Dortmund	-> Borussia Dortmund =  0.64? (y/n)y
# Las Palmas	-> Las Palmas =  1.0? (y/n)y
# Roma	-> Roma =  1.0? (y/n)y
# Genoa	-> Genoa =  1.0? (y/n)y
# Benevento	-> Benevento =  1.0? (y/n)y
# Alavés	-> Alaves =  0.8333333333333334? (y/n)y
# RB Leipzig	-> RasenBallsport Leipzig =  0.625? (y/n)y
# Hannover 96	-> Hannover 96 =  1.0? (y/n)y
# Napoli	-> Napoli =  1.0? (y/n)y
# Fiorentina	-> Fiorentina =  1.0? (y/n)y
# Milan	-> AC Milan =  0.7692307692307693? (y/n)y
# Eibar	-> Eibar =  1.0? (y/n)y
# SPAL	-> SPAL 2013 =  0.6153846153846154? (y/n)y
# Real Madrid	-> Real Madrid =  1.0? (y/n)y
# Espanyol	-> Espanyol =  1.0? (y/n)y
# Chievo	-> Chievo =  1.0? (y/n)y
# Getafe	-> Getafe =  1.0? (y/n)y
# Torino	-> Torino =  1.0? (y/n)y
# Villarreal	-> Villarreal =  1.0? (y/n)y
# Cagliari	-> Cagliari =  1.0? (y/n)y
# West Ham	-> West Ham =  1.0? (y/n)y
# Atlético Madrid	-> Atletico Madrid =  0.9333333333333333? (y/n)y
# Fulham	-> Fulham =  1.0? (y/n)y
# Wolves	-> Alaves =  0.6666666666666666? (y/n)n
# Wolves	-> Wolfsburg =  0.5333333333333333? (y/n)n
# Wolves	-> Troyes =  0.5? (y/n)n
# Wolves	-> Toulouse =  0.42857142857142855? (y/n)n
# Wolves	-> Juventus =  0.42857142857142855? (y/n)n
# Wolves	-> West Ham =  0.42857142857142855? (y/n)n
# Wolves	-> Wolverhampton Wanderers =  0.41379310344827586? (y/n)y
# Reims	-> Reims =  1.0? (y/n)y
# Cardiff City	-> Cardiff =  0.7368421052631579? (y/n)y
# Empoli	-> Empoli =  1.0? (y/n)y
# Parma	-> Las Palmas =  0.5333333333333333? (y/n)y
# Rayo Vallecano	-> Rayo Vallecano =  1.0? (y/n)y
# Nîmes	-> Nimes =  0.8? (y/n)y
# Düsseldorf	-> Fortuna Duesseldorf =  0.6206896551724138? (y/n)y
# Valladolid	-> Real Valladolid =  0.8? (y/n)y
# Frosinone	-> Frosinone =  1.0? (y/n)y
# Nürnberg	-> Nuernberg =  0.8235294117647058? (y/n)y
# Huesca	-> SD Huesca =  0.8? (y/n)y
# Brest	-> Brest =  1.0? (y/n)y
# Aston Villa	-> Aston Villa =  1.0? (y/n)y
# Norwich City	-> Norwich =  0.7368421052631579? (y/n)y
# Mallorca	-> Mallorca =  1.0? (y/n)y
# Union Berlin	-> Union Berlin =  1.0? (y/n)y
# Sheffield Utd	-> Sheffield United =  0.896551724137931? (y/n)y
# Granada	-> Granada =  1.0? (y/n)y
# Osasuna	-> Osasuna =  1.0? (y/n)y
# Paderborn 07	-> Paderborn =  0.8571428571428571? (y/n)y
# Lecce	-> Lecce =  1.0? (y/n)y
# Brescia	-> Brescia =  1.0? (y/n)y
# Lorient	-> Lorient =  1.0? (y/n)y
# Lens	-> Lens =  1.0? (y/n)y
# Cádiz	-> Cadiz =  0.8? (y/n)y
# Leeds United	-> Sheffield United =  0.7142857142857143? (y/n)n
# Leeds United	-> Newcastle United =  0.6428571428571429? (y/n)n
# Leeds United	-> Manchester United =  0.6206896551724138? (y/n)n
# Leeds United	-> Leeds =  0.5882352941176471? (y/n)y
# Elche	-> Elche =  1.0? (y/n)y
# Arminia	-> Amiens =  0.6153846153846154? (y/n)n
# Arminia	-> Arminia Bielefeld =  0.5833333333333334? (y/n)y
# Spezia	-> Spezia =  1.0? (y/n)y

# %%
import pickle
f = open("final_col_map.pkl","wb")
pickle.dump(final_col_map,f)
f.close()

# %%
import pickle
f = open("final_col_map.pkl","rb")
final_col_map = pickle.load(f)
f.close()

# %%
len(final_col_map.keys())
# Out:
# 129

# %%
len(set(final_col_map.values()))
# Out:
# 129

# %%
map_fbref_us = final_col_map

# %%
map_us_fbref = {}
for fbref_team in map_fbref_us:
    map_us_fbref[map_fbref_us[fbref_team]] = fbref_team

# %%
df['h_title'] = df['h_title'].replace(map_us_fbref)
df['a_title'] = df['a_title'].replace(map_us_fbref)
# Out:
# /opt/anaconda3/envs/general/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/general/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = df.rename(columns = {
    'h_title': 'Team_Home',
    'a_title': 'Team_Away',
    'xG_h': 'xg_Home',
    'xG_a': 'xg_Away',
    'datetime': 'Date',
    'forecast_w': 'Prob_Home',
    'forecast_l': 'Prob_Away',
    'season': 'Season',
    'league': 'League'
}).drop(['goals_h', 'goals_a', 'forecast_d'], 1)
df
# Out:
#            Team_Home        Team_Away   xg_Home   xg_Away        Date  \
# 11641         Monaco         Toulouse  2.146360  0.248798  2017-08-04
# 11640      Paris S-G           Amiens  2.252640  0.190301  2017-08-05
# 11638    Montpellier             Caen  1.461790  0.319240  2017-08-05
# 11637           Lyon       Strasbourg  1.727830  0.292445  2017-08-05
# 11636  Saint-Étienne             Nice  0.943684  0.593773  2017-08-05
# ...              ...              ...       ...       ...         ...
# 7512   Hellas Verona           Spezia  2.041220  1.176410  2021-05-01
# 2707           Elche  Atlético Madrid  1.381180  1.015160  2021-05-01
# 10160      Paris S-G             Lens  1.377640  1.514980  2021-05-01
# 7511         Crotone            Inter  0.759966  2.341690  2021-05-01
# 2706          Huesca    Real Sociedad  0.446278  0.298366  2021-05-01
#
#        Prob_Home  Prob_Away     Season   League
# 11641     0.8672     0.0223  2017-2018  Ligue_1
# 11640     0.8981     0.0144  2017-2018  Ligue_1
# 11638     0.7392     0.0547  2017-2018  Ligue_1
# 11637     0.8120     0.0327  2017-2018  Ligue_1
# 11636     0.4413     0.1732  2017-2018  Ligue_1
# ...          ...        ...        ...      ...
# 7512      0.6142     0.1601  2020-2021  Serie_A
# 2707      0.4723     0.2161  2020-2021  La_liga
# 10160     0.3156     0.4107  2020-2021  Ligue_1
# 7511      0.0715     0.7642  2020-2021  Serie_A
# 2706      0.2880     0.1737  2020-2021  La_liga
#
# [6987 rows x 9 columns]

# %%
df['League'].unique()
# Out:
# array(['Ligue_1', 'EPL', 'La_liga', 'Bundesliga', 'Serie_A'], dtype=object)

# %%
league_us_fbref = {
    'Ligue_1': 'Ligue1',
    'EPL': 'EPL',
    'La_liga': 'LaLiga',
    'Serie_A': 'SerieA',
    'Bundesliga': 'Bundesliga'
}
df['League'] = df['League'].replace(league_us_fbref)

# %%
col_replace2 = {}
for col in df.columns:
    if col not in ['Season', 'Date', 'League', 'Team_Home', 'Team_Away']:
        col_replace2[col] = 'US'+col
col_replace2
# Out:
# {'xg_Home': 'USxg_Home',
#  'xg_Away': 'USxg_Away',
#  'Prob_Home': 'USProb_Home',
#  'Prob_Away': 'USProb_Away'}

# %%
df = df.rename(columns=col_replace2)
df
# Out:
#            Team_Home        Team_Away  USxg_Home  USxg_Away        Date  \
# 11641         Monaco         Toulouse   2.146360   0.248798  2017-08-04
# 11640      Paris S-G           Amiens   2.252640   0.190301  2017-08-05
# 11638    Montpellier             Caen   1.461790   0.319240  2017-08-05
# 11637           Lyon       Strasbourg   1.727830   0.292445  2017-08-05
# 11636  Saint-Étienne             Nice   0.943684   0.593773  2017-08-05
# ...              ...              ...        ...        ...         ...
# 7512   Hellas Verona           Spezia   2.041220   1.176410  2021-05-01
# 2707           Elche  Atlético Madrid   1.381180   1.015160  2021-05-01
# 10160      Paris S-G             Lens   1.377640   1.514980  2021-05-01
# 7511         Crotone            Inter   0.759966   2.341690  2021-05-01
# 2706          Huesca    Real Sociedad   0.446278   0.298366  2021-05-01
#
#        USProb_Home  USProb_Away     Season  League
# 11641       0.8672       0.0223  2017-2018  Ligue1
# 11640       0.8981       0.0144  2017-2018  Ligue1
# 11638       0.7392       0.0547  2017-2018  Ligue1
# 11637       0.8120       0.0327  2017-2018  Ligue1
# 11636       0.4413       0.1732  2017-2018  Ligue1
# ...            ...          ...        ...     ...
# 7512        0.6142       0.1601  2020-2021  SerieA
# 2707        0.4723       0.2161  2020-2021  LaLiga
# 10160       0.3156       0.4107  2020-2021  Ligue1
# 7511        0.0715       0.7642  2020-2021  SerieA
# 2706        0.2880       0.1737  2020-2021  LaLiga
#
# [6987 rows x 9 columns]

# %%
df.to_csv('../final_data/understat/matches.csv', index = False)
