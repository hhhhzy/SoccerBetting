# %%
import pandas as pd

# %%
fbref_df = pd.read_csv('fbref/merged_ODrating_fbref.csv', parse_dates=['Date']).sort_values('Date')
understat_df = pd.read_csv('understat/matches.csv', parse_dates=['Date']).sort_values('Date')
_538_df = pd.read_csv('538/matches.csv', parse_dates=['Date']).sort_values('Date')
fbdata_df = pd.read_csv('fbdata/matches.csv', parse_dates=['Date']).sort_values('Date')

# %%
fbref_df.head(1)
# Out:
#       League     Season       Date Team_Home  FBREFPossession_Home  \
# 4132  Ligue1  2017-2018 2017-08-04    Monaco                    71
#
#       FBREFSave%_Home  Goals_Home  FBREFAst_Home  FBREFPK_Home  \
# 4132             33.3           3              3             0
#
#       FBREFPKatt_Home  ...  FBREFCrdY_Away  FBREFCrdR_Away  FBREFxg_away  \
# 4132                0  ...               3               0           0.3
#
#       FBREFxa_Away  FBREFSCA_Away  FBREFGCA_Away  FBREFORating_Home  \
# 4132           0.3           11.0            4.0           1.211652
#
#       FBREFDRating_Home FBREFORating_Away  FBREFDRating_Away
# 4132           1.166637          0.975881           1.103493
#
# [1 rows x 37 columns]

# %%
understat_df.head(1)
# Out:
#   Team_Home Team_Away  USxg_Home  USxg_Away       Date  USProb_Home  \
# 0    Monaco  Toulouse    2.14636   0.248798 2017-08-04       0.8672
#
#    USProb_Away     Season  League
# 0       0.0223  2017-2018  Ligue1

# %%
 len(fbref_df),  len(understat_df)
# Out:
# (6979, 6987)

# %%
merge1 = pd.merge(fbref_df, understat_df, on = ['League', 'Season', 'Team_Home', 'Team_Away', 'Date'], how = 'inner')
merge1
# Out:
#       League     Season       Date      Team_Home  FBREFPossession_Home  \
# 0     Ligue1  2017-2018 2017-08-04         Monaco                    71
# 1     Ligue1  2017-2018 2017-08-05           Lyon                    62
# 2     Ligue1  2017-2018 2017-08-05         Troyes                    38
# 3     Ligue1  2017-2018 2017-08-05    Montpellier                    52
# 4     Ligue1  2017-2018 2017-08-05  Saint-Étienne                    41
# ...      ...        ...        ...            ...                   ...
# 6964  SerieA  2020-2021 2021-04-26          Lazio                    41
# 6965  SerieA  2020-2021 2021-04-26         Torino                    47
# 6966  LaLiga  2020-2021 2021-04-26          Eibar                    53
# 6967  LaLiga  2020-2021 2021-04-28  Athletic Club                    50
# 6968  LaLiga  2020-2021 2021-04-29      Barcelona                    81
#
#       FBREFSave%_Home  Goals_Home  FBREFAst_Home  FBREFPK_Home  \
# ...

# %%
merge2 = pd.merge(merge1, _538_df, on = ['League', 'Season', 'Team_Home', 'Team_Away', 'Date'], how = 'inner')
merge2
# Out:
#       League     Season       Date      Team_Home  FBREFPossession_Home  \
# 0     Ligue1  2017-2018 2017-08-04         Monaco                    71
# 1     Ligue1  2017-2018 2017-08-05           Lyon                    62
# 2     Ligue1  2017-2018 2017-08-05         Troyes                    38
# 3     Ligue1  2017-2018 2017-08-05    Montpellier                    52
# 4     Ligue1  2017-2018 2017-08-05  Saint-Étienne                    41
# ...      ...        ...        ...            ...                   ...
# 6919  SerieA  2020-2021 2021-04-26          Lazio                    41
# 6920  SerieA  2020-2021 2021-04-26         Torino                    47
# 6921  LaLiga  2020-2021 2021-04-26          Eibar                    53
# 6922  LaLiga  2020-2021 2021-04-28  Athletic Club                    50
# 6923  LaLiga  2020-2021 2021-04-29      Barcelona                    81
#
#       FBREFSave%_Home  Goals_Home  FBREFAst_Home  FBREFPK_Home  \
# ...

# %%
merge3 = pd.merge(merge2, fbdata_df, on = ['League', 'Season', 'Team_Home', 'Team_Away', 'Date'], how = 'inner')
merge3
# Out:
#       League     Season       Date      Team_Home  FBREFPossession_Home  \
# 0     Ligue1  2017-2018 2017-08-04         Monaco                    71
# 1     Ligue1  2017-2018 2017-08-05           Lyon                    62
# 2     Ligue1  2017-2018 2017-08-05         Troyes                    38
# 3     Ligue1  2017-2018 2017-08-05    Montpellier                    52
# 4     Ligue1  2017-2018 2017-08-05  Saint-Étienne                    41
# ...      ...        ...        ...            ...                   ...
# 6919  SerieA  2020-2021 2021-04-26          Lazio                    41
# 6920  SerieA  2020-2021 2021-04-26         Torino                    47
# 6921  LaLiga  2020-2021 2021-04-26          Eibar                    53
# 6922  LaLiga  2020-2021 2021-04-28  Athletic Club                    50
# 6923  LaLiga  2020-2021 2021-04-29      Barcelona                    81
#
#       FBREFSave%_Home  Goals_Home_x  FBREFAst_Home  FBREFPK_Home  \
# ...

# %%
merge3.to_csv('final_data.csv', index = False)

# %%
for col in merge3.columns:
    if 'Prob' in col:
        print(col)
# Out:
# USProb_Home
# USProb_Away
# 538Prob_Home
# 538Prob_Away
