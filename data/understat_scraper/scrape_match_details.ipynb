# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

import os
from pathlib import Path

from tqdm.auto import tqdm

# %%
from diskcache import Cache

cache = Cache("match_details.shelve")

@cache.memoize()
def get_page(link):
    print(link)
    return requests.get(link).content

# %%
import sys
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
matches_df = pd.read_csv(f'dfs/matches.csv', parse_dates=['datetime'])
leagues = matches_df['league'].unique()

# %%
base_url = 'https://understat.com/match/'

dfs = []

for _, row in tqdm(matches_df.iterrows()):
    if row['h_short_title'] == 'BAS' and row['a_short_title'] == 'LYO' and row['datetime'] == pd.Timestamp(2017,4,16):
        continue
    if row['isResult'] == True:
        match_id = row['id']
        url = base_url + str(match_id)

        #Use requests to get the webpage and BeautifulSoup to parse the page
        res = get_page(url)
        soup = BeautifulSoup(res, 'lxml')
        scripts = soup.find_all('script')

        #get only the shotsData
        strings = scripts[1].string
        # strip unnecessary symbols and get only JSON data 
        ind_start = strings.index("('")+2 
        ind_end = strings.index("')") 
        json_data = strings[ind_start:ind_end] 
        json_data = json_data.encode('utf8').decode('unicode_escape')

        #convert string to json format
        data = json.loads(json_data)
        data_home = data['h']
        data_away = data['a']

        df_h = pd.DataFrame(data_home)
        df_h['season'] = row['season']
        df_h['league'] = row['league']
        df_h['HomeAway'] = 'Home'

        df_a = pd.DataFrame(data_away)
        df_a['season'] = row['season']
        df_a['league'] = row['league']
        df_a['HomeAway'] = 'Away'

        df = pd.concat([df_h, df_a])

        dfs.append(df)
        
merged_df = pd.concat(dfs)
merged_df.to_csv(f'dfs/shots.csv', index=False)
# Out:
# 0it [00:00, ?it/s]
# https://understat.com/match/4241
# https://understat.com/match/4240
# https://understat.com/match/4235
# https://understat.com/match/4244
# https://understat.com/match/4243
# https://understat.com/match/4236
# https://understat.com/match/4239
# https://understat.com/match/4229
# https://understat.com/match/4226
# https://understat.com/match/4232
# https://understat.com/match/4230
# https://understat.com/match/4225
# https://understat.com/match/4227
# https://understat.com/match/4231
# https://understat.com/match/4234
# https://understat.com/match/4233
# https://understat.com/match/4228
# https://understat.com/match/3231
# https://understat.com/match/4217
# https://understat.com/match/4222
# https://understat.com/match/4216
# https://understat.com/match/4215
# https://understat.com/match/4220
# https://understat.com/match/4219
# https://understat.com/match/4218
# https://understat.com/match/4224
# https://understat.com/match/4213
# https://understat.com/match/4212
# https://understat.com/match/4206
# https://understat.com/match/4211
# https://understat.com/match/4210
# https://understat.com/match/4208
# https://understat.com/match/4207
# https://understat.com/match/4209
# https://understat.com/match/4214
# https://understat.com/match/4205
# https://understat.com/match/4199
# https://understat.com/match/4203
# https://understat.com/match/4196
# https://understat.com/match/4204
# https://understat.com/match/4200
# https://understat.com/match/4197
# https://understat.com/match/4195
# https://understat.com/match/4198
# https://understat.com/match/4202
# https://understat.com/match/4201
# https://understat.com/match/4192
# https://understat.com/match/4191
# https://understat.com/match/4185
# https://understat.com/match/4190
# https://understat.com/match/4187
# https://understat.com/match/4189
# https://understat.com/match/4194
# https://understat.com/match/4193
# https://understat.com/match/4188
# https://understat.com/match/4186
# https://understat.com/match/4151
# https://understat.com/match/4179
# https://understat.com/match/4180
# https://understat.com/match/4176
# https://understat.com/match/4177
# https://understat.com/match/4175
# https://understat.com/match/4182
# https://understat.com/match/4181
# https://understat.com/match/4184
# https://understat.com/match/4178
# https://understat.com/match/4183
# https://understat.com/match/4117
# https://understat.com/match/4170
# https://understat.com/match/4169
# https://understat.com/match/4167
# https://understat.com/match/4166
# https://understat.com/match/4172
# https://understat.com/match/4165
# https://understat.com/match/4174
# https://understat.com/match/4173
# https://understat.com/match/4168
# https://understat.com/match/4171
# https://understat.com/match/4163
# https://understat.com/match/4156
# https://understat.com/match/4161
# https://understat.com/match/4159
# https://understat.com/match/4155
# https://understat.com/match/4158
# https://understat.com/match/4160
# https://understat.com/match/4162
# https://understat.com/match/4164
# https://understat.com/match/4157
# https://understat.com/match/4148
# https://understat.com/match/4154
# https://understat.com/match/4152
# https://understat.com/match/4149
# https://understat.com/match/4147
# https://understat.com/match/4145
# https://understat.com/match/4150
# https://understat.com/match/4153
# https://understat.com/match/4146
# https://understat.com/match/4135
# https://understat.com/match/4142
# https://understat.com/match/4140
# https://understat.com/match/4143
# https://understat.com/match/4139
# https://understat.com/match/4138
# https://understat.com/match/4137
# https://understat.com/match/4136
# https://understat.com/match/4141
# https://understat.com/match/4144
# https://understat.com/match/4134
# https://understat.com/match/4131
# https://understat.com/match/4127
# https://understat.com/match/4129
# https://understat.com/match/4128
# https://understat.com/match/4126
# https://understat.com/match/4125
# https://understat.com/match/4133
# https://understat.com/match/4130
# https://understat.com/match/4132
# https://understat.com/match/4124
# https://understat.com/match/4123
# https://understat.com/match/4122
# https://understat.com/match/4121
# https://understat.com/match/4120
# https://understat.com/match/4119
# https://understat.com/match/4118
# https://understat.com/match/4116
# https://understat.com/match/4115
# https://understat.com/match/3243
# https://understat.com/match/4114
# https://understat.com/match/4113
# https://understat.com/match/4112
# https://understat.com/match/4110
# https://understat.com/match/4108
# https://understat.com/match/4111
# https://understat.com/match/4109
# https://understat.com/match/4107
# https://understat.com/match/4106
# https://understat.com/match/4105
# https://understat.com/match/3264
# https://understat.com/match/3259
# https://understat.com/match/3261
# https://understat.com/match/3262
# https://understat.com/match/3263
# https://understat.com/match/3260
# https://understat.com/match/3265
# https://understat.com/match/3266
# https://understat.com/match/3267
# https://understat.com/match/3268
# https://understat.com/match/3258
# https://understat.com/match/3257
# https://understat.com/match/3256
# https://understat.com/match/3251
# https://understat.com/match/3255
# https://understat.com/match/3254
# https://understat.com/match/3253
# https://understat.com/match/3252
# https://understat.com/match/3250
# https://understat.com/match/3249
# https://understat.com/match/3248
# https://understat.com/match/3247
# https://understat.com/match/3246
# https://understat.com/match/3245
# https://understat.com/match/3244
# https://understat.com/match/3242
# https://understat.com/match/3241
# https://understat.com/match/3240
# https://understat.com/match/3239
# https://understat.com/match/3238
# https://understat.com/match/3237
# https://understat.com/match/3236
# https://understat.com/match/3233
# https://understat.com/match/3232
# https://understat.com/match/3235
# https://understat.com/match/3234
# https://understat.com/match/3230
# https://understat.com/match/3229
# https://understat.com/match/3228
# https://understat.com/match/2869
# https://understat.com/match/2868
# https://understat.com/match/2866
# https://understat.com/match/2870
# https://understat.com/match/2871
# https://understat.com/match/2867
# https://understat.com/match/2865
# https://understat.com/match/2864
# https://understat.com/match/2863
# https://understat.com/match/2862
# https://understat.com/match/2861
# https://understat.com/match/2860
# https://understat.com/match/2855
# https://understat.com/match/2859
# https://understat.com/match/2858
# https://understat.com/match/2857
# https://understat.com/match/2856
# https://understat.com/match/2854
# https://understat.com/match/2853
# https://understat.com/match/2852
# https://understat.com/match/2851
# https://understat.com/match/2850
# https://understat.com/match/2849
# https://understat.com/match/2848
# https://understat.com/match/2847
# https://understat.com/match/2846
# https://understat.com/match/2845
# https://understat.com/match/2844
# https://understat.com/match/2843
# https://understat.com/match/2842
# https://understat.com/match/2841
# https://understat.com/match/2840
# https://understat.com/match/2839
# https://understat.com/match/2838
# https://understat.com/match/2837
# https://understat.com/match/2836
# https://understat.com/match/2835
# https://understat.com/match/2834
# https://understat.com/match/2833
# https://understat.com/match/3327
# https://understat.com/match/3326
# https://understat.com/match/3325
# https://understat.com/match/3324
# https://understat.com/match/3323
# https://understat.com/match/3322
# https://understat.com/match/3321
# https://understat.com/match/3320
# https://understat.com/match/3319
# https://understat.com/match/3318
# https://understat.com/match/2348
# https://understat.com/match/2347
# https://understat.com/match/2346
# https://understat.com/match/2341
# https://understat.com/match/2342
# https://understat.com/match/2344
# https://understat.com/match/2345
# https://understat.com/match/2343
# https://understat.com/match/2340
# https://understat.com/match/2339
# https://understat.com/match/2338
# https://understat.com/match/2337
# https://understat.com/match/2336
# https://understat.com/match/2334
# https://understat.com/match/2333
# https://understat.com/match/2332
# https://understat.com/match/2335
# https://understat.com/match/2331
# https://understat.com/match/2330
# https://understat.com/match/2329
# https://understat.com/match/2328
# https://understat.com/match/2327
# https://understat.com/match/2326
# https://understat.com/match/2321
# https://understat.com/match/2325
# https://understat.com/match/2324
# https://understat.com/match/2323
# https://understat.com/match/2322
# https://understat.com/match/2320
# https://understat.com/match/2319
# https://understat.com/match/2318
# https://understat.com/match/2317
# https://understat.com/match/2316
# https://understat.com/match/2315
# https://understat.com/match/2314
# https://understat.com/match/2313
# https://understat.com/match/2312
# https://understat.com/match/2311
# https://understat.com/match/2310
# https://understat.com/match/2309
# https://understat.com/match/2308
# https://understat.com/match/2307
# https://understat.com/match/2306
# https://understat.com/match/2305
# https://understat.com/match/2304
# https://understat.com/match/2303
# https://understat.com/match/2302
# https://understat.com/match/2301
# https://understat.com/match/2300
# https://understat.com/match/2299
# https://understat.com/match/2298
# https://understat.com/match/2297
# https://understat.com/match/2296
# https://understat.com/match/2295
# https://understat.com/match/2294
# https://understat.com/match/2293
# https://understat.com/match/2292
# https://understat.com/match/2291
# https://understat.com/match/2290
# https://understat.com/match/2289
# https://understat.com/match/2288
# https://understat.com/match/2287
# https://understat.com/match/2286
# https://understat.com/match/2283
# https://understat.com/match/2281
# https://understat.com/match/2282
# https://understat.com/match/2285
# https://understat.com/match/2284
# https://understat.com/match/2280
# https://understat.com/match/2279
# https://understat.com/match/2278
# https://understat.com/match/2277
# https://understat.com/match/2276
# https://understat.com/match/2273
# https://understat.com/match/2271
# https://understat.com/match/2272
# https://understat.com/match/2274
# https://understat.com/match/2275
# https://understat.com/match/2270
# https://understat.com/match/2269
# https://understat.com/match/2268
# https://understat.com/match/2267
# https://understat.com/match/2266
# https://understat.com/match/2262
# https://understat.com/match/2261
# https://understat.com/match/2263
# https://understat.com/match/2264
# https://understat.com/match/2265
# https://understat.com/match/2260
# https://understat.com/match/2259
# https://understat.com/match/2258
# https://understat.com/match/2257
# https://understat.com/match/2256
# https://understat.com/match/2254
# https://understat.com/match/2253
# https://understat.com/match/2252
# https://understat.com/match/2255
# https://understat.com/match/2251
# https://understat.com/match/2250
# https://understat.com/match/2249
# https://understat.com/match/2248
# https://understat.com/match/2243
# https://understat.com/match/2240
# https://understat.com/match/2241
# https://understat.com/match/2242
# https://understat.com/match/2239
# https://understat.com/match/2244
# https://understat.com/match/2245
# https://understat.com/match/2246
# https://understat.com/match/2247
# https://understat.com/match/2238
# https://understat.com/match/2228
# https://understat.com/match/2237
# https://understat.com/match/2236
# https://understat.com/match/2235
# https://understat.com/match/2234
# https://understat.com/match/2233
# https://understat.com/match/2232
# https://understat.com/match/2231
# https://understat.com/match/2230
# https://understat.com/match/2229
# https://understat.com/match/2227
# https://understat.com/match/2226
# https://understat.com/match/2225
# https://understat.com/match/2224
# https://understat.com/match/2223
# https://understat.com/match/2222
# https://understat.com/match/2221
# https://understat.com/match/2220
# https://understat.com/match/2219
# https://understat.com/match/2218
# https://understat.com/match/2217
# https://understat.com/match/2216
# https://understat.com/match/2215
# https://understat.com/match/2214
# https://understat.com/match/2213
# https://understat.com/match/2212
# https://understat.com/match/2211
# https://understat.com/match/2210
# https://understat.com/match/2209
# https://understat.com/match/2208
# https://understat.com/match/2207
# https://understat.com/match/2206
# https://understat.com/match/2202
# https://understat.com/match/2201
# https://understat.com/match/2203
# https://understat.com/match/2205
# https://understat.com/match/2204
# https://understat.com/match/2200
# https://understat.com/match/2199
# https://understat.com/match/2198
# https://understat.com/match/2197
# https://understat.com/match/2196
# https://understat.com/match/2192
# https://understat.com/match/2193
# https://understat.com/match/2191
# https://understat.com/match/2194
# https://understat.com/match/2195
# https://understat.com/match/2190
# https://understat.com/match/2189
# https://understat.com/match/2188
# https://understat.com/match/2187
# https://understat.com/match/2186
# https://understat.com/match/2184
# https://understat.com/match/2183
# https://understat.com/match/2181
# https://understat.com/match/2185
# https://understat.com/match/2182
# https://understat.com/match/2180
# https://understat.com/match/2179
# https://understat.com/match/2178
# https://understat.com/match/2177
# https://understat.com/match/2176
# https://understat.com/match/2175
# https://understat.com/match/2174
# https://understat.com/match/2173
# https://understat.com/match/2172
# https://understat.com/match/2171
# https://understat.com/match/2170
# https://understat.com/match/2169
# https://understat.com/match/2168
# https://understat.com/match/2167
# https://understat.com/match/2166
# https://understat.com/match/2165
# https://understat.com/match/2164
# https://understat.com/match/2163
# https://understat.com/match/2162
# https://understat.com/match/2161
# https://understat.com/match/2160
# https://understat.com/match/2159
# https://understat.com/match/2158
# https://understat.com/match/2157
# https://understat.com/match/2156
# https://understat.com/match/2155
# https://understat.com/match/2154
# https://understat.com/match/2153
# https://understat.com/match/2152
# https://understat.com/match/2151
# https://understat.com/match/2150
# https://understat.com/match/2149
# https://understat.com/match/2148
# https://understat.com/match/2147
# https://understat.com/match/2146
# https://understat.com/match/2145
# https://understat.com/match/2144
# https://understat.com/match/2143
# https://understat.com/match/2142
# https://understat.com/match/2141
# https://understat.com/match/2140
# https://understat.com/match/2139
# https://understat.com/match/2138
# https://understat.com/match/2137
# https://understat.com/match/2136
# https://understat.com/match/2135
# https://understat.com/match/2133
# https://understat.com/match/2131
# https://understat.com/match/2132
# https://understat.com/match/2134
# https://understat.com/match/2130
# https://understat.com/match/2129
# https://understat.com/match/2128
# https://understat.com/match/2127
# https://understat.com/match/2126
# https://understat.com/match/2121
# https://understat.com/match/2123
# https://understat.com/match/2122
# https://understat.com/match/2124
# https://understat.com/match/2125
# https://understat.com/match/2120
# https://understat.com/match/2119
# https://understat.com/match/2118
# https://understat.com/match/2117
# https://understat.com/match/2116
# https://understat.com/match/2111
# https://understat.com/match/2115
# https://understat.com/match/2114
# https://understat.com/match/2113
# https://understat.com/match/2112
# https://understat.com/match/2110
# https://understat.com/match/2109
# https://understat.com/match/2108
# https://understat.com/match/2107
# https://understat.com/match/2106
# https://understat.com/match/2105
# https://understat.com/match/2104
# https://understat.com/match/2103
# https://understat.com/match/2102
# https://understat.com/match/2101
# https://understat.com/match/2100
# https://understat.com/match/2099
# https://understat.com/match/2098
# https://understat.com/match/2097
# https://understat.com/match/2096
# https://understat.com/match/2095
# https://understat.com/match/2094
# https://understat.com/match/2093
# https://understat.com/match/2092
# https://understat.com/match/2091
# https://understat.com/match/2090
# https://understat.com/match/2089
# https://understat.com/match/2088
# https://understat.com/match/2087
# https://understat.com/match/2086
# https://understat.com/match/2085
# https://understat.com/match/2084
# https://understat.com/match/2083
# https://understat.com/match/2082
# https://understat.com/match/2081
# https://understat.com/match/2080
# https://understat.com/match/2079
# https://understat.com/match/2078
# https://understat.com/match/2077
# https://understat.com/match/2076
# https://understat.com/match/2075
# https://understat.com/match/2074
# https://understat.com/match/2073
# https://understat.com/match/2072
# https://understat.com/match/2071
# https://understat.com/match/2070
# https://understat.com/match/2069
# https://understat.com/match/2068
# https://understat.com/match/2067
# https://understat.com/match/2066
# https://understat.com/match/2063
# https://understat.com/match/2062
# https://understat.com/match/2061
# https://understat.com/match/2064
# https://understat.com/match/2065
# https://understat.com/match/2060
# https://understat.com/match/2059
# https://understat.com/match/2058
# https://understat.com/match/2057
# https://understat.com/match/2056
# https://understat.com/match/2055
# https://understat.com/match/2054
# https://understat.com/match/2053
# https://understat.com/match/2052
# https://understat.com/match/2051
# https://understat.com/match/2050
# https://understat.com/match/2049
# https://understat.com/match/2048
# https://understat.com/match/2047
# https://understat.com/match/2046
# https://understat.com/match/2045
# https://understat.com/match/2044
# https://understat.com/match/2043
# https://understat.com/match/2042
# https://understat.com/match/2041
# https://understat.com/match/2040
# https://understat.com/match/2039
# https://understat.com/match/2038
# https://understat.com/match/2037
# https://understat.com/match/2036
# https://understat.com/match/2035
# https://understat.com/match/2034
# https://understat.com/match/2033
# https://understat.com/match/2032
# https://understat.com/match/2031
# https://understat.com/match/2030
# https://understat.com/match/2029
# https://understat.com/match/2028
# https://understat.com/match/2027
# https://understat.com/match/2024
# https://understat.com/match/2022
# https://understat.com/match/2023
# https://understat.com/match/2026
# https://understat.com/match/2025
# https://understat.com/match/2021
# https://understat.com/match/2020
# https://understat.com/match/2019
# https://understat.com/match/2018
# https://understat.com/match/2017
# https://understat.com/match/2016
# https://understat.com/match/2012
# https://understat.com/match/2011
# https://understat.com/match/2013
# https://understat.com/match/2014
# https://understat.com/match/2015
# https://understat.com/match/2010
# https://understat.com/match/2009
# https://understat.com/match/2008
# https://understat.com/match/2007
# https://understat.com/match/2006
# https://understat.com/match/2005
# https://understat.com/match/2002
# https://understat.com/match/2001
# https://understat.com/match/2004
# https://understat.com/match/2003
# https://understat.com/match/2000
# https://understat.com/match/1999
# https://understat.com/match/1998
# https://understat.com/match/1997
# https://understat.com/match/1996
# https://understat.com/match/1994
# https://understat.com/match/1993
# https://understat.com/match/1991
# https://understat.com/match/1995
# https://understat.com/match/1992
# https://understat.com/match/1990
# https://understat.com/match/1989
# https://understat.com/match/1988
# https://understat.com/match/1987
# https://understat.com/match/1986
# https://understat.com/match/1985
# https://understat.com/match/1980
# https://understat.com/match/1982
# https://understat.com/match/1981
# https://understat.com/match/1983
# https://understat.com/match/1984
# https://understat.com/match/1979
# https://understat.com/match/1978
# https://understat.com/match/1977
# https://understat.com/match/1976
# https://understat.com/match/1975
# https://understat.com/match/1974
# https://understat.com/match/1971
# https://understat.com/match/1973
# https://understat.com/match/1972
# https://understat.com/match/1970
# https://understat.com/match/1969
# https://understat.com/match/1968
# https://understat.com/match/1967
# https://understat.com/match/1966
# https://understat.com/match/1965
# https://understat.com/match/1960
# https://understat.com/match/1962
# https://understat.com/match/1961
# https://understat.com/match/1964
# https://understat.com/match/1963
# https://understat.com/match/1959
# https://understat.com/match/1958
# https://understat.com/match/1957
# https://understat.com/match/1956
# https://understat.com/match/1955
# https://understat.com/match/1954
# https://understat.com/match/1951
# https://understat.com/match/1952
# https://understat.com/match/1953
# https://understat.com/match/1950
# https://understat.com/match/1949
# https://understat.com/match/1948
# https://understat.com/match/1947
# https://understat.com/match/1946
# https://understat.com/match/1945
# https://understat.com/match/1944
# https://understat.com/match/1942
# https://understat.com/match/1941
# https://understat.com/match/1940
# https://understat.com/match/1943
# https://understat.com/match/1939
# https://understat.com/match/1938
# https://understat.com/match/1937
# https://understat.com/match/1936
# https://understat.com/match/1931
# https://understat.com/match/1935
# https://understat.com/match/1934
# https://understat.com/match/1933
# https://understat.com/match/1932
# https://understat.com/match/1930
# https://understat.com/match/1929
# https://understat.com/match/1928
# https://understat.com/match/1927
# https://understat.com/match/1926
# https://understat.com/match/1925
# https://understat.com/match/1924
# https://understat.com/match/1923
# https://understat.com/match/1922
# https://understat.com/match/1921
# https://understat.com/match/1920
# https://understat.com/match/1919
# https://understat.com/match/1918
# https://understat.com/match/1917
# https://understat.com/match/1916
# https://understat.com/match/1915
# https://understat.com/match/1914
# https://understat.com/match/1913
# https://understat.com/match/1912
# https://understat.com/match/1911
# https://understat.com/match/1910
# https://understat.com/match/1909
# https://understat.com/match/1908
# https://understat.com/match/1907
# https://understat.com/match/1906
# https://understat.com/match/1903
# https://understat.com/match/1901
# https://understat.com/match/1902
# https://understat.com/match/1905
# https://understat.com/match/1904
# https://understat.com/match/1900
# https://understat.com/match/1899
# https://understat.com/match/1898
# https://understat.com/match/1897
# https://understat.com/match/1896
# https://understat.com/match/1891
# https://understat.com/match/1893
# https://understat.com/match/1892
# https://understat.com/match/1895
# https://understat.com/match/1894
# https://understat.com/match/1890
# https://understat.com/match/1889
# https://understat.com/match/1888
# https://understat.com/match/1887
# https://understat.com/match/1886
# https://understat.com/match/1883
# https://understat.com/match/1881
# https://understat.com/match/1882
# https://understat.com/match/1884
# https://understat.com/match/1885
# https://understat.com/match/1880
# https://understat.com/match/1879
# https://understat.com/match/1878
# https://understat.com/match/1877
# https://understat.com/match/1876
# https://understat.com/match/1871
# https://understat.com/match/1873
# https://understat.com/match/1872
# https://understat.com/match/1870
# https://understat.com/match/1874
# https://understat.com/match/1875
# https://understat.com/match/1869
# https://understat.com/match/5884
# https://understat.com/match/5883
# https://understat.com/match/5882
# https://understat.com/match/5881
# https://understat.com/match/5880
# https://understat.com/match/5879
# https://understat.com/match/5878
# https://understat.com/match/5877
# https://understat.com/match/5876
# https://understat.com/match/5875
# https://understat.com/match/5869
# https://understat.com/match/5865
# https://understat.com/match/5866
# https://understat.com/match/5867
# https://understat.com/match/5868
# https://understat.com/match/5874
# https://understat.com/match/5870
# https://understat.com/match/5871
# https://understat.com/match/5872
# https://understat.com/match/5873
# https://understat.com/match/5864
# https://understat.com/match/5863
# https://understat.com/match/5862
# https://understat.com/match/5860
# https://understat.com/match/5859
# https://understat.com/match/5858
# https://understat.com/match/5857
# https://understat.com/match/5861
# https://understat.com/match/5856
# https://understat.com/match/5855
# https://understat.com/match/5854
# https://understat.com/match/5853
# https://understat.com/match/5852
# https://understat.com/match/5850
# https://understat.com/match/5848
# https://understat.com/match/5847
# https://understat.com/match/5851
# https://understat.com/match/5849
# https://understat.com/match/5846
# https://understat.com/match/5845
# https://understat.com/match/5925
# https://understat.com/match/5924
# https://understat.com/match/5923
# https://understat.com/match/5922
# https://understat.com/match/5917
# https://understat.com/match/5919
# https://understat.com/match/5918
# https://understat.com/match/5920
# https://understat.com/match/5921
# https://understat.com/match/5916
# https://understat.com/match/5915
# https://understat.com/match/5914
# https://understat.com/match/5913
# https://understat.com/match/5912
# https://understat.com/match/5908
# https://understat.com/match/5909
# https://understat.com/match/5907
# https://understat.com/match/5910
# https://understat.com/match/5911
# https://understat.com/match/5906
# https://understat.com/match/5905
# https://understat.com/match/5904
# https://understat.com/match/5903
# https://understat.com/match/5900
# https://understat.com/match/5899
# https://understat.com/match/5898
# https://understat.com/match/5901
# https://understat.com/match/5902
# https://understat.com/match/5897
# https://understat.com/match/5896
# https://understat.com/match/5895
# https://understat.com/match/5894
# https://understat.com/match/5893
# https://understat.com/match/5892
# https://understat.com/match/5887
# https://understat.com/match/5891
# https://understat.com/match/5890
# https://understat.com/match/5889
# https://understat.com/match/5888
# https://understat.com/match/5886
# https://understat.com/match/5885
# https://understat.com/match/5959
# https://understat.com/match/5958
# https://understat.com/match/5957
# https://understat.com/match/5952
# https://understat.com/match/5956
# https://understat.com/match/5955
# https://understat.com/match/5954
# https://understat.com/match/5953
# https://understat.com/match/5951
# https://understat.com/match/5950
# https://understat.com/match/5949
# https://understat.com/match/5948
# https://understat.com/match/5947
# https://understat.com/match/5946
# https://understat.com/match/5945
# https://understat.com/match/5944
# https://understat.com/match/5943
# https://understat.com/match/5942
# https://understat.com/match/5941
# https://understat.com/match/5940
# https://understat.com/match/5939
# https://understat.com/match/5938
# https://understat.com/match/5937
# https://understat.com/match/5934
# https://understat.com/match/5932
# https://understat.com/match/5933
# https://understat.com/match/5935
# https://understat.com/match/5936
# https://understat.com/match/5931
# https://understat.com/match/5930
# https://understat.com/match/5929
# https://understat.com/match/5928
# https://understat.com/match/5927
# https://understat.com/match/5926
# https://understat.com/match/5995
# https://understat.com/match/5993
# https://understat.com/match/5994
# https://understat.com/match/5996
# https://understat.com/match/5997
# https://understat.com/match/5992
# https://understat.com/match/5991
# https://understat.com/match/5990
# https://understat.com/match/5989
# https://understat.com/match/5988
# https://understat.com/match/5987
# https://understat.com/match/5984
# https://understat.com/match/5985
# https://understat.com/match/5986
# https://understat.com/match/5983
# https://understat.com/match/5982
# https://understat.com/match/5981
# https://understat.com/match/5980
# https://understat.com/match/5979
# https://understat.com/match/5975
# https://understat.com/match/5978
# https://understat.com/match/5977
# https://understat.com/match/5976
# https://understat.com/match/5974
# https://understat.com/match/5973
# https://understat.com/match/5972
# https://understat.com/match/5971
# https://understat.com/match/5970
# https://understat.com/match/5969
# https://understat.com/match/5968
# https://understat.com/match/5967
# https://understat.com/match/5966
# https://understat.com/match/5965
# https://understat.com/match/5964
# https://understat.com/match/5963
# https://understat.com/match/5962
# https://understat.com/match/5961
# https://understat.com/match/5960
# https://understat.com/match/6035
# https://understat.com/match/6034
# https://understat.com/match/6033
# https://understat.com/match/6032
# https://understat.com/match/6031
# https://understat.com/match/6030
# https://understat.com/match/6029
# https://understat.com/match/6028
# https://understat.com/match/6026
# https://understat.com/match/6027
# https://understat.com/match/6025
# https://understat.com/match/6024
# https://understat.com/match/6023
# https://understat.com/match/6022
# https://understat.com/match/6021
# https://understat.com/match/6020
# https://understat.com/match/6019
# https://understat.com/match/6018
# https://understat.com/match/6017
# https://understat.com/match/6016
# https://understat.com/match/6015
# https://understat.com/match/6014
# https://understat.com/match/6013
# https://understat.com/match/6012
# https://understat.com/match/6011
# https://understat.com/match/6010
# https://understat.com/match/6009
# https://understat.com/match/6008
# https://understat.com/match/6006
# https://understat.com/match/6007
# https://understat.com/match/6003
# https://understat.com/match/6002
# https://understat.com/match/6001
# https://understat.com/match/6004
# https://understat.com/match/6005
# https://understat.com/match/6000
# https://understat.com/match/5999
# https://understat.com/match/5998
# https://understat.com/match/6075
# https://understat.com/match/6074
# https://understat.com/match/6073
# https://understat.com/match/6072
# https://understat.com/match/6071
# https://understat.com/match/6070
# https://understat.com/match/6069
# https://understat.com/match/6068
# https://understat.com/match/6067
# https://understat.com/match/6066
# https://understat.com/match/6065
# https://understat.com/match/6064
# https://understat.com/match/6063
# https://understat.com/match/6062
# https://understat.com/match/6061
# https://understat.com/match/6060
# https://understat.com/match/6059
# https://understat.com/match/6058
# https://understat.com/match/6057
# https://understat.com/match/6056
# https://understat.com/match/6055
# https://understat.com/match/6053
# https://understat.com/match/6054
# https://understat.com/match/6052
# https://understat.com/match/6051
# https://understat.com/match/6050
# https://understat.com/match/6049
# https://understat.com/match/6048
# https://understat.com/match/6047
# https://understat.com/match/6046
# https://understat.com/match/6045
# https://understat.com/match/6044
# https://understat.com/match/6042
# https://understat.com/match/6040
# https://understat.com/match/6039
# https://understat.com/match/6043
# https://understat.com/match/6041
# https://understat.com/match/6038
# https://understat.com/match/6037
# https://understat.com/match/6036
# https://understat.com/match/6113
# https://understat.com/match/6112
# https://understat.com/match/6111
# https://understat.com/match/6108
# https://understat.com/match/6106
# https://understat.com/match/6107
# https://understat.com/match/6109
# https://understat.com/match/6110
# https://understat.com/match/6105
# https://understat.com/match/6104
# https://understat.com/match/6103
# https://understat.com/match/6102
# https://understat.com/match/6101
# https://understat.com/match/6099
# https://understat.com/match/6098
# https://understat.com/match/6097
# https://understat.com/match/6100
# https://understat.com/match/6096
# https://understat.com/match/6095
# https://understat.com/match/6094
# https://understat.com/match/6093
# https://understat.com/match/6092
# https://understat.com/match/6091
# https://understat.com/match/6090
# https://understat.com/match/6089
# https://understat.com/match/6088
# https://understat.com/match/6087
# https://understat.com/match/6086
# https://understat.com/match/6085
# https://understat.com/match/6084
# https://understat.com/match/6083
# https://understat.com/match/6082
# https://understat.com/match/6081
# https://understat.com/match/6080
# https://understat.com/match/6079
# https://understat.com/match/6078
# https://understat.com/match/6077
# https://understat.com/match/6076
# https://understat.com/match/6144
# https://understat.com/match/6143
# https://understat.com/match/6142
# https://understat.com/match/6141
# https://understat.com/match/6140
# https://understat.com/match/6139
# https://understat.com/match/6138
# https://understat.com/match/6137
# https://understat.com/match/6136
# https://understat.com/match/6135
# https://understat.com/match/6134
# https://understat.com/match/6133
# https://understat.com/match/6132
# https://understat.com/match/6131
# https://understat.com/match/6126
# https://understat.com/match/6127
# https://understat.com/match/6128
# https://understat.com/match/6129
# https://understat.com/match/6130
# https://understat.com/match/6125
# https://understat.com/match/6124
# https://understat.com/match/6123
# https://understat.com/match/6122
# https://understat.com/match/6121
# https://understat.com/match/6120
# https://understat.com/match/6117
# https://understat.com/match/6116
# https://understat.com/match/6118
# https://understat.com/match/6119
# https://understat.com/match/6115
# https://understat.com/match/6114
# https://understat.com/match/6184
# https://understat.com/match/6183
# https://understat.com/match/6182
# https://understat.com/match/6181
# https://understat.com/match/6179
# https://understat.com/match/6178
# https://understat.com/match/6177
# https://understat.com/match/6180
# https://understat.com/match/6176
# https://understat.com/match/6175
# https://understat.com/match/6174
# https://understat.com/match/6173
# https://understat.com/match/6170
# https://understat.com/match/6168
# https://understat.com/match/6169
# https://understat.com/match/6167
# https://understat.com/match/6171
# https://understat.com/match/6172
# https://understat.com/match/6166
# https://understat.com/match/6165
# https://understat.com/match/6164
# https://understat.com/match/6163
# https://understat.com/match/6162
# https://understat.com/match/6161
# https://understat.com/match/6160
# https://understat.com/match/6159
# https://understat.com/match/6158
# https://understat.com/match/6157
# https://understat.com/match/6156
# https://understat.com/match/6155
# https://understat.com/match/6154
# https://understat.com/match/6153
# https://understat.com/match/6152
# https://understat.com/match/6151
# https://understat.com/match/6150
# https://understat.com/match/6149
# https://understat.com/match/6148
# https://understat.com/match/6147
# https://understat.com/match/6146
# https://understat.com/match/6145
# https://understat.com/match/6224
# https://understat.com/match/6223
# https://understat.com/match/6222
# https://understat.com/match/6221
# https://understat.com/match/6220
# https://understat.com/match/6219
# https://understat.com/match/6218
# https://understat.com/match/6217
# https://understat.com/match/6216
# https://understat.com/match/6215
# https://understat.com/match/6214
# https://understat.com/match/6213
# https://understat.com/match/6212
# https://understat.com/match/6211
# https://understat.com/match/6210
# https://understat.com/match/6209
# https://understat.com/match/6208
# https://understat.com/match/6207
# https://understat.com/match/6206
# https://understat.com/match/6205
# https://understat.com/match/6204
# https://understat.com/match/6202
# https://understat.com/match/6203
# https://understat.com/match/6201
# https://understat.com/match/6200
# https://understat.com/match/6199
# https://understat.com/match/6198
# https://understat.com/match/6197
# https://understat.com/match/6196
# https://understat.com/match/6195
# https://understat.com/match/6194
# https://understat.com/match/6193
# https://understat.com/match/6187
# https://understat.com/match/6189
# https://understat.com/match/6188
# https://understat.com/match/6186
# https://understat.com/match/6190
# https://understat.com/match/6191
# https://understat.com/match/6192
# https://understat.com/match/6185

# %%
row
# Out:
# id                              4238
# isResult                        True
# h_id                             162
# h_title                    SC Bastia
# h_short_title                    BAS
# a_id                             178
# a_title                         Lyon
# a_short_title                    LYO
# goals_h                          0.0
# goals_a                          3.0
# xG_h                             0.0
# xG_a                             0.0
# datetime         2017-04-16 00:00:00
# forecast_w                      0.33
# forecast_d                      0.33
# forecast_l                      0.33
# season                     2016-2017
# league                       Ligue_1
# Name: 11696, dtype: object

# %%
row['datetime'] == pd.Timestamp(2017,4,16)
# Out:
# True

# %%
from tqdm.auto import tqdm

base_url = 'https://understat.com/match/'

dfs = []

for _, row in tqdm(matches_df.iterrows()):
    if row['isResult'] == True:
        match_id = row['id']
        url = base_url + str(match_id)

        #Use requests to get the webpage and BeautifulSoup to parse the page
        res = get_page(url)
        soup = BeautifulSoup(res, 'lxml')
        scripts = soup.find_all('script')

        #get only the shotsData
        strings = scripts[2].string
        # strip unnecessary symbols and get only JSON data 
        ind_start = strings.index("('")+2 
        ind_end = strings.index("')") 
        json_data = strings[ind_start:ind_end] 
        json_data = json_data.encode('utf8').decode('unicode_escape')

        #convert string to json format
        data = json.loads(json_data)
        data_home = data['h']
        data_away = data['a']
        
        data_home = [data_home[key] for key in data_home]
        data_away = [data_away[key] for key in data_away]

        df_h = pd.DataFrame(data_home)
        df_h['season'] = row['season']
        df_h['league'] = row['league']
        df_h['match_id'] = row['id']
        df_h['HomeAway'] = 'Home'

        df_a = pd.DataFrame(data_away)
        df_a['season'] = row['season']
        df_a['league'] = row['league']
        df_a['match_id'] = row['id']
        df_a['HomeAway'] = 'Away'

        df = pd.concat([df_h, df_a])

        dfs.append(df)
        
roster_df = pd.concat(dfs)
roster_df.to_csv('dfs/rosters.csv', index=False)
# Out:
# 0it [00:00, ?it/s]
